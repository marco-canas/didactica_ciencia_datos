# %% [markdown]
# # Tutorial de acceso a los datos de Antioquia mira su cielo

# %% [markdown]
# Por Luisa Fernanda Buriticá Ruíz

# %% [markdown]
# cuál será la razón de que al intentar instalar el paquete csv me aparezca el siguiente mensaje de error: [7784 preload-host-spawn-strategy] Warning: waitpid override ignores groups
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
# ERROR: No matching distribution found for csv
# [7784 preload-host-spawn-strategy] Warning: waitpid override ignores groups

# %% [markdown]
# El mensaje de error que estás viendo indica que el paquete "csv" no está disponible para instalarse a través de la herramienta de administración de paquetes que estás utilizando (como pip o conda).
#
# La razón de este error es que "csv" es en realidad un módulo incorporado en Python y no es necesario instalarlo por separado. Es una parte estándar de la biblioteca estándar de Python, lo que significa que siempre está disponible cuando trabajas con Python.
#
# Para utilizar el módulo csv en tu código Python, simplemente importa el módulo csv en tu script:
#
# ```python
# import csv
#
# # A partir de aquí, puedes usar las funciones y clases proporcionadas por el módulo csv
# ```
#
# No es necesario instalar el paquete csv, ya que ya está incluido en la instalación de Python por defecto.
#
# Si estás teniendo algún problema específico relacionado con el módulo csv o necesitas realizar alguna tarea en particular, no dudes en proporcionar más detalles para que pueda ayudarte mejor.

# %%
import csv

# %% [markdown]
# # Cómo activar el entorno virtual necesario
#
# Utilice el siguiente código:

# %%
#source /sysroot/home/marco/Documentos/7_didactica_ciencia_datos/3_datasets/antioquia_mira_su_cielo/.venv/bin/activate
