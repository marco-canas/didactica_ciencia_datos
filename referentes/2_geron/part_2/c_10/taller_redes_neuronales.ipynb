# %% [markdown]
# # Taller sobre redes neuronales: Ejemplo de aplicación en reconocimiento de imágenes

# %% [markdown]
# Fecha: Viernes 11 de noviembre de 2022.
#
# Date: Friday 11th of november of 2022.

# %% [markdown]
# Hours: from 4:00 pm to 6:00 pm

# %% [markdown]
# Lugar: Sala de sistemas de la Seccional Bajo Cauca de la Universidad de Antioquia.

# %% [markdown]
# Inscripción: Gratuita, hasta el lunes 14 de marzo. Limitada a 30 participantes.
#
# Requisitos para la obtención del certificado acreditativo: Asistencia al menos al 80% de las clases.
#
# Contacto: Para cualquier duda dirigirse a Mª Rosa Ponce (mrponce@umh.es) o Ana Peiró (apeiro@umh.es)

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'
