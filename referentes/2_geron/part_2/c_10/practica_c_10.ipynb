# %% [markdown]
# # Obtener los datos en un proceso de constitución de un modelo de clasificación multiclase

# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
from chapter_10 import obtener_datos_fashion_mnist

# %%
(X_train_full, y_train_full), (X_test, y_test) = obtener_datos_fashion_mnist()

# %% [markdown]
# ## Constitución del conjunto de validación y escalado de los datos

# %%
X_train_full[0].dtype
# Out:
# dtype('uint8')

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %%
X_valid, X_train = X_train_full[:5000]/255.0, X_train_full[5000:]/255.0

X_test = X_test/255.0

# %%
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

# %%
X_valid.shape
# Out:
# (5000, 28, 28)

# %%
X_train.shape
# Out:
# (55000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train_full
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
y_train.shape
# Out:
# (55000,)

# %%
y_valid.shape
# Out:
# (5000,)

# %%
y_test.shape
# Out:
# (10000,)

# %%
y_test.dtype
# Out:
# dtype('uint8')
