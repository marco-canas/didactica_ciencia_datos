# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
np.random.seed(513)

X = 2*np.random.rand(100,1)
y = 4 + 3*X + np.random.randn(100,1)

# %%
X.ndim
# Out:
# 2

# %%
theta[1][0]
# Out:
# 2.903011528450276

# %%
plt.plot(X,y, 'bo')
a,b = np.min(X), np.max(X)
plt.plot([a,b],[a*theta[1][0] + theta[0][0], b*theta[1][0] + theta[0][0]],'r-')
plt.grid(alpha = 0.3)
plt.savefig('regresor_lineal_artificial.jpg')
plt.show()

# %%
X_b = np.c_[np.ones((100,1)), X]

# %%
X_b
# Out:
# array([[1.        , 0.19794495],
#        [1.        , 0.08196544],
#        [1.        , 1.32819405],
#        [1.        , 0.20578593],
#        [1.        , 1.29417135],
#        [1.        , 0.28548432],
#        [1.        , 1.06750664],
#        [1.        , 0.76222133],
#        [1.        , 1.6869686 ],
#        [1.        , 1.13418497],
#        [1.        , 1.25402165],
#        [1.        , 1.97191524],
#        [1.        , 1.28252368],
#        [1.        , 1.73461728],
#        [1.        , 0.95905237],
#        [1.        , 1.23018209],
#        [1.        , 0.35279828],
#        [1.        , 1.14484831],
#        [1.        , 1.72497552],
#        [1.        , 0.92987432],
#        [1.        , 0.94821588],
#        [1.        , 0.92245088],
#        [1.        , 1.23942555],
#        [1.        , 1.56377327],
#        [1.        , 0.91064501],
#        [1.        , 1.60885382],
#        [1.        , 1.30887886],
#        [1.        , 1.35185623],
# ...

# %%
theta = (np.linalg.inv(X_b.T.dot(X_b))).dot(X_b.T).dot(y)

# %%
theta
# Out:
# array([[4.05534262],
#        [2.90301153]])

# %%
from random import randint, random 
import numpy as np 
import matplotlib.pyplot as plt 
cant_elementos=input('Ingrese la cantidad de elementos deseada: ') 
n= int(cant_elementos) 
x = [0] 
y = [0] 
for i in range(n): 
    x.append(randint(0,100)) 
    y.append(randint(0,100)) 
    plt.plot(x,y,'x-') 
    x = [0] 
    y = [0] 
    plt.xlabel('Valores de X') 
    plt.ylabel('Valores de Y') 
    plt.show()
# Out:
# Ingrese la cantidad de elementos deseada: 2
