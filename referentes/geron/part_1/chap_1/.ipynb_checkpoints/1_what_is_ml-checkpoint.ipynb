# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/taca/blob/main/ref/geron/part_1/chap_1/1_what_is_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Capítulo 1. El panorama del aprendizaje automático

# %% [markdown]
# ## [Primer video de apoyo](https://www.youtube.com/watch?v=d8N_ydVmjYc)

# %% [markdown]
# ## ¿Qué es el aprendizaje automático?

# %% [markdown]
# El aprendizaje automático es la ciencia (y el arte) de programar computadoras para que puedan aprender de los datos.

# %% [markdown]
# **Machine Learning**
#
# es el campo de estudio que brinda a las computadoras la capacidad de aprender sin ser programadas explícitamente.
#
# —Arthur Samuel, 1959

# %% [markdown]
# **Definición de Machine Learning desde la Ingeniería**:
#
# Se dice que un programa de computadora aprende de la experiencia $E$ con respecto a alguna tarea $T$ y alguna medida de desempeño $P$,
#
# si su desempeño en $T$, medido por $P$, mejora con la experiencia $E$.
#
# —Tom Mitchell, 1997

# %% [markdown]
# Su filtro de correo no deseado (spam) es un programa de aprendizaje automático que,
# * con ejemplos de correos electrónicos no deseados (Marcados por los usuarios) y
# * ejemplos de correos electrónicos regulares, puede aprender a marcar el spam.

# %% [markdown]
# Los ejemplos que utiliza el sistema para aprender se denominan **conjunto de entrenamiento**.

# %% [markdown]
# Cada ejemplo de entrenamiento es llamada **instancia de entrenamiento (o muestra)**.

# %% [markdown]
# En este caso,
# * la tarea $T$ es marcar como spam a nuevos correos electrónicos,
# * la experiencia $E$ son los datos de entrenamiento y
# * la medida de desempeño $P$ debe definirse; por ejemplo, el utilizar la proporción de correos electrónicos clasificados correctamente.

# %% [markdown]
# Esta medida de desempeño en particular se llama **precisión**, y se utiliza a menudo en tareas de **clasificación**.

# %% [markdown]
# Si acaba de descargar un texto de Wikipedia, su computadora tiene muchos más datos, pero de repente no es mejor en ninguna tarea.

# %% [markdown]
# Por lo tanto, descargar un texto de Wikipedia no es aprendizaje automático.

# %% [markdown]
# ### ¿Por qué utilizar el aprendizaje automático?
#
# Considere cómo escribiría un filtro de spam usando la programación tradicional:

# %% [markdown]
# 1. En primer lugar, debería considerar cómo se ve normalmente el spam.
# * Puedes notar que algunas palabras o frases ("tarjeta de crédito", "gratis" e "increíble") tienden a aparecer  mucho en la línea de asunto.
# * Quizás también notaría algunos otros patrones en el nombre del remitente, el cuerpo del correo electrónico y otras partes del correo electrónico.

# %% [markdown]
# 2. Escribiría un algoritmo de detección para cada uno de los patrones que notó y su  programa marcaría los correos electrónicos como **spam** si se detectaran algunos de estos patrones.

# %% [markdown]
# 3. Probaría su programa y repetiría los pasos 1 y 2 hasta que fuera lo suficientemente bueno para ejecutarse.

# %%
from IPython.display import Image 
Image('figure_1_1.JPG',width=600,height=300)

# %% [markdown]
# Dado que el problema es difícil, es probable que su programa se convierta en una **larga lista de reglas complejas,** bastante difíciles de mantener.

# %% [markdown]
# Por el contrario, un filtro de spam basado en técnicas de **aprendizaje automático** aprende automáticamente:
#
# * qué palabras y frases son buenos predictores de spam al detectar patrones de palabras inusualmente frecuentes en los ejemplos de spam.

# %%
from IPython.display import Image 
Image('figure_1_2.jpg',width=400,height=200)

# %% [markdown]
# El programa es mucho más corto, más fácil de mantener y probablemente más preciso.

# %% [markdown]
# ¿Qué pasa si los spammers notan que todos sus correos electrónicos que contienen "4U" están bloqueados?

# %% [markdown]
# En su lugar, podrían empezar a escribir "For U".

# %% [markdown]
# Un filtro de spam que utiliza técnicas de programación tradicionales debería actualizarse para marcar los correos electrónicos "For U".

# %% [markdown]
# Si los spammers (detectores de correo no deseado) siguen trabajando alrededor de su filtro de spam, tendrá que seguir escribiendo nuevas reglas para siempre.

# %% [markdown]
# Por el contrario, un filtro de spam basado en técnicas de aprendizaje automático **detectará automáticamente** que "For U" se ha vuelto inusualmente frecuente en el spam marcado por los usuarios, y comienza a marcarlos sin su intervención.

# %%
from IPython.display import Image
Image('figure_1_3.jpg',width=600,height=300)

# %% [markdown]
# Otra área en la que destaca el aprendizaje automático son los **problemas demasiado complejos para los enfoques tradicionales** o que no tienen un algoritmo conocido.

# %% [markdown]
# Por ejemplo, considere el reconocimiento de voz:
#
# * Supongamos que desea comenzar de manera simple y escribir un programa capaz de distinguir las palabras "one" y "Two".

# %% [markdown]
# Es posible que observe que la palabra "Two" comienza con un sonido de tono alto ("T"), por lo que podría codificar un algoritmo que mida la intensidad del sonido de tono alto y usarlo para distinguir *ones* y *twos*, pero obviamente esta técnica no se puede escalar a miles de palabras habladas por millones de personas muy diferentes en entornos ruidosos y en docenas de idiomas.

# %% [markdown]
# La mejor solución (al menos hoy) es escribir un algoritmo que aprenda por sí mismo, dados muchos ejemplos de grabaciones para cada palabra.

# %% [markdown]
# Finalmente, el aprendizaje automático puede ayudar a los humanos a aprender (Figura 1-4).

# %%
from IPython.display import Image 
Image('figure_1_4.jpg',width=600,height=300)

# %% [markdown]
# Los algoritmos de ML se pueden inspeccionar para ver qué han aprendido (aunque para algunos algoritmos esto puede ser complicado).

# %% [markdown]
# Por ejemplo, una vez que un filtro de spam ha sido entrenado con suficiente spam, se puede inspeccionar fácilmente para revelar la lista de palabras y combinaciones de palabras que cree que son los mejores predictores de spam.

# %% [markdown]
# A veces, esto revelará correlaciones insospechadas o nuevas tendencias y, por lo tanto, conducirá a una mejor comprensión del problema.

# %% [markdown]
# La aplicación de técnicas de aprendizaje automático para profundizar en grandes cantidades de datos puede ayudar a descubrir patrones que no eran evidentes de inmediato.
#
# * A esto se le llama **minería de datos**.

# %% [markdown]
# En resumen, el aprendizaje automático es ideal para:

# %% [markdown]
# * Problemas para los que las soluciones existentes requieren muchos ajustes o listas largas de reglas: un algoritmo de aprendizaje automático a menudo puede simplificar el código y funcionar mejor que el enfoque tradicional.

# %% [markdown]
# * Problemas complejos para los que el uso de un **enfoque tradicional** no ofrece una buena solución: las mejores técnicas de aprendizaje automático tal vez puedan encontrar una solución.

# %% [markdown]
# * Entornos fluctuantes: un sistema de aprendizaje automático puede adaptarse a nuevos datos.

# %% [markdown]
# * Obtener información sobre problemas complejos y grandes cantidades de datos.

# %% [markdown]
# # Ejemplos de aplicaciones

# %% [markdown]
# ### [Segundo video de apoyo](https://www.youtube.com/watch?v=GimwAuG10cE)

# %% [markdown]
# Veamos algunos ejemplos concretos de tareas de Machine Learning, junto con las técnicas que pueden abordarlas:

# %% [markdown]
# Analizar imágenes de productos en una línea de producción para clasificarlos automáticamente

# %% [markdown]
# Esta es la clasificación de imágenes, que normalmente se realiza mediante redes neuronales convolucionales (CNN; consulte el Capítulo 14).

# %% [markdown]
# Detección de tumores en escáneres cerebrales.

# %% [markdown]
# Se trata de una segmentación semántica, en la que se clasifica cada píxel de la imagen (como queremos determinar la ubicación exacta y la forma de los tumores), normalmente también mediante CNN.

# %% [markdown]
# Clasificación automática de artículos de noticias

# %% [markdown]
# Este es el procesamiento del lenguaje natural (NLP) y, más específicamente, la clasificación de texto, que se puede abordar utilizando redes neuronales recurrentes (RNN), CNN o Transformers (consulte el Capítulo 16).

# %% [markdown]
# Marcar automáticamente comentarios ofensivos en foros de discusión

# %% [markdown]
# Esta también es una clasificación de texto, utilizando las mismas herramientas de PNL.

# %% [markdown]
# Resumir documentos largos automáticamente

# %% [markdown]
# Esta es una rama de la PNL llamada resumen de texto, nuevamente usando las mismas herramientas.

# %% [markdown]
# Crear un chatbot o un asistente personal

# %% [markdown]
# Esto involucra muchos componentes de la PNL, incluida la comprensión del lenguaje natural (NLU) y los módulos de respuesta a preguntas.

# %% [markdown]
# * Pronosticar los ingresos de su empresa el próximo año, en base a muchas métricas de desempeño

# %% [markdown]
# Esta es una tarea de regresión (es decir, predecir valores) que se puede abordar utilizando cualquier modelo de regresión,
# * como un modelo de regresión lineal o
# * de regresión polinomial (ver Capítulo 4),
# * una SVM de regresión (ver Capítulo 5),
# * un bosque aleatorio de regresión (ver Capítulo 7),
# * o una red neuronal artificial (ver Capítulo 10).

# %% [markdown]
# Si desea tener en cuenta las secuencias de métricas de rendimiento anteriores, puede utilizar RNN, CNN o Transformers (consulte los capítulos 15 y 16).

# %% [markdown]
# Hacer que su aplicación reaccione a los comandos de voz

# %% [markdown]
# Este es el reconocimiento de voz, que requiere procesar muestras de audio:

# %% [markdown]
# dado que son secuencias largas y complejas, normalmente se procesan utilizando RNN, CNN o Transformers (véanse los capítulos 15 y 16).

# %% [markdown]
# Detección de fraudes con tarjetas de crédito Se trata de detección de anomalías (consulte el Capítulo 9).

# %% [markdown]
# * Segmentar clientes en función de sus compras para que puedas diseñar una estrategia de marketing diferente para cada segmento.
# Esta es una tarea de agrupación (consulte el Capítulo 9).

# %% [markdown]
# Representar un conjunto de datos complejo y de alta dimensión en un diagrama claro y profundo

# %% [markdown]
# Esta es la visualización de datos, que a menudo implica técnicas de reducción de dimensionalidad (consulte el Capítulo 8).

# %% [markdown]
# ## Recomendar un producto que pueda interesar a un cliente, basado en compras anteriores

# %% [markdown]
# Este es un sistema de recomendación. Un enfoque consiste en alimentar las compras anteriores (y otra información sobre el cliente) a una red neuronal artificial (consulte el Capítulo 10) y hacer que produzca la próxima compra más probable.

# %% [markdown]
# Esta red neuronal normalmente se entrenaría en secuencias pasadas de compras en todos los clientes.

# %% [markdown]
# ## Construyendo un bot inteligente para un juego

# %% [markdown]
# Esto a menudo se aborda mediante el aprendizaje por refuerzo (RL; consulte el Capítulo 18), que es una rama del aprendizaje automático que capacita a los agentes (como los bots) para elegir las acciones que maximizarán sus recompensas con el tiempo (por ejemplo, un bot puede obtener una recompensa cada vez que el jugador pierde algunos puntos de vida), dentro de un entorno determinado (como el juego).

# %% [markdown]
# El famoso programa AlphaGo que venció al campeón mundial en el juego de Go fue construido usando RL.

# %% [markdown]
# Esta lista podría seguir y seguir, pero es de esperar que le dé una idea de la increíble amplitud y complejidad de las tareas que puede abordar el aprendizaje automático y los tipos de técnicas que usaría para cada tarea.

# %% [markdown]
# # Tipos de sistemas de aprendizaje automático

# %% [markdown]
# Hay tantos tipos diferentes de sistemas de aprendizaje automático que es útil clasificarlos en categorías amplias, según los siguientes criterios:

# %% [markdown]
# Si están capacitados o no con supervisión humana (supervisados, no supervisados, semisupervisados y aprendizaje reforzado)

# %% [markdown]
# Si pueden aprender o no de forma incremental sobre la marcha (aprendizaje en línea o por lotes)

# %% [markdown]
# Ya sea que funcionen simplemente comparando nuevos puntos de datos con puntos de datos conocidos o, en cambio, detectando patrones en los datos de entrenamiento y construyendo un modelo predictivo, al igual que lo hacen los científicos (aprendizaje basado en instancias versus aprendizaje basado en modelos)

# %% [markdown]
# Estos criterios no son exclusivos; puedes combinarlos de la forma que quieras.

# %% [markdown]
# Por ejemplo, un filtro de spam de última generación puede aprender sobre la marcha utilizando un modelo de red neuronal profunda entrenado con ejemplos de spam y ham; esto lo convierte en un sistema de aprendizaje supervisado, basado en modelos y en línea.

# %% [markdown]
# Veamos cada uno de estos criterios un poco más de cerca.

# %% [markdown]
# ## Aprendizaje supervisado/no supervisado

# %% [markdown]
# Los sistemas de aprendizaje automático se pueden clasificar según la cantidad y el tipo de supervisión que reciben durante el entrenamiento.

# %% [markdown]
# Hay cuatro categorías principales:
#
# * aprendizaje supervisado,
# * aprendizaje no supervisado,
# * aprendizaje semisupervisado y
# * aprendizaje reforzado.

# %% [markdown]
# ## Supervised learning

# %% [markdown]
# En el aprendizaje supervisado, el conjunto de entrenamiento que alimenta al algoritmo incluye las soluciones deseadas, llamadas etiquetas (Figura 1-5).

# %%
from IPython.display import Image
Image('figure_1_5.JPG',width=600,height=300)

# %% [markdown]
# * Una tarea típica de aprendizaje supervisado es la clasificación.
# * El filtro de spam es un buen ejemplo de esto: está entrenado con muchos correos electrónicos de ejemplo junto con su clase (spam o ham), y debe aprender a clasificar nuevos correos electrónicos.

# %% [markdown]
# Otra tarea típica es predecir un valor numérico objetivo, como el precio de un automóvil, dado un conjunto de características (kilometraje, edad, marca, etc.) llamados predictores.

# %% [markdown]
# * Este tipo de tarea se llama **regresión** (Figura 1-6).
# * Para entrenar el sistema, debe darle muchos ejemplos de automóviles, incluidos sus predictores y sus etiquetas (es decir, sus precios).

# %% [markdown]
# NOTA

# %% [markdown]
# * En Machine Learning, un **atributo** es un tipo de datos (por ejemplo, "kilometraje"),
# * mientras que una característica tiene varios significados, según el contexto, pero generalmente significa un atributo más su valor (por ejemplo, "kilometraje = 15.000").

# %% [markdown]
# Mucha gente usa las palabras atributo y característica indistintamente.

# %% [markdown]
# Tenga en cuenta que algunos algoritmos de regresión también se pueden utilizar para la clasificación y viceversa.

# %% [markdown]
# Por ejemplo, la regresión logística se usa comúnmente para la clasificación, ya que puede generar un valor que corresponde a la probabilidad de pertenecer a una clase determinada (por ejemplo, 20% de probabilidad de ser spam).

# %%
from IPython.display import Image
Image('figure_1_6.jpg',width=600,height=300)

# %% [markdown]
# Estos son algunos de los algoritmos de aprendizaje supervisado más importantes (que se tratan en este libro):

# %% [markdown]
# * $k$-Vecinos más cercanos
# * Regresión lineal
# * Regresión logística
# * Máquinas de soporte vectorial (SVM)
# * Árboles de decisión y bosques aleatorios
# * Redes neuronales

# %% [markdown]
# ## Aprendizaje sin supervisión

# %% [markdown]
# * En el aprendizaje no supervisado, como puede adivinar, los datos de entrenamiento no están etiquetados (Figura 1-7).
# * El sistema intenta aprender sin un maestro.

# %%
from IPython.display import Image 
Image('figure_1_7.jpg',width=600,height=300)

# %% [markdown]
# Estos son algunos de los algoritmos de aprendizaje no supervisados más importantes (la mayoría de ellos se tratan en los capítulos 8 y 9):

# %% [markdown]
# * Clustering
#   * K-Means
#   * DBSCAN
#   * Hierarchical Cluster Analysis (HCA)

# %% [markdown]
# * Agrupación
#   * K-medias
#   * DBSCAN
#   * Análisis jerárquico de conglomerados (HCA)

# %% [markdown]
# * Detección de anomalías y detección de novedades.
#   * SVM de una clase
#   * Bosque de aislamiento

# %% [markdown]
# * Visualización y reducción de dimensionalidad
#   * Análisis de componentes principales (PCA)
#   * Kernel PCA
#   * Incrustación lineal local (LLE)
#   * Incorporación de vecinos estocásticos distribuidos en t (t-SNE)

# %% [markdown]
# * Aprendizaje de reglas de asociación
#   * Apriori
#   * Eclat

# %% [markdown]
# Por ejemplo, supongamos que tiene muchos datos sobre los visitantes de su blog.

# %% [markdown]
# Es posible que desee ejecutar un algoritmo de agrupación en clústeres para intentar detectar grupos de visitantes similares (Figura 1-8).

# %% [markdown]
# En ningún momento le dice al algoritmo a qué grupo pertenece un visitante: encuentra esas conexiones sin su ayuda.

# %% [markdown]
# Por ejemplo, podría notar que el 40% de sus visitantes son hombres que aman los cómics y generalmente leen su blog por la noche, mientras que el 20% son jóvenes amantes de la ciencia ficción que visitan los fines de semana.

# %% [markdown]
# Si usa un algoritmo de agrupamiento jerárquico, también puede subdividir cada grupo en grupos más pequeños.

# %% [markdown]
# Esto puede ayudarlo a orientar sus publicaciones para cada grupo.

# %%
from IPython.display import Image
Image('figure_1_8.jpg',width=600,height=300)

# %% [markdown]
# Los algoritmos de visualización también son buenos ejemplos de algoritmos de aprendizaje no supervisados: usted les proporciona una gran cantidad de datos complejos y sin etiquetar, y generan una representación 2D o 3D de sus datos que se puede trazar fácilmente (Figura 1-9).

# %% [markdown]
# Estos algoritmos intentan preservar la mayor cantidad de estructura posible (por ejemplo, tratando de evitar que los clústeres separados en el espacio de entrada se superpongan en la visualización) para que pueda comprender cómo se organizan los datos y quizás identificar patrones insospechados.

# %%
from IPython.display import Image
Image('figure_1_9.jpg',width=600,height=300)

# %% [markdown]
# Una tarea relacionada es la reducción de dimensionalidad, en la que el objetivo es simplificar los datos sin perder demasiada información.

# %% [markdown]
# Una forma de hacer esto es fusionar varias propiedades correlacionadas en una.

# %% [markdown]
# Por ejemplo, el kilometraje de un automóvil puede estar fuertemente correlacionado con su edad, por lo que el algoritmo de reducción de dimensionalidad los fusionará en una característica que representa el desgaste del automóvil.

# %% [markdown]
# A esto se le llama extracción de características.

# %% [markdown]
# ## TIP  o consejo.

# %% [markdown]
# A menudo, es una buena idea intentar reducir la dimensión de sus datos de entrenamiento utilizando un algoritmo de reducción de dimensionalidad antes de alimentarlo a otro algoritmo de aprendizaje automático (como un algoritmo de aprendizaje supervisado).

# %% [markdown]
# Se ejecutará mucho más rápido, los datos ocuparán menos espacio en disco y memoria y, en algunos casos, también puede funcionar mejor.

# %% [markdown]
# Otra tarea importante sin supervisión es la detección de anomalías, por ejemplo, detectar transacciones inusuales con tarjetas de crédito para evitar fraudes, detectar defectos de fabricación o eliminar automáticamente los valores atípicos de un conjunto de datos antes de enviarlos a otro algoritmo de aprendizaje.

# %% [markdown]
# El sistema se muestra principalmente en instancias normales durante el entrenamiento, por lo que aprende a reconocerlas; luego, cuando ve una nueva instancia, puede decir si se ve como una normal o si es probable que sea una anomalía (vea la Figura 1-10).

# %% [markdown]
# Una tarea muy similar es la detección de novedades: tiene como objetivo detectar nuevas instancias que se ven diferentes de todas las instancias en el conjunto de entrenamiento. Esto requiere tener un conjunto de entrenamiento muy "limpio", desprovisto de cualquier instancia que le gustaría que detecte el algoritmo.

# %% [markdown]
# Por ejemplo, si tiene miles de imágenes de perros, y el 1% de estas imágenes representan chihuahuas, entonces un algoritmo de detección de novedades no debería tratar las nuevas imágenes de chihuahuas como novedades.

# %% [markdown]
# Por otro lado, los algoritmos de detección de anomalías pueden considerar a estos perros como tan raros y tan diferentes de otros perros que probablemente los clasificarían como anomalías (sin ofender a los chihuahuas).

# %%
from IPython.display import Image
Image('figure_1_10.jpg',width=600,height=300)

# %% [markdown]
# Finalmente, otra tarea común sin supervisión es el aprendizaje de reglas de asociación, en el que el objetivo es profundizar en grandes cantidades de datos y descubrir relaciones interesantes entre atributos.

# %% [markdown]
# Por ejemplo, suponga que tiene un supermercado:
# * La ejecución de una regla de asociación en sus registros de ventas puede revelar que las personas que comprar salsa barbacoa y papas fritas también suelen comprar bistec.

# %% [markdown]
# Por lo tanto, es posible que desee colocar estos elementos cerca unos de otros.

# %% [markdown]
# ## Aprendizaje semisupervisado

# %% [markdown]
# Dado que el etiquetado de datos suele llevar mucho tiempo y es costoso, a menudo
# tienen muchas instancias sin etiquetar y pocas instancias etiquetadas. Algunos
# los algoritmos pueden manejar datos que están parcialmente etiquetados. Se llama
# aprendizaje semisupervisado (Figura 1-11).

# %%
from IPython.display import Image
Image('figure_1_11.jpg',width=600,height=300)

# %% [markdown]
# Algunos servicios de alojamiento de fotografías, como Google Photos, son buenos ejemplos de esto. Una vez que subes todas las fotos de tu familia al servicio, este reconoce automáticamente que la misma persona A aparece en las fotos 1, 5 y 11, mientras que otra persona B aparece en las fotos 2, 5 y 7. Esta es la parte sin supervisión del algoritmo (agrupamiento).

# %% [markdown]
# Ahora todo lo que necesita el sistema es que le digas quiénes son estas personas. Simplemente agregue una etiqueta por persona y podrá nombrar
# todos en cada foto, lo cual es útil para buscar fotos.

# %% [markdown]
# La mayoría de los algoritmos de aprendizaje semisupervisados ​​son combinaciones de algoritmos supervisados ​​y no supervisados.

# %% [markdown]
# Por ejemplo, las redes de creencias profundas (DBN) se basan en componentes no supervisados ​​llamados máquinas de Boltzmann restringidas (RBM) apiladas una encima de la otra.

# %% [markdown]
# Los RBM se entrenan secuencialmente de una manera no supervisada, y luego todo el sistema se afina utilizando técnicas de aprendizaje supervisado.

# %% [markdown]
# ## Aprendizaje reforzado

# %% [markdown]
# El aprendizaje por refuerzo es una bestia muy diferente.

# %% [markdown]
# El sistema de aprendizaje, denominado agente en este contexto, puede observar el entorno, seleccionar y realizar acciones y obtener recompensas a cambio (o sanciones en forma de recompensas negativas, como se muestra en la Figura 1-12).

# %% [markdown]
# Luego debe aprender por sí mismo cuál es la mejor estrategia, llamada política, para obtener la mayor recompensa con el tiempo.

# %% [markdown]
# Una política define qué acción debe elegir el agente cuando se encuentra en una situación determinada.

# %%
from IPython.display import Image
Image('figure_1_12.jpg',width=600,height=300)

# %% [markdown]
# Por ejemplo, muchos robots implementan algoritmos de aprendizaje por refuerzo para aprender a caminar.

# %% [markdown]
# DeepMind’s AlphaGo program is also a good example of Reinforcement Learning: it made the headlines in May 2017 when it beat the world champion Ke Jie at the game of Go.

# %% [markdown]
# Por ejemplo, muchos robots implementan algoritmos de aprendizaje por refuerzo para aprender a caminar.

# %% [markdown]
# El programa AlphaGo de DeepMind también es un buen ejemplo de aprendizaje por refuerzo: apareció en los titulares en mayo de 2017 cuando venció al campeón mundial Ke Jie en el juego de Go.

# %% [markdown]
# Aprendió su política ganadora analizando millones de juegos y luego jugando muchos juegos contra sí mismo.

# %% [markdown]
# Tenga en cuenta que el aprendizaje se apagó durante los juegos contra el campeón; AlphaGo solo estaba aplicando la política que había aprendido.

# %% [markdown]
# Aprendió su política ganadora analizando millones de juegos y luego jugando muchos juegos contra sí mismo.

# %% [markdown]
# Tenga en cuenta que el aprendizaje se desactivó durante los juegos contra el campeón; AlphaGo solo estaba aplicando la política que había aprendido.

# %% [markdown]
# ## Aprendizaje por lotes y en línea

# %% [markdown]
# Another criterion used to classify Machine Learning systems is whether or not the system can learn incrementally from a stream of incoming data.

# %% [markdown]
# Otro criterio utilizado para clasificar los sistemas de aprendizaje automático es si el sistema puede aprender de forma incremental a partir de un flujo de datos entrantes.

# %% [markdown]
# ### Batch learning

# %% [markdown]
# ### Aprendizaje por lotes

# %% [markdown]
# En el aprendizaje por lotes, el sistema es incapaz de aprender de forma incremental: debe entrenarse utilizando todos los datos disponibles. Por lo general, esto requerirá mucho tiempo y recursos informáticos, por lo que generalmente se realiza sin conexión.

# %% [markdown]
# Primero se entrena el sistema, luego se lanza a producción y se ejecuta sin aprender nunca más; simplemente aplica lo que ha aprendido.

# %% [markdown]
# A esto se le llama aprendizaje fuera de línea.

# %% [markdown]
# Si desea que un sistema de aprendizaje por lotes conozca datos nuevos (como un nuevo tipo de spam), debe entrenar una nueva versión del sistema desde cero en el conjunto de datos completo (no solo los nuevos datos, sino también los antiguos ), luego detenga el sistema anterior y reemplácelo por el nuevo.

# %% [markdown]
# Afortunadamente, todo el proceso de capacitación, evaluación y lanzamiento de un sistema de aprendizaje automático se puede automatizar con bastante facilidad (como se muestra en la Figura 1-3), por lo que incluso un sistema de aprendizaje por lotes puede adaptarse al cambio.

# %% [markdown]
# Simplemente actualice los datos y entrene una nueva versión del sistema desde cero con la frecuencia que necesite.

# %% [markdown]
# This solution is simple and often works fine, but training using the full set of data can take many hours, so you would typically train a new system only every 24 hours or even just weekly.

# %% [markdown]
# Si su sistema necesita adaptarse a datos que cambian rápidamente (por ejemplo, para predecir los precios de las acciones), entonces necesita una solución más reactiva.

# %% [markdown]
# Also, training on the full set of data requires a lot of computing resources (CPU, memory space, disk space, disk I/O, network I/O, etc.).

# %% [markdown]
# If you have a lot of data and you automate your system to train from scratch every day, it will end up costing you a lot of money.

# %% [markdown]
# If the amount of data is huge, it may even be impossible to use a batch learning algorithm.

# %% [markdown]
# Finally, if your system needs to be able to learn autonomously and it has limited resources (e.g., a smartphone application or a rover on Mars), then carrying around large amounts of training data and taking up a lot of resources to train for hours every day is a showstopper.

# %% [markdown]
# Fortunately, a better option in all these cases is to use algorithms that are
# capable of learning incrementally.

# %% [markdown]
# ### Aprender en línea

# %% [markdown]
# En el aprendizaje en línea, el sistema se entrena de forma incremental alimentándolo con instancias de datos de forma secuencial, ya sea individualmente o en pequeños grupos llamados minilotes.

# %% [markdown]
# Cada paso de aprendizaje es rápido y económico, por lo que el sistema puede aprender sobre nuevos datos sobre la marcha, a medida que llegan (consulte la Figura 1-13).

# %%
from IPython.display import Image
Image('figure_1_13.jpg',width=600,height=300)

# %% [markdown]
# El aprendizaje en línea es excelente para los sistemas que reciben datos como un flujo continuo (por ejemplo, precios de las acciones) y necesitan adaptarse a los cambios de manera rápida o autónoma.

# %% [markdown]
# También es una buena opción si tiene recursos informáticos limitados: una vez que un sistema de aprendizaje en línea ha aprendido sobre nuevas instancias de datos, ya no los necesita, por lo que puede descartarlos (a menos que desee poder retroceder a una estado y "reproducir" los datos).

# %% [markdown]
# Esto puede ahorrar una gran cantidad de espacio.

# %% [markdown]
# Los algoritmos de aprendizaje en línea también se pueden usar para entrenar sistemas en enormes conjuntos de datos que no pueden caber en la memoria principal de una máquina (esto se llama aprendizaje fuera de núcleo).

# %% [markdown]
# El algoritmo carga parte de los datos, ejecuta un paso de entrenamiento en esos datos y repite el proceso hasta que se ha ejecutado en todos los datos (consulte la Figura 1-14).

# %%
from IPython.display import Image
Image('figure_1_14.jpg',width=600,height=300)

# %% [markdown]
# ## WARNING

# %% [markdown]
# Un parámetro importante de los sistemas de aprendizaje en línea es qué tan rápido deben adaptarse a los datos cambiantes: esto se llama tasa de aprendizaje.

# %% [markdown]
# Si establece una alta tasa de aprendizaje, su sistema se adaptará rápidamente a los datos nuevos, pero también tenderá a olvidar rápidamente los datos antiguos (no desea que un filtro de correo no deseado marque solo los últimos tipos de correo no deseado que se mostró).

# %% [markdown]
# Por el contrario, si establece una tasa de aprendizaje baja, el sistema tendrá más inercia; es decir, aprenderá más lentamente, pero también será menos sensible al ruido en los nuevos datos o a secuencias de puntos de datos no representativos (valores atípicos).

# %% [markdown]
# Un gran desafío con el aprendizaje en línea es que si se introducen datos incorrectos en el sistema, el rendimiento del sistema disminuirá gradualmente.

# %% [markdown]
# Si es un sistema en vivo, sus clientes lo notarán.

# %% [markdown]
# For example, bad data could come from a malfunctioning sensor on a robot, or from someone spamming a search engine to try to rank high in search results.

# %% [markdown]
# To reduce this risk, you need to monitor your system closely and promptly switch learning off (and possibly revert to a previously working state) if you detect a drop in performance.

# %% [markdown]
# You may also want to monitor the input data and react to abnormal data (e.g., using an anomaly detection algorithm).

# %% [markdown]
# ## Instance-Based Versus Model-Based Learning

# %% [markdown]
# One more way to categorize Machine Learning systems is by how they generalize.

# %% [markdown]
# Most Machine Learning tasks are about making predictions.

# %% [markdown]
# This means that given a number of training examples, the system needs to be able to make good predictions for (generalize to) examples it has never seen before.

# %% [markdown]
# Having a good performance measure on the training data is good, but insufficient; the true goal is to perform well on new instances.

# %% [markdown]
# There are two main approaches to generalization: instance-based learning
# and model-based learning.

# %% [markdown]
# ## Instance-based learning

# %% [markdown]
# Possibly the most trivial form of learning is simply to learn by heart. If you
# were to create a spam filter this way, it would just flag all emails that are
# identical to emails that have already been flagged by users—not the worst
# solution, but certainly not the best.

# %% [markdown]
# Instead of just flagging emails that are identical to known spam emails, your spam filter could be programmed to also flag emails that are very similar to known spam emails.

# %% [markdown]
# This requires a measure of similarity between two emails.

# %% [markdown]
# A (very basic) similarity measure between two emails could be to count the number of words they have in common.

# %% [markdown]
# The system would flag an email as spam if it has many words in common with a known spam email.

# %% [markdown]
# This is called instance-based learning: the system learns the examples by heart, then generalizes to new cases by using a similarity measure to compare them to the learned examples (or a subset of them).

# %% [markdown]
# For example, in Figure 1-15 the new instance would be classified as a triangle because
# the majority of the most similar instances belong to that class.

# %%
from IPython.display import Image
Image('figure_1_15.jpg',width=600,height=300)

# %% [markdown]
# ## Model-based learning

# %% [markdown]
# Otra forma de generalizar a partir de un conjunto de ejemplos es construir un modelo de estos ejemplos y luego usar ese modelo para hacer predicciones.

# %% [markdown]
# Esto se llama aprendizaje basado en modelos (Figura 1-16).

# %%
from IPython.display import Image
Image('figure_1_16.jpg',width=600,height=300)

# %% [markdown]
# Por ejemplo, suponga que desea saber si el dinero hace feliz a la gente, por lo que descarga los datos del Índice para una vida mejor del sitio web de la OCDE y las estadísticas sobre el producto interno bruto (PIB) per cápita del sitio web del FMI.

# %% [markdown]
# Then you join the tables and sort by GDP per capita. Table 1-1 shows an excerpt of what you get.

# %%
from IPython.display import Image
Image('table_1_1.jpg',width=600,height=300)

# %% [markdown]
# Let’s plot the data for these countries (Figure 1-17).

# %%
from IPython.display import Image
Image('figure_1_17.jpg',width=600,height=300)

# %% [markdown]
# There does seem to be a trend here! Although the data is noisy (i.e., partly random), it looks like life satisfaction goes up more or less linearly as the country’s GDP per capita increases.

# %% [markdown]
# So you decide to model life satisfaction as a linear function of GDP per capita. This step is called model selection:
# you selected a linear model of life satisfaction with just one attribute, GDP per capita (Equation 1-1).

# %% [markdown]
# Equation 1-1. A simple linear model

# %% [markdown]
# $$ \text{life satisfaction} = \theta_{0} + \theta_{1} \times \text{GDP per capita} $$

# %% [markdown]
# Este modelo tiene dos parámetros de modelo, $\theta_{0}$ y $\theta_{1}$.

# %% [markdown]
# Al ajustar estos parámetros, puede hacer que su modelo represente cualquier función lineal, como se muestra en la Figura 1-18.

# %%
from IPython.display import Image
Image('figure_1_18.jpg',width=600,height=300)

# %% [markdown]
# Before you can use your model, you need to define the parameter values θ and θ .

# %% [markdown]
# How can you know which values will make your model perform best?

# %% [markdown]
# To answer this question, you need to specify a performance measure.

# %% [markdown]
# You can either define a utility function (or fitness function) that measures how good your model is, or you can define a cost function that measures how bad it is.

# %% [markdown]
# For Linear Regression problems, people typically use a cost function that measures the distance between the linear model’s predictions and the training examples; the objective is to minimize this distance.

# %% [markdown]
# This is where the Linear Regression algorithm comes in: you feed it your training examples, and it finds the parameters that make the linear model fit best to your data.

# %% [markdown]
# This is called training the model. In our case, the algorithm finds that the optimal parameter values are θ = 4.85 and θ =
# 4.91 × 10 .

# %% [markdown]
# ## WARNING

# %% [markdown]
# De manera confusa, la misma palabra "modelo" puede referirse a un tipo de modelo (p. ej., regresión lineal), a una arquitectura de modelo completamente especificada (p. ej., regresión lineal con una entrada y una salida) o al modelo final entrenado listo para ser utilizado. utilizado para predicciones (por ejemplo, regresión lineal con una entrada y una salida, usando $\theta_{0} = 4,85$ y $\theta_{1} = 4,91 \times 10$).

# %% [markdown]
# Model selection consists in choosing the type of model and fully specifying its architecture.

# %% [markdown]
# Training a model means running an algorithm to find the model parameters that will make it best fit the training data (and hopefully make good predictions on new data).

# %% [markdown]
# Ahora el modelo se ajusta lo más posible a los datos de entrenamiento (para un modelo lineal), como puede ver en la Figura 1-19.

# %% [markdown]
# <img src = 'https://github.com/marco-canas/didactica_ciencia_datos/blob/main/referentes/geron/part_1/chap_1/figure_1_19.jpg?raw=true'>

# %% [markdown]
# You are finally ready to run the model to make predictions.

# %% [markdown]
# For example, say you want to know how happy Cypriots are, and the OECD data does not have the answer.

# %% [markdown]
# Fortunately, you can use your model to make a good prediction: you look up Cyprus’s GDP per capita, find $\$22,587$, and then
# apply your model and find that life satisfaction is likely to be somewhere around $4.85 + 22,587 \times 4.91 \times 10 = 5.96$.

# %% [markdown]
# To whet your appetite, Example 1-1 shows the Python code that loads the data, prepares it, creates a scatterplot for visualization, and then trains a linear model and makes a prediction.

# %% [markdown]
# Example 1-1. Training and running a linear model using Scikit-Lear

# %%
def prepare_country_stats(oecd_bli, gdp_per_capita):
    oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
    oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
    gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
    gdp_per_capita.set_index("Country", inplace=True)
    full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)
    full_country_stats.sort_values(by="GDP per capita", inplace=True)
    remove_indices = [0, 1, 6, 8, 33, 34, 35]
    keep_indices = list(set(range(36)) - set(remove_indices))
    return full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model


# Load the data
url1 = 'https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/lifesat/oecd_bli_2015.csv'
oecd_bli = pd.read_csv(url1, thousands=',')

url2 = 'https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/lifesat/gdp_per_capita.csv'
gdp_per_capita = pd.read_csv(url2,thousands=',',delimiter='\t',
encoding='latin1', na_values="n/a")


# Prepare the data
country_stats = prepare_country_stats(oecd_bli, gdp_per_capita)
X = np.c_[country_stats["GDP per capita"]]
y = np.c_[country_stats["Life satisfaction"]]
# Visualize the data
country_stats.plot(kind='scatter', x="GDP per capita", y='Life satisfaction')
plt.show()
# Select a linear model
model = sklearn.linear_model.LinearRegression()
# Train the model
model.fit(X, y)
# Make a prediction for Cyprus
X_new = [[22587]] # Cyprus's GDP per capita
print(model.predict(X_new)) # outputs [[ 5.96242338]]
# Out:
# [[5.96242338]]

# %% [markdown]
# ## NOTE

# %% [markdown]
# If you had used an instance-based learning algorithm instead, you would have found that
# Slovenia has the closest GDP per capita to that of Cyprus ($20,732), and since the
# OECD data tells us that Slovenians’ life satisfaction is 5.7, you would have predicted a
# life satisfaction of 5.7 for Cyprus. If you zoom out a bit and look at the two next-closest
# countries, you will find Portugal and Spain with life satisfactions of 5.1 and 6.5,
# respectively. Averaging these three values, you get 5.77, which is pretty close to your
# model-based prediction. This simple algorithm is called k-Nearest Neighbors regression
# (in this example, k = 3).

# %% [markdown]
# Replacing the Linear Regression model with k-Nearest Neighbors regression in the previous code is as simple as replacing these two lines:

# %%
import sklearn.linear_model
model = sklearn.linear_model.LinearRegression()

# %% [markdown]
# with these two:

# %%
import sklearn.neighbors
model = sklearn.neighbors.KNeighborsRegressor(
n_neighbors=3)

# %% [markdown]
# If all went well, your model will make good predictions. If not, you may
# need to use more attributes (employment rate, health, air pollution, etc.), get
# more or better-quality training data, or perhaps select a more powerful
# model (e.g., a Polynomial Regression model).
# In summary:
# You studied the data.
# You selected a model.
# You trained it on the training data (i.e., the learning algorithm
# searched for the model parameter values that minimize a cost
# function).
# Finally, you applied the model to make predictions on new cases
# (this is called inference), hoping that this model will generalize well.
# This is what a typical Machine Learning project looks like. In Chapter 2
# you will experience this firsthand by going through a project end to end.
# We have covered a lot of ground so far: you now know what Machine
# Learning is really about, why it is useful, what some of the most common
# categories of ML systems are, and what a typical project workflow looks
# like. Now let’s look at what can go wrong in learning and prevent you from
# making accurate predictions.

# %% [markdown]
# ## Main Challenges of Machine Learning

# %% [markdown]
# In short, since your main task is to select a learning algorithm and train it on
# some data, the two things that can go wrong are “bad algorithm” and “bad
# data.” Let’s start with examples of bad data.

# %% [markdown]
# ### Insufficient Quantity of Training Data

# %% [markdown]
# For a toddler to learn what an apple is, all it takes is for you to point to an apple and say “apple” (possibly repeating this procedure a few times).

# %% [markdown]
# Now the child is able to recognize apples in all sorts of colors and shapes.

# %% [markdown]
# Genius.

# %% [markdown]
# Machine Learning is not quite there yet; it takes a lot of data for most Machine Learning algorithms to work properly.

# %% [markdown]
# Even for very simple problems you typically need thousands of examples, and for complex problems such as image or speech recognition you may need millions of examples (unless you can reuse parts of an existing model).
