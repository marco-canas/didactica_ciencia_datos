# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/1_Basic_Descriptive_Statistics/1_medidas_tendencia_central/3_moda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo a la lectura interactiva y experimental de esta cuaderno]()

# %% [markdown]
# # Rango

# %% [markdown]
# Defnición: Diferencia entre el valor máximo y el valor

# %% [markdown]
# # Agenda
#
# 1. Generación de muestras o matrices aleatorias con el módulo random de NumPy.
# 2. rango como función definida por el usuario
# 3. rango con statistics
# 4. Rango intercuartílico.

# %% [markdown]
# ## Práctica de cálculo e interpretación del rango con Python

# %%
import numpy as np 
import scipy as sc
import statistics as st

# %%
estaturas = np.array([1.65, 1.55, 1.70, 1.60, 1.65])

# %%
estaturas.sort()

# %%
estaturas # estaturas ordenadas
# Out:
# array([1.55, 1.6 , 1.65, 1.65, 1.7 ])

# %%
def rango(datos):
    maximo = np.max(datos)
    minimo = np.min(datos)
    rango = maximo-minimo
    return rango

# %%
rango(estaturas)
# Out:
# 0.1499999999999999

# %%
sc.stats.iqr(estaturas, rng=(0, 100))
# Out:
# 0.1499999999999999

# %% [markdown]
# ## Interpretación
#
# Las alturas de las personas dadas solo difieren en 15 centímetros a lo sumo.

# %% [markdown]
# ## Tareas de fijación de conceptos y adquisición de habilidades

# %% [markdown]
# ## Evaluación

# %% [markdown]
# ## Referentes

# %% [markdown]
# * Documentación de scipy para calcular el rango intercuartílico.
# * Función iqr del módulo stats de la librería scipy: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.iqr.html
# * Sobre el módulo statistics de python y las medidas de dispersión de datos: https://docs.python.org/es/3/library/statistics.html
