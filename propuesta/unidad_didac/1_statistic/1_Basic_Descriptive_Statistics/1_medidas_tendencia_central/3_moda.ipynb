# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/1_Basic_Descriptive_Statistics/1_medidas_tendencia_central/3_moda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# <table align="center">  <td>    <a href="https://github.dev/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/1_Basic_Descriptive_Statistics/1_medidas_tendencia_central/3_moda.ipynb" > [Edit on GitHub]

# %% [markdown]
# ## [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Video de apoyo a la lectura interactivw y experimental](https://www.youtube.com/watch?v=MgqwNdrybSk)

# %% [markdown]
# # Medidas de tendencia central - Moda

# %% [markdown]
# ## Preconceptos
#
# 1. DataFrame de Pandas
# 2. el método `value_counts()` de pandas.

# %% [markdown]
# ## Definición

# %% [markdown]
# es el dato más frecuente de una variable categórica.

# %% [markdown]
# ## Actividad práctica en Google Colab

# %%
import statistics as st

# %%
st.mode(['f', 'f', 'm'])
# Out:
# 'f'

# %%
import statistics as st

# %%
st.mode((1,1,2))
# Out:
# 1

# %% [markdown]
# $$x = $$

# %% [markdown]
# ## Referentes
