# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/1_Basic_Descriptive_Statistics/1_medidas_tendencia_central/1_media.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# # Medidas de Tendencia central- Madiana

# %% [markdown]
# ## Conceptos teóricos mínimos para realizar la práctica

# %% [markdown]
# 1. DataFrame de Pandas
# 2.

# %% [markdown]
# # Actividad práctica

# %% [markdown]
# ## Tareas de fijación de conceptos y de adquisición de habilidades

# %% [markdown]
# 1. Crea una lista con las edades de tus compañeros de clase y calcula la madiana utilizando la ibrería numpy.

# %% [markdown]
# ## Evaluación

# %% [markdown]
# ## Referentes

# %% [markdown]
# ### [Continue la secuencia de enseñanza a través de este vínculo](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/1_Basic_Descriptive_Statistics/1_medidas_tendencia_central/3_moda.ipynb)
