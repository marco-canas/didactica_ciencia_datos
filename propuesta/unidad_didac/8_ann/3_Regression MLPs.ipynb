# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/8_ann/3_Regression%20MLPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo a la lectura interactiva y experimental de esta cuaderno](https://www.youtube.com/watch?v=M28VSCll6iQ)

# %% [markdown]
# # [3_Regression MLPs](https://github.com/ageron/handson-ml3/blob/main/10_neural_nets_with_keras.ipynb)

# %% [markdown]
# First, MLPs can be used for regression tasks. If you want to predict a single value (e.g., the price of a house, given many of its features), then you just need a single output neuron: its output is the predicted value.

# %% [markdown]
# For multivariate regression (i.e., to predict multiple values at once), you need one output neuron per output dimension.

# %% [markdown]
# For example, to locate the center of an object in an image, you need to predict 2D coordinates, so you need two output neurons.

# %% [markdown]
# If you also want to place a bounding box around the object, then you need two more numbers: the width and the height of the
# object. So, you end up with four output neurons.

# %% [markdown]
# In general, when building an MLP for regression, you do not want to use any activation function for the output neurons, so they are free to output any range of values.

# %% [markdown]
# If you want to guarantee that the output will always be positive, then you can use the ReLU activation function in the output layer.

# %% [markdown]
# Alternatively, you can use the softplus activation function, which is a smooth variant of ReLU: softplus(z) = log(1 + exp(z)).

# %% [markdown]
# It is close to 0 when z is negative, and close to z when z is positive.

# %% [markdown]
# Finally, if you want to guarantee that the predictions will fall within a given range of values, then you can use the logistic function or the hyperbolic tangent, and then scale the labels to the appropriate range: 0 to 1 for the logistic function and –1 to 1 for the hyperbolic tangent.

# %% [markdown]
# The loss function to use during training is typically the mean squared error, but if you have a lot of outliers in the training set, you may prefer to use the mean absolute error instead. Alternatively, you can use the Huber loss, which is a combination of both.

# %% [markdown]
# ## TIP

# %% [markdown]
# The Huber loss is quadratic when the error is smaller than a threshold δ (typically 1) but linear when the error is larger than δ.

# %% [markdown]
# The linear part makes it less sensitive to outliers than the mean squared error, and the quadratic part allows it to converge faster and be more precise than the mean absolute error.

# %% [markdown]
# Table 10-1 summarizes the typical architecture of a regression MLP

# %% [markdown]
# tabla 10.1
# <img src = ''>

# %%
from sklearn.datasets import fetch_california_housing # importamos la función para obtener los datos
from sklearn.metrics import mean_squared_error # trajo la medida de desempeño
from sklearn.model_selection import train_test_split # divide en entrenamiento, validacion y testeo
from sklearn.neural_network import MLPRegressor # la clase para constituir un modelo de regresion
from sklearn.pipeline import make_pipeline # import la función que construye canalizaciones
from sklearn.preprocessing import StandardScaler # la clase que escala los datos 

housing = fetch_california_housing() # crea la variable housing 
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42) # dividimos en train_full y testeo
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42) # subdividimos a X_train_full en X_train y X_valid,

mlp_reg = MLPRegressor(hidden_layer_sizes=[50, 50, 50], random_state=42) # instanciando la clase MLPRegressor 
pipeline = make_pipeline(StandardScaler(), mlp_reg) # composición de operadores 
pipeline.fit(X_train, y_train) # entrena a la función pipeline con los datos de entrenamiento. 
y_pred = pipeline.predict(X_valid)
rmse = mean_squared_error(y_valid, y_pred, squared=False)

# %%
rmse
# Out:
# 0.5053326657968639

# %%
jt -t onedork -T -N -kl
# Out:
#   File "C:\Users\Marco\AppData\Local\Temp\ipykernel_16656\4033519841.py", line 1
#     jt -t onedork -T -N -kl
#           ^
# SyntaxError: invalid syntax

# %%
jt -t onedork
# Out:
#   File "C:\Users\Marco\AppData\Local\Temp\ipykernel_16656\2824949351.py", line 1
#     jt -t onedork
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Referentes
#
# * Cuaderno de Geron del capítulo 10 en GitHub: https://github.com/ageron/handson-ml3/blob/main/10_neural_nets_with_keras.ipynb
