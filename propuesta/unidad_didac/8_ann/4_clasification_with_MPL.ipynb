# %% [markdown]
# # Clasificación multiclase con una MPL

# %% [markdown]
# ## Referentes
#
# * El cuaderno en GitHub de Geron sobre el capítulo 10 de su libro Hand on Machine Learnig with sklearn, keras and tensorflow
