# %% [markdown]
# <table align="center">  <td>    <a href="https://colab.research.google.com/drive/1xP4114dTrli4O-GHYHdaYs6mmcCfPtqB#scrollTo=EfJ-1lc5nsCw"_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>  </td></table>

# %% [markdown]
# ## [Video de apoyo a la lectura de este glosario]()

# %% [markdown]
# # Glosario

# %% [markdown]
# Crearemos un glosario para propiciar el acercamiento de los lectores a los términos de la estrategia, por ahora vamos en:

# %% [markdown]
# ##  Machine Learning:

# %% [markdown]
# ## Python

# %% [markdown]
# ## Sklearn de Python

# %% [markdown]
#     GitHub de Microsoft
#
#     Colaboratory
#
#     YouTube
#
#     Kaggle de Google
#
#     Jupyter Notebook
#
#     Spyder de Anaconda
#
#     Librerías Numpy
#
#     Pandas
#
#     Matplotlib

# %% [markdown]
# ## Referentes que establecieron las definiciones que aquí se presentan
