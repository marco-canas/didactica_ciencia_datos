# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/1_datos_variables/1_str/str.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo a la lectura interactiva y experimental de este cuaderno](https://www.youtube.com/watch?v=vLQMCQSguz8)

# %% [markdown]
# ## [Vínculo al programa del curso en Machine Leaning y ciencia de datos:  ](https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/cartilla/cartilla.ipynb)

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# ## Definición y características de este [modelo](https://udearroba.udea.edu.co/blog/aprendizaje-invertido-otras-formas-de-ensenar-y-aprender/)
#
#
# El aprendizaje invertido es un enfoque pedagógico que posibilita trascender del modelo tradicional de enseñanza.

# %% [markdown]
# Dicho enfoque hace uso de entornos virtuales, en los cuales el docente dispone de una serie de recursos para abordar la enseñanza de los contenidos. Uno de los recursos más utilizados es la videoclase, pues permite que los estudiantes puedan escuchar y observar al docente mientras explica una temática, así como demostraciones y procedimientos específicos. Por tanto, este recurso resulta valioso para los estudiantes, quienes podrán revisarlo en el espacio temporal que deseen y las veces que lo consideren necesario para su aprendizaje. Adicionalmente, es importante que los docentes dispongan las indicaciones o instrucciones -por fuera del aula- en relación con las actividades/prácticas/ejercicios que los estudiantes deben llevar a cabo. Por ende, se espera que los estudiantes hagan la revisión de contenidos e indicaciones de manera previa al encuentro sincrónico.

# %% [markdown]
# ## ¿Qué es?
#
# Flipped Learning o aprendizaje invertido es un enfoque pedagógico en el que:
#
# * la instrucción directa se realiza fuera del aula y
# * se utiliza el tiempo de clase para llevar a cabo actividades que impliquen el desarrollo de procesos cognitivos de mayor complejidad, en las que son necesarias la ayuda y la experiencia del docente.

# %% [markdown]
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/atributos_aprendizaje_invertido.png?raw=true'>

# %% [markdown]
# # Proceso Flipped Learning
#
# ## Fuera del Aula
#
# ### Docente:
# * Diseña y planea el proceso de enseñanza-aprendizaje del aula, integrando estrategias, modelos de enseñanza y metodologías (aprendizaje basado en proyectos, aprendizaje cooperativo y colaborativo,…).
#
# * Diseña y planea actividades que se realizarán fuera del aula (ver vídeos, cumplimentar cuestionarios,…).
#
# * Selecciona e integra la tecnología en actividades de aprendizaje activo.
#
# * Diseña actividades de evaluación que promuevan el aprendizaje del alumnado.

# %% [markdown]
# ## Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas
#
# ### DAR DESDE EL CORAZÓN
# #### La esencia de la comunicación no violenta
#
# Lo que quiero en la vida es compasión,
# una corriente que fluya entre los demás y yo,
# basada en un mutuo dar desde el corazón.
#
# [MARSHALL ROSENBERG](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Efb_5fC50D5JnA4BzTKzgsIB9UeMjgs1kCU-sROZDlWTGw?e=gjRMdZ)

# %% [markdown]
# # Título de la clase:  El tipo de dato string

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# *

# %% [markdown]
# ## Cuestionario para realizar labores de memorización, observación y síntesis de la información (Además de diagnóstico)
#
# 1. ¿?
# 2. ¿?
# 3. ¿?
# 4. ¿?
# 5. ¿?

# %% [markdown]
# ## Establecimiento de prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.
#
# (Elabore una lista de preguntas al rededor de los conceptos que consideres necesarios para empezar la clase).
#
# 1.
# 2.
# 3.

# %% [markdown]
# # Para el diseño de la clase tenga en cuenta algunos problemas de aprendizaje

# %% [markdown]
# ## Secuencia conceptual introductoria a la clase (Se propone leer toda la secuencia conceptual antes de la clase, memorizarla y sintetizarla o reescribirla en sus palabras)

# %% [markdown]
# ## Definición
#
#
# Los datos tipo string son los que guardan el nombre de las personas a través de mensajes delimitados por comillas dobles o comillas simples.

# %% [markdown]
# ### Ejemplo 1 de string

# %%
nombre_una_joven = "Alejandra Perez Henano"

# %%
print(nombre_una_joven)
# Out:
# Alejandra Perez Henano

# %%
nombre_una_joven
# Out:
# 'Alejandra Perez Henano'

# %% [markdown]
# La función `type()`nos devuelve el tipo de variable

# %%
type(nombre_una_joven)
# Out:
# str

# %% [markdown]
# un dato de tipo str es un dato tipo string o cadena de caracteres.

# %% [markdown]
# ## Otraos ejemplo de datos tipo String

# %% [markdown]
# 1. el sexo

# %%
sexo = 'masculino'

# %%
sexo_2 = "femenino"

# %% [markdown]
# Los datos tipo string son para variables categóricas, como la variable sexo que es una variables categórica binaria no ordinal.

# %% [markdown]
# Aunque hay varoiables categóricas ordinales como el estrato social que no se describe ususlamnete con string sino con enteros.

# %% [markdown]
# ## Mapa conceptual de la clase elaborado en CMapTools
#
# <img src = ''>

# %% [markdown]
# ## Tareas para realizar antes de la clase
# 1. Ver los videos respectivos []()
# 2. Memorizar las definiciones []()
# 3. Sintetizar o resumir la información en mapas conceptuales. []()
# 4. Tareas para incentivar el uso de la calculadora Casio Para ingenieros y licenciados.

# %% [markdown]
# # Tareas de fijación de conceptos y adquisición de habilidades

# %% [markdown]
# 1. cree una cadena de caracteres cpon su nombre completo
# 2. cree un string con sus apellidos.
# 3. Haga el proceso de pasar toda la cadena de minúsculas a mayúsculas.

# %% [markdown]
# ## Solución

# %%
nombre = 'Marco Julio'

# %%
apellidos = "Cañas Campillo"

# %%
nombre.lower() #
# Out:
# 'marco julio'

# %%
nombre.upper()
# Out:
# 'MARCO JULIO'

# %% [markdown]
# **Conclusion:**
#
# Los datos tipo string son datos que tienen asociados métodos y atributos para que el científico de datos pueda manipularlos a su antojo.

# %% [markdown]
# ## [Evaluación ]()

# %% [markdown]
# 1. cre una cadena de caracteres y cambie una de las letras por otra utilizandpo la función `replace()` letra por otra diferentes

# %% [markdown]
# ## Solución

# %%
otro_nombre = 'adriana'

# %%
otro_nombre.replace('a', 'h')
# Out:
# 'hdrihnh'

# %%
nombre.capitalize()
# Out:
# 'Marco julio'

# %%
nombre.count('o')
# Out:
# 2

# %%
import numpy as np 
edades = np.array([48, 24])

# %%
edades.mean()
# Out:
# 36.0

# %% [markdown]
# ## Referencias
#
# * [Geron, Aurelien]()
#
# * [Geron, Aurelien. GitHub]()
#
# * [La función replace de Python para cadenas de caracteres](https://parzibyte.me/blog/2022/07/18/python-reemplazar-una-letra-por-otra/)

# %% [markdown]
# Para a la siguiente clase sobre tipos de datos donde veremos los datos tipo int, para ello pulse [aquí](https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/1_datos_variables/2_int/int.ipynb)
