# %% [markdown]
# <table align="center">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/0_jugar_python/0_install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Cómo aprender python desde la aplicación en línea Replit

# %% [markdown]
# ## Agenda
#
# 1. Registrarse en la aplicación en línea [replit](https://replit.com/) a través de su correo de Google
# 2. Instalar OBS para grabar videos para dibulgación científica.

# %% [markdown]
# ## Imagen de la aplicación en línea replit
#
# <img src = 'https://github.com/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/0_jugar_python/replit.png?raw=true'>

# %% [markdown]
# <img src = ''>

# %% [markdown]
# ## [Video de apoyo a la lectura de este cuaderno](https://www.youtube.com/watch?v=TuHs_KR0PxU)

# %% [markdown]
# # Instalación de OBS para grabación de videos de divulgación científica
