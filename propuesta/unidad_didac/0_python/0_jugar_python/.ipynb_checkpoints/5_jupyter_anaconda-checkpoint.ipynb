# %% [markdown]
# <table align="center">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/0_jugar_python/0_install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo a la lectura de este cuaderno](https://www.youtube.com/watch?v=nNnSl1YXc4E)

# %% [markdown]
# # Introducción a Jupyter de Anaconda
#
# <img src = 'https://i.pinimg.com/originals/64/2b/4a/642b4a4eb254da80899e5700633aa789.jpg'>

# %% [markdown]
# 1. www.anaconda.org
# 2. Ir a descargas
# 3. abrir la aplicación web Jupyter.
# 4. Crear un nuevo cuaderno .ipynb

# %% [markdown]
# ## Referentes

# %% [markdown]
# [Continue su aprendizaje en el cuaderno siguiente sobre GitBash]()
