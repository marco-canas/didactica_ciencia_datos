# %% [markdown]
# <table align="center">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/0_jugar_python/0_install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # [Lista de repreducción para orientar la introducción al uso de python para ciencia de datos](https://www.youtube.com/watch?v=poYW_S10wkg&list=PLbk60veMSVKu-ApVm9vg3hh-n2VXGoduk)

# %% [markdown]
# ## [Cinco formas de trabajar con el lenguaje Python. Cinco interpretes](https://www.youtube.com/watch?v=wQjhQOwnFqk)

# %% [markdown]
# 1. Espacio de trabajo online
#    - Google Colab o Colaboratory
#    - Replit
#
# 2. Espacio de trabajo en local
#    - Anaconda: Jupyter
#    - IDLE de Python: (https://www.python.org/)
#    - La terminal del computador: Window PowerShell. Este camino sólo funciona después de instalar python de su página oficial: https://www.python.org/

# %% [markdown]
# # Instalación de GitBash

# %% [markdown]
# # Instalación de Visual Studio Code

# %% [markdown]
# ## Trabajar desde la terminal las operaciones matemáticas básicas con python

# %% [markdown]
# ## Referentes
#
# * www.python.org: https://www.python.org/

# %% [markdown]
# [Continue su aprendizaje desarrollando su pensamiento algoritmico con la aplicación lightbot](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/0_jugar_python/1_lightbot.ipynb)
