# %% [markdown]
# <table align="center">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/0_jugar_python/0_install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo a la lectura interactiva y experimental de este cuaderno](https://www.youtube.com/watch?v=BFMrhLiDgcg)

# %% [markdown]
# # Introducción al uso de Google Colab para ciencia de datos

# %% [markdown]
# <img src = 'https://miro.medium.com/max/1100/1*S2AyJcdw8EPcn7gwDVSBCA.webp'>
