# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/0_jugar_python/0_install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # [Video de apoyo a la lectura experimental e interactiva de este cuaderno]()

# %% [markdown]
# Después de instalar Python y empezar la labor de desarrollo del pensamiento algoritmico, seguiremos con aprender a programar utilizando Turtle de Python. Es decir, aprenderemos a programar jugando.

# %% [markdown]
# # Aprende a programar creando por primera vez un Juego

# %% [markdown]
# ## Prerrequisitos
#
# * Declarar funciones
# * Bucles o controladores de flujo (Cliclo for, ciclo while, ciclo condicional)
# * listas de python

# %% [markdown]
# ### Datos
# * tipo int
# * tipo float
# * tipo str

# %%
edad_mi_hijo = 13  # crear variables la sintaxis es: nombre_variable + operador de asignación (=) + dato 
estatura_mi_hijo = 1.66
nombre_de_mi_hijo = "joseph"

# %%
type(edad_mi_hijo) 
type(estatura_mi_hijo)
type(nombre_de_mi_hijo)
# Out:
# str

# %% [markdown]
# ### Estructuras de datos
#
# * listas
# * tuplas
# * diccionarios

# %%
type({})
# Out:
# dict

# %%
informacion_de_mi_hijo = {'nombre de mi hijo': nombre_de_mi_hijo, 'edad de mi hijo': edad_mi_hijo, 'estatura de mi hijo': estatura_mi_hijo}

# %%
informacion_de_mi_hijo
# Out:
# {'nombre de mi hijo': 'joseph',
#  'edad de mi hijo': 13,
#  'estatura de mi hijo': 1.66}

# %% [markdown]
# Podemos introducir los conceptos de tipos de datos, estructuraras de datos, creación de variables, algoritmo, con la excusa de creaar un juego como el de la Serpiente que busca su alimento.

# %% [markdown]
# ¿Para crear un juego cómo se inicia Joseph?

# %%
# Importando el módulo Turtle 

import turtle

# %% [markdown]
# Turtle es

# %% [markdown]
# ## Referentes
# * Cesar. Canal: *Mundo Python*:
# * YouDevs: https://www.youtube.com/watch?v=bW0o4g4cg1g&t=8s
# * Graficos con Turtle: https://docs.python.org/es/3.9/library/turtle.html
