# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/3_funciones/1_functions_with_sentence_def.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso de Machine Learning en la UdeA:  ](https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/cartilla/cartilla.ipynb)

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)
#
# ## Definición y características de este modelo

# %% [markdown]
# ## ¿Qué es?
#
# Flipped Learning o aprendizaje invertido es un enfoque pedagógico en el que:
#
# * la instrucción directa se realiza fuera del aula y
# * se utiliza el tiempo de clase para llevar a cabo actividades que impliquen el desarrollo de procesos cognitivos de mayor complejidad, en las que son necesarias la ayuda y la experiencia del docente.

# %% [markdown]
# ## ¿Para qué sirve?
#
# Mejora el proceso de enseñanza-aprendizaje realizando,
#
# * **fuera del aula**, actividades de aprendizaje sencillas (observar, memorizar, resumir, etc.) y,
# * **en el aula**, actividades más complejas (razonar, examinar, priorizar, argumentar, proponer, etc.) que requieren la interacción entre iguales y la ayuda del docente como facilitador.

# %% [markdown]
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/atributos_aprendizaje_invertido.png?raw=true'>

# %% [markdown]
# # Proceso Flipped Learning

# %% [markdown]
# ## Fuera del Aula

# %% [markdown]
# ### Docente:

# %% [markdown]
# * Diseña y planea el proceso de enseñanza-aprendizaje del aula, integrando estrategias, modelos de enseñanza y metodologías (aprendizaje basado en proyectos, aprendizaje cooperativo y colaborativo,…).
#
# * Diseña y planea actividades que se realizarán fuera del aula (ver vídeos, tareas de completación de cuestionarios,…).
#
# * Selecciona e integra la tecnología en actividades de aprendizaje activo.
#
# * Diseña actividades de evaluación que promuevan el aprendizaje del alumnado.

# %% [markdown]
# ### Alumnado:

# %% [markdown]
# * Accede, cuantas veces necesite, a las actividades facilitadas por el profesorado.
# * Realiza las actividades propuestas.

# %% [markdown]
# ## En el Aula

# %% [markdown]
# ### Docente:

# %% [markdown]
# * Guía y facilita los procesos de aprendizaje, atendiendo a la diversidad.
# * Retroalimenta el desempeño de los equipos/grupos y del alumnado individualmente.
# * Genera espacios para la coevaluación y autoevaluación.

# %% [markdown]
# ### Alumnado:

# %% [markdown]
# * Realiza las actividades (debates, exposiciones orales, informes, diario de aprendizaje, cuaderno de trabajo cooperativo,…).
# * Recibe retroalimentación inmediata del profesorado y de sus compañeros y compañeras.
# * Accede, si fuera necesario, a las actividades previas facilitadas por el profesorado.

# %% [markdown]
# ## Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas
#
# John Allen Paulos. El hombre anumérico. El analfabetismo matemático y sus consecuencias.
#
# "Las mates siempre fueron mi asignatura más floja."
#
# <<Un millón de dólares, mil millones o un billón. No importa cuánto siempre y cuando hagamos algo por resolver el problema.>>
#
# << Jerry y yo no iremos a Europa, con tantos terroristas...>>
#
# El anumerismo, o incapacidad de menejar cómodamente los conceptos fundamentales de número y azar, atormenta a demasiados ciudadanos que, por lo demás, pueden ser perfectamente instruidos.

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# * Aprender a crear funciones de usuario de Python a través de la sentencia `def`.

# %% [markdown]
# ## Establecimiento de prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.
#
# (Elabore una lista de preguntas al rededor de los conceptos que consideres necesarios para empezar la clase).
#
# 1. ¿Qué es una función matemática?
# 2. ¿Cómo podemos interpretar una función como una máquina?
# 3. ¿Qué es el desarrollo creciente de una función de usuario de Python?

# %% [markdown]
# # Para el diseño de la clase tenga en cuenta algunos problemas de aprendizaje

# %% [markdown]
# * Diferenciar entre definir una función y llamar a la misma

# %% [markdown]
# # Secuencia conceptual introductoria al tema de funciones de Python

# %% [markdown]
# ### Contenido
#
# 1. Definir el concepto de función en Python
# 2. Tipos de funciones en Python
# 3. Definición y estructura de una función en Python
# 4. llamado a una función
# 5. ejemplos de funciones
# 6. Los argumentos de las funciones en Python.
# 7. La sentencia return en Python
# 8. Funciones de la librería standar de python.
# 9. Beneficios del uso de las funciones de Python

# %% [markdown]
# ## Mapa conceptual elaborado en CMapTools

# %% [markdown]
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/3_funciones/python%20functions.jpeg?raw=true'>

# %% [markdown]
# ## Python functions

# %% [markdown]
# A function is a block of code that performs a specific task.
#
# Suppose, you need to create a program to create a circle and color it. You can create two functions to solve this problem:
#
# * create a circle function
# * create a color function

# %% [markdown]
# Dividing a complex problem into smaller chunks makes our program easy to understand and reuse.

# %% [markdown]
# Dividir un problema complejo en partes más pequeñas hace que nuestro programa sea fácil de entender y reutilizar.

# %% [markdown]
# ## Types of function

# %% [markdown]
# There are two types of function in Python programming:
#
# * **Standard library functions** - These are built-in functions in Python that are available to use.
# * **User-defined functions** - We can create our own functions based on our requirements.

# %% [markdown]
# Python Function Declaration
#
# The syntax to declare a function is:
#
# ```python
# def function_name(arguments):
#     # function body
#
#     return
# ```

# %% [markdown]
# Here,
# * `def` - keyword used to declare a function
# * `function_name` - any name given to the function
# * `arguments` - any value passed to function
# * `return` (optional) - returns value from a function

# %% [markdown]
# Let's see an example,

# %%
def greet():
    print('Hello World!')

# %% [markdown]
# Here, we have created a function named `greet()`. It simply prints the text Hello World!.

# %% [markdown]
# This function doesn't have any arguments and doesn't return any values. We will learn about arguments and return statements later in this tutorial.

# %% [markdown]
# ## Calling a Function in Python
#
# In the above example, we have declared a function named `greet()`.

# %%
def greet():
    print('Hello World!')

# %% [markdown]
# # Emulación o práctica de codificación

# %%
def greet():
    print("Hello World!")

# %%
greet()
# Out:
# Hello World!

# %% [markdown]
# Now, to use this function, we need to call it.

# %% [markdown]
# Here's how we can call the greet() function in Python.

# %%
# call the function
greet()
# Out:
# Hello World!

# %% [markdown]
# # Python Function Arguments
#
# As mentioned earlier, a function can also have arguments. An argument is a value that is accepted by a function. For example,

# %% [markdown]
# ```python
# # function with two arguments
# def add_numbers(num1, num2):
#     sum = num1 + num2
#     print('Sum: ',sum)
#
# # function with no argument
# def add_numbers():
#     # code
# ```

# %% [markdown]
# If we create a function with arguments, we need to pass the corresponding values while calling them. For example,

# %%
def add_numbers_with_arguments(num_1, num_2):
    sum = num_1 + num_2
    print("La suma es: ", sum)
    
def add_numbers_without_arguments():
    print("Sumar es una operación importante")

# %%
add_numbers_with_arguments(1,2)
# Out:
# La suma es:  3

# %%
add_numbers_without_arguments()
# Out:
# Sumar es una operación importante

# %% [markdown]
# Here, `add_numbers_with_arguments(5, 4)` specifies that arguments `num1` and `num2` will get values 5 and 4 respectively.

# %% [markdown]
# ## Example 1: Python Function Arguments

# %%
# function with two arguments
def add_numbers(num1, num2):
    sum = num1 + num2
    print("Sum: ",sum)

# function call with two values
add_numbers(5, 4)

# Output: Sum: 9
# Out:
# Sum:  9

# %% [markdown]
# We can also call the function by mentioning **the argument name** as:

# %%
add_numbers(num1 = 5, num2 = 4)
# Out:
# Sum:  9

# %% [markdown]
# In Python, we call it Keyword Argument (or named argument). The code above is equivalent to

# %%
add_numbers(5, 4)
# Out:
# Sum:  9

# %% [markdown]
# # The return Statement in Python
#
# A Python function may or may not return a value. If we want our function to return some value to a function call, we use the return statement. For example,

# %%
def add_numbers():
    ...
    return sum

# %% [markdown]
# Here, we are returning the variable sum to the function call.
#
# ### Note:
#
# The return statement also denotes that the function has ended. Any code after return is not executed.

# %% [markdown]
# # Example 2: Function return Type

# %%
# function definition
def find_square(num):
    result = num * num
    return result

# function call
square = find_square(3)

print('Square:', square)

# Output: Square: 9
# Out:
# Square: 9

# %% [markdown]
# In the above example, we have created a function named find_square(). The function accepts a number and returns the square of the number.
#
# <img src = 'https://www.programiz.com/sites/tutorial2program/files/function-return-value-python.png'>

# %% [markdown]
# Benefits of Using Functions
#
# 1. Code Reusable - We can use the same function multiple times in our program which makes our code reusable. For example,

# %%
# function definition
def get_square(num):
    return num * num

for i in [1,2,3, 4]:
    # function call
    result = get_square(i)
    print('Square of',i, '=',result)
# Out:
# Square of 1 = 1
# Square of 2 = 4
# Square of 3 = 9
# Square of 4 = 16

# %% [markdown]
# ## Tareas para realizar antes de la clase

# %% [markdown]
# 1. Ver los videos respectivos []()
# 2. Memorizar las definiciones [definición de función de python](https://udeaeduco-my.sharepoint.com/:u:/g/personal/marco_canas_udea_edu_co/Ee7IA-nYgcBBrvoPuB-x9B4BjVv9sHdQw832Dbt1i3TwXg?e=QbhRl1)
# 3. Sintetizar o resumir la información en mapas conceptuales. [](https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/3_funciones/python%20functions.jpeg?raw=true)

# %% [markdown]
# # Tareas para realizar en clase

# %% [markdown]
# * Modelación matemática
#   - Cree una función que calcule el promedio de un conjunto de datos numéricos de una variable cuantitativa continua.
#
#
# * Trabajo en equipos
#   - cree una función que calcule el coeficiente de correlación de Pearson entre dos variables cuantitativas continuas creadas artificialmente a través de numpy.random.

# %% [markdown]
# # Tareas para realizar después de la realización de la clase

# %% [markdown]
# * Actividades de memorización:
#   - escucha reiterada de grabaciones de fórmulas y resultados científicos.
#   - relectura de notas.
#   - ejercicios de mayor complejidad.
#   - construir funciones para selección de atributos predictores mejor correlacionados con la variable objetivo

# %% [markdown]
# ## Dificultades de aprendizaje detectados durante la clase

# %% [markdown]
# * Definición de variables y llamado de valores asociados a una variable previamente definida.

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# * Utilizar la tecla ctrl + shift + seleccionar con el click izquierdo del mouse y luego cambiar una de los nombres de la función y verá como se cambian los nombres en todas las partes señaladas.

# %% [markdown]
# ## Cuestionario para realizar labores de memorización y observación,  a la síntesis de la información

# %% [markdown]
# 1. Cómo se definen variables en Python
# 2. Cómo se llaman variables

# %% [markdown]
# ## Grabaciones en audio para fomentar la capacidad de memorizar enunciados de teoremas y resultados científicos y la capacidad de parafrasear estos resultados.

# %% [markdown]
# Se dispondrá de un lugar en el drive asociuado al correo institucional de la Universidad Nacional del Profesor Marso para albergar los archivosd de audio de fomento a la memoirización, enunciación y parafraseo de los resultados científicos, prtopiedades, reglas, etc.
#
# * Vocaroo

# %% [markdown]
# ### Comparta sus cuadernos y videos, evidencias de su aprendizaje [aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUMEMwTEZVMzEwVVBPTElWNVg5OVEyWUhMUy4u)
#
# o a través del correo marco.canas@udea.edu.co

# %% [markdown]
# # Vocabulary

# %% [markdown]
# * function
# * return
# * definition
# * square
# * root
# * square root

# %% [markdown]
# ## Quiz de 5 minutos para ejercitación y adquisición de habilidades

# %% [markdown]
# 1. Crear una función que reste dos números
# 2. Crear una función que duplique números.

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [stewart precálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ERHIq62I6qFNrmxy6LZb8ZMBci7kUsyNME1nIh9yCBMJ_w?e=0zMSla)
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
# * [uzcategui](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ETDikm-lVl1Or8XoEo9oyh0BEti9Zs8le-f0D-dBdtZmbA?e=bBsoyQ)
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [Programiz](https://www.programiz.com/python-programming/function)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo](https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/4_control_de_flujo/1_if.ipynb)

# %% [markdown]
# # Conjeturas pedagógicas fruto de la aplicación del modelo de aprendizaje invertido y del enfoque hacia la ciencia de datos con python
#
# 1. Todo cálculo o resultado debe ser interpretado en una línea markdown del cuaderno Jupyter, inmediatamente después de la enunciación del resultado y después de la presentación de una tabla o gráfico bidimensional, de tal menera que el estudiante explicite la comprensión verbal del resultado y las inferencias o estrategias que este resultado le sugieren.

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado.
#
# Y a mi esposa Yasmira por su apoyo, orientación y acompañamiento.
