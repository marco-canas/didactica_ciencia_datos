# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/congreso_entornos_aprendizaje_innovadores/entorno_aprendizaje_june_6_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Enseñar Machine Learning en la Universidad de Antioquia con Google Colab, GitHub y YouTube

# %% [markdown]
# Lopez Nohava, Luz Mariela -(Bibliotecóloga y coordinadora de la Biblioteca e investigadora de la Seccional Bajo Cauca - Caucasia)
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/congreso_entornos_aprendizaje_innovadores/mariela_leyendo.jpg?raw=true' width = 300>

# %% [markdown]
# ## Cañas Campillo, Marco Julio Magister en Ciencias Matemáticas
# ### Institución: Universidad de Antioquia
# #### Caucasia, Colombia

# %% [markdown]
# El coloquio de Machine Learning y didáctica de la matemática Universitaria con Python y Latex.  Liderado por el profesor Yuber Hernany tapias Arboleda
#
# Licenciado en Matemáticas Básicas
#
# Magister en Matemáticas de la Universidad de Antioquia
#
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/congreso_entornos_aprendizaje_innovadores/yuber_lina_jas_y_yo.jpg?raw=true' width = 500>

# %% [markdown]
#  # Enseñanza online:
#   - Cartilla diseñada para la enseñanza del Machine Learning en la Universidad de Antioquia.

# %% [markdown]
#  - Enfoque pedagógico de aprendizaje invertido en la enseñanza del machine learning.
#
#   <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/congreso_entornos_aprendizaje_innovadores/aprendizaje_invertido.png?raw=true' width = 600>

# %% [markdown]
#   - Uso del lenguaje de programación Python para la constitución de modelos predictivos.
#
#   <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/congreso_entornos_aprendizaje_innovadores/python.jpeg?raw=true' width = 600>
#
#   - Combinación de teoría y aplicación práctica a través de la vinculación de  - [GitHub](https://github.com/marco-canas/7_didactica_ciencia_datos/tree/main/propuesta/unidad_didac) - [YouTube](https://www.youtube.com/watch?v=vLQMCQSguz8) y [Google Colab](https://colab.research.google.com/drive/1hAwfTPBnpv89r2JkWjG6EDH_ESaoS-sm)/watch?v=vLQMCQSguz8), que permiten la lectura experimental e interactiva.

# %% [markdown]
#
#
# # Secuencia metodológica:
#   - Introducción a [Python](https://github.com/marco-canas/7_didactica_ciencia_datos/tree/main/propuesta/unidad_didac/0_python).
#   - [Estadística](https://github.com/marco-canas/7_didactica_ciencia_datos/tree/main/propuesta/unidad_didac/1_statistic) para ciencia de datos.
#   - [Regresión](https://github.com/marco-canas/7_didactica_ciencia_datos/tree/main/propuesta/unidad_didac/2_regresion).
#   - [Clasificación](https://github.com/marco-canas/7_didactica_ciencia_datos/tree/main/propuesta/unidad_didac/3_clasificacion).
#
#    <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/congreso_entornos_aprendizaje_innovadores/machine_learning_python_regresion_clasificacion.jpg?raw=true' width = 600>

# %% [markdown]
# - Resultados de aprendizaje para los estudiantes:
#   - adquirieron habilidades de codificación y memoria muscular y comprensiva de las las funciones de python necesarias para el machine learning.
#   - habilidades para la Obtención de datasets públicos y didácticos en [Kaggle](https://www.kaggle.com/).
#   - Construcción de modelos predictivos de machine learning.
#   - Justificación de la configuración de los modelos.
#   - Presentación de los modelos y sus resultados.

# %% [markdown]
# # Conclusiones:
#   - El enfoque pedagógico de aprendizaje invertido es efectivo en la enseñanza del machine learning.
#   - Uso de herramientas tecnológicas como Google Colab, GitHub, YouTube y Kaggle.
#   - Resultados significativos en el desarrollo de habilidades y conocimientos en técnicas de Machine Learning.

# %% [markdown]
# # Referentes

# %% [markdown]
# * Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.[Geron, Aurelien. Hands on Machine Learning](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Ecet27yjQzZIlT1Y_Bc2erkBUhbeYuIe6HG8i1FYZRlZww?e=dlvZ4v)
#
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/congreso_entornos_aprendizaje_innovadores/hands_on_machine_learning.jpeg?raw=true' width = 400>
#
# Enfoque práctico de la enseñanza del Machine Learning

# %% [markdown]
# * [Fórmulas más comunes en latex](https://wiki.geogebra.org/es/C%C3%B3digo_LaTeX_para_las_f%C3%B3rmulas_m%C3%A1s_comunes)

# %% [markdown]
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)

# %% [markdown]
# * [chatGPT](https://openai.com/blog/chatgpt)

# %% [markdown]
# * McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".[Wes Mackinney. ](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EVbi5JIeBl9ErbiUnZfGe8YBhNTnZ8sxTK5hjIOPK4UpGw?e=fFclah)
