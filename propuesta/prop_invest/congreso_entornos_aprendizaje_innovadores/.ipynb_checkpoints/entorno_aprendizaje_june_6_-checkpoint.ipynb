# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/congreso_internacional_entornos_aprendizaje_innovadores/ponencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Enseñar Machine Learning en la Universidad de Antioquia con Google Colab, GitHub y YouTube
# ## Lopez Nohava, Luz Mariela - Cañas Campillo, Marco Julio
# ### Institución: Universidad de Antioquia
# #### Caucasia, Colombia

# %% [markdown]
# # Resumen:
#   - Enfoque pedagógico de aprendizaje invertido en la enseñanza del machine learning.
#   - Uso del lenguaje de programación Python para la constitución de modelos predictivos.
#   - Combinación de teoría y aplicación práctica a través de la vinculación de Google Colab - GitHub y YouTube, que permiten la lectura experimental e interactiva.

# %% [markdown]
#
#
# Diapositiva 3:
# - Secuencia metodológica:
#   - Introducción a Python.
#   - Estadística para ciencia de datos.
#   - Regresión.
#   - Clasificación.

# %% [markdown]
# Diapositiva 4:
# - Resultados de la estrategia didáctica:
#   - Desarrollo de habilidades para obtener datasets asociados a problemas investigativos o empresariales.
#   - Constitución de modelos predictivos de machine learning para regresión o clasificación.
#   - Justificación de la configuración de los modelos.
#   - Presentación del proceso de construcción del modelo, interpretación de las predicciones y limitaciones/potencialidades.

# %% [markdown]
# Diapositiva 5:
# - Acceso a los contenidos del curso:
#   - Repositorio en GitHub: https://github.com/marco-canas/7_didactica_ciencia_datos/tree/main/propuesta/unidad_didac.
#   - Utilización de cuadernos Jupyter interactivos en Google Colab.

# %% [markdown]
# Diapositiva 6:
# - Uso de herramientas tecnológicas:
#   - Google Colab: plataforma para la enseñanza en línea.
#   - GitHub: repositorio de materiales y recursos del curso.
#   - YouTube: videos asociados a los cuadernos Jupyter para reforzar los temas tratados.

# %% [markdown]
# Diapositiva 7:
# - Metodología:
#   1. Introducción a Python para ciencia de datos.
#   2. Estadística para ciencia de datos.
#   3. Modelos de regresión para variables numéricas continuas.
#   4. Modelos de clasificación para variables categóricas.

# %% [markdown]
# Diapositiva 8:
# - Resultados de aprendizaje para los estudiantes:
#   - Obtención de datasets asociados a problemas investigativos o empresariales.
#   - Construcción de modelos predictivos de machine learning.
#   - Justificación de la configuración de los modelos.
#   - Presentación de los modelos y sus resultados.

# %% [markdown]
# Diapositiva 9:
# - Enseñanza online:
#   - Cartilla diseñada para la enseñanza del Machine Learning en la Universidad de Antioquia.

# %% [markdown]
# Diapositiva 10:
# - Conclusiones:
#   - El enfoque pedagógico de aprendizaje invertido es efectivo en la enseñanza del machine learning.
#   - Uso de herramientas tecnológicas como Google Colab, GitHub y YouTube.
#   - Resultados significativos en el desarrollo de habilidades y conocimientos en los estudiantes.

# %% [markdown]
# # Referentes
#
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [Fórmulas más comunes en latex](https://wiki.geogebra.org/es/C%C3%B3digo_LaTeX_para_las_f%C3%B3rmulas_m%C3%A1s_comunes)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.[Geron, Aurelien. Hands on Machine Learning](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Ecet27yjQzZIlT1Y_Bc2erkBUhbeYuIe6HG8i1FYZRlZww?e=dlvZ4v)
#
# * McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".[Wes Mackinney. ](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EVbi5JIeBl9ErbiUnZfGe8YBhNTnZ8sxTK5hjIOPK4UpGw?e=fFclah)
