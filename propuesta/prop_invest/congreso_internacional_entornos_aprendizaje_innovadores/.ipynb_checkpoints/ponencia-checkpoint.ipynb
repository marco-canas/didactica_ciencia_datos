# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/congreso_educaci_superior_u_sucre/ponencia_u_sucre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Lista de reproducción de preparación de ponencia en Uni Sucre](https://www.youtube.com/watch?v=qw820UChN-w&t=195s)

# %% [markdown]
# # Ponencia para Uni Sucre

# %% [markdown]
# # IV Encuentro Internacional de Investigación e Innovación en Educación Matemática EII+ED+MAT

# %% [markdown]
# ## Términos de referencia

# %% [markdown]
# Se aceptan trabajos derivados de
#
# * proyectos de investigación en curso o terminados
# * experiencias didácticas y
# * reflexiones teórico prácticas.

# %% [markdown]
# 2. Los participantes pueden hacer su intervención como asistente o ponente de trabajo.

# %% [markdown]
# 3. Los participantes que postulen trabajos deben seleccionar
#
#    * la modalidad en que desean participar y
#    * preparar el documento en la plantilla respectiva y atendiendo las orientaciones dadas.

# %% [markdown]
# 4. Las líneas temáticas para los ponentes (comunicaciones breves, talleres, poster y experiencias
# pedagógicas en matemáticas) deben estar acordes a los siguientes ejes:
#
#     * Eje 2: Estrategias, tecnologías y materiales de enseñanza y el desarrollo del pensamiento matemático, para nuestro caso el desarrollo del pensamiento computacional.
#     * Eje 4: Educación por Competencias y resolución de problemas
#     * Eje 5: Tendencias y prospectivas en la educación matemática
# Eje 6: Reflexiones sobre las perspectivas teóricas en educación matemática
# Eje 7: Enseñanza de las matemáticas, formación ciudadana y cultura
# Eje 8: Didácticas específicas de cada pensamiento (variacional, numérico, aleatorio,
# geométrico y espacial)
# Eje 9: Didáctica de las matemáticas en la educación primaria
# Eje 10: Investigación en Educación Matemática

# %% [markdown]
# ## Referencias
#
# * Uni Sucre: https://www.unisucre.edu.co/eiiem/
