# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/1_Basic_Descriptive_Statistics/1_medidas_tendencia_central/1_media.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# [para subir la propuesta de clic aquí](https://forms.office.com/pages/responsepage.aspx?id=IefhmYRxjkmK_7KtTlPBwsCcR061nZ5Ns9xEgSS2Lt9UMDE5U1Y4QU45RDc1RkZCTkpWTThPVEZLOC4u)

# %% [markdown]
# [Promoción de la convocatoria de virtualización de cursos](https://www.udea.edu.co/wps/portal/udea/web/generales/interna/!ut/p/z1/1ZTLctowFIZfBRZZenQ1NkvhuCbmYgwhxNp0hC0atWATWzhpnr7ywLS5Ae2kXVQb64y-c_ulY8DBLeC5qNUXoVWRi7WxE9757HY9jBiFw2AaepB1POY7s5shdjFYvATgANmQxf5kfB15k8sQA26Ox7HtI-wZfxtTGIcUDS4ZgTNCD_7wyGLw9_xPAPx0_TeAA57meqvvQLItSi3Wu0yKCyiql9ZdsZH7vXzUMq-MPj-37ZS0lyRvyby1Fq09lRZ5XaRCF6USVesVuMtVLctKaWFOm-iGNoDKisbIZKVFKrKiuoC1KvVOrNWTSE1G3FS7TVUGEkS6hkmptXLh0qLOElluJ82sbkd2qXSxg1bL17fztn1-WvxFk--5vlHf_QTj4Jr2KWV9l9H3ATgd9YLYRz613wBXxIdxd2xPSHCFqUMOwKkndK7MxLTpHG0zQmBRK_kA5nlRbsyjnv2hiv1zGSj8YIZ9-F8aQWw0inphMBwhGHn4r4Q_Wj36p-EHH60-PDfD5ielvt7fc2YmuZmjRw1u_4NR3m7m8_nGJd-tb1N_NfIJTcL6qTe2Dh-esPYPzabWWw!!/dz/d5/L2dBISEvZ0FBIS9nQSEh/?page=udea.generales.interna&urile=wcm:path:/PortalUdeA/asPortalUdeA/asHomeUdeA/Extension/Extensi%2521c3%2521b3n%2Ben%2Bla%2BUdeA/Convocatorias%2Bextensi%2521c3%2521b3n%2Buniversitaria/asContenido/asDestacados/virtualizacion2#ConvocatoriasUdeA%20%C3%B0%C2%9F%C2%92%C2%A1%20%C2%A1Apost%C3%83%C2%A9mosle%20a%20la%20educaci%C3%83%C2%B3n%20virtual%21&utm_source=MasterBase%20UDEA2COMCO&utm_medium=email&utm_content=2&utm_term=none)

# %% [markdown]
# ## [Video de apoyo a la difusión de esta propuesta de virtualización](https://www.youtube.com/watch?v=K4se0rWBoIs)

# %% [markdown]
# # Propuesta de virtualización de curso: Introducción al machine learning y a la ciencia de datos con Python

# %% [markdown]
# Todas las propuestas deben incluir la siguiente información:

# %% [markdown]
# * Nombre de la actividad o programa de educación continua a virtualizar:
#
#   - *Curso de introducción al Machine Learning y a la ciencia de datos con Python*

# %% [markdown]
# ## Tipo de actividad (curso corto o ruta de aprendizaje que lleve a la certificación de cursos, talleres y diplomas)
#
# Curso de un solo módulo de tecnicas de Machine Learning.

# %% [markdown]
# ## Duración de la actividad o actividades en horas (especificar si es un curso de 16 horas o una ruta de aprendizaje)
#
# Es un curso de 16 horas donde se forma a los estudiantes e investigadores en tecnicas de Machine Learning y ciencia de datos con Python.

# %% [markdown]
# # Descripción de la actividad, que debe incluir:
#    * Pertinencia académica y social del programa
#    * Justificación de la necesidad de virtualizar la actividad

# %% [markdown]
# En cuanto a la pertinencia académica de virtualizar este curso de machine learning tenemos que:
#
# * En la actualidad es necesario automatizar la toma de decisiones y el análisis de datos para evitar riesgos en las empresas tanto privadas como públicas.
#
# * Las metodologías en análisis de datos se pueden aprender a través de videos cortos que ejemplifiquen la manera de procesar la información con Python y de constituir modelos predictivos de machine learning con skilearn. Esto si los videos están apoyando unos diseños de contenidos a través de cuaderno jupyter para lectura interactiva y experimental y a los cuales el estudiante tiene libre acceso a través de la red social GitHub y vínculo o asociación con la aplicación en línea Google Colab (Colaboratory). Esta aplicación en línea permite ejecutar código python en computadores en línea y de manera gratuita son tener que descargar ningún software.

# %% [markdown]
# <img src = 'https://miro.medium.com/v2/resize:fit:720/1*mM0p_SF47QA74232hkjjNw.png'>

# %% [markdown]
# Virtualizar el curso de machine learning permite a las personas acceder a cualquier hora del día a su proceso de formación en ciencia de datos y requiere de un componente inicial muy práctico para la adquisición de metodología de análisis de datos y de codificación en lenguaje Python para esta actividad.
#
# Y en la actualidad, el análisis de datos con técnicas de machine learning a través del lenguaje gratuito que es Python, se ha vuelto de gran necesidad diaria en múltiples campos del saber y de la vida cotidiana.

# %% [markdown]
# ## Objetivos de la actividad de formación

# %% [markdown]
# * Adquirir habilidades de procesamiento de datos y constitución de modelos predictivos a través del lenguaje gratuito Python.
#
# * Formar a investigadores y personas vinculadas con la empresa privada en el análisis de datos y toma de decisiones a través de técnicas de Machine learning aplicadas con lenguaje de programación Python.

# %% [markdown]
# ## Público objetivo

# %% [markdown]
# Estudiantes de pregrado de la Universidad de Antioquia y público en general de Colombia y el mundo, del sector privado interesado en aprender técnicas de machine learning y de ciencia de datos con Python para convertirse en científicos de datos.

# %% [markdown]
# ## Contenidos (módulos y/o temas)

# %% [markdown]
# 1.	Introducción al lenguaje Python para ciencia de datos: tipos de datos en Python, estructuras de datos en Python, librerías para procesamiento, visualización y modelamiento.
# 2.	Estadística para ciencia de datos:
#    *	Estadística descriptiva para ciencia de datos(Numpy, Scipy, statistics)
#    *	Estadística inferencial para ciencia de datos.
# 3.	Visualización de datos con matplotlib, seaborn y plotly de Python.
# 4.	Preprocesamiento de datos con Sklearn
# 5.	Constitución de modelos de clasificación binaria, multiclase, multisalida y multietiqueta.
# 6.	Constitución de modelos de regresión.

# %% [markdown]
# ##   Metodología

# %% [markdown]
# ## Aportes de la unidad académica o administrativa

# %% [markdown]
# ## Información de los docentes, expertos temáticos e interventor

# %% [markdown]
# ## Demanda esperada (Se priorizarán las ofertas que aporten elementos que soporten la demanda del programa en el medio).

# %% [markdown]
# ## Trayectoria del(os) proponente(s)

# %% [markdown]
# ##	Bibliografía
#
# * Calderón Piedras, S. Guía metodológica introductoria a la ciencia de datos.
#
#
# * Géron, A. (2022). Hands-on machine learning with Scikit-Learn, Keras, and TensorFlow. " O'Reilly Media, Inc.".
#
#
# * Müller, A. C., & Guido, S. (2016). Introduction to machine learning with Python: a guide for data scientists. " O'Reilly Media, Inc.".

# %% [markdown]
#
# ## Calendario
#
# * Recepción de propuestas: Del 2 de noviembre de 2022 al 16 de febrero de 2023 o antes de agotar los recursos asignados para la virtualización.
# * Sesión informativa:  Miércoles 16 de noviembre de 2022, 4:00 p. m. por Teams. ID de la reunión: 293 497 949 851. Código de acceso: veLCBp.
# * Inicio del proceso de virtualización: Se firmará el acta de inicio máximo 15 días hábiles después de la comunicación enviada a las propuestas que resulten seleccionadas.
#     Asesorías y acompañamiento: A través del correo educacion.continua@udea.edu.co y el teléfono 219 51 73.

# %% [markdown]
# # Tarea

# %% [markdown]
# La propuesta es un curso certificable de 3 módulos de 12 horas

# %% [markdown]
# Los módulos son:
#
# 1.  Python
# 2.  Estadistica
# 3.  Aprendizaje supervizado

# %% [markdown]
# Redactar la estructura o metodología de cada uno de los tres módulos
