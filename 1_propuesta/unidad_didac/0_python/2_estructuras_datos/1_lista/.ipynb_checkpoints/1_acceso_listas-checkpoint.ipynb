# %% [markdown]
# # Acceso a los elementos de una lista

# %%
lista = ['marco', 47, 1.65]

# %% [markdown]
# ## Acceder al primer elemento

# %%
lista[0]
# Out:
# 'marco'

# %% [markdown]
# El elemento asociado al índice cero va a ser siempre el primer elemento de una lista.

# %%
lista = ['Hola', 'Mundo', 'Chanchito feliz']

# %% [markdown]
# ## Diferencia entre indice y posición

# %% [markdown]
# Para acceder a los elementos de una lista lo hacemos a través del indice no através de su posición.

# %% [markdown]
# ## Eliminando elementos de una lista

# %% [markdown]
# ## Referentes
#
# * Nicolas Shurmann: Udemy
