# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/2_estructuras_datos/1_lista/2_eliminar_datos_lista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# # Eliminando datos de una lista

# %%
lista_int = [1,5,3,4]

# %%
lista_int.sort()

# %%
lista_int
# Out:
# [1, 3, 4, 5]

# %%
lista_float = [1.0, 2.5, 3,1, 0.5]

# %%
lista_str = ['Marco', 'Julio', 'Cañas', 'Campillo']

# %%
lista_str.sort()

# %%
lista_str
# Out:
# ['Campillo', 'Cañas', 'Julio', 'Marco']

# %%
lista_bool = [True, False]

# %%
lista_mixta = [1, 2.5, 'Marco', True]

# %%
lista_mixta.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [57], line 1
# ----> 1 lista_mixta.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %% [markdown]
# # Eliminar el último elemento de una lista

# %%
lista_int.pop() # Para eliminar el último elemento de la lista
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 lista_int.pop() # Para eliminar el último elemento de la lista
#
# IndexError: pop from empty list

# %%
lista_int
# Out:
# [1, 2, 3]

# %% [markdown]
# ## Eliminar un elemento en particular

# %%
lista = ['Hola', 'Mundo', 'Marco', 'Julio']

# %%
lista.remove('Marco') 
# el argumento de la función remove debe ser el valor 
# que quiere borrar de la lista

# %%
lista
# Out:
# ['Hola', 'Mundo', 'Julio']

# %% [markdown]
# # Reverse and sort

# %%
lista = ['Hola', 'Mundo', 'Marco', 'Julio']

# %%
lista.reverse() # invierte el orden de la lista

# %%
lista
# Out:
# ['Hola', 'Mundo', 'Marco', 'Julio']

# %%
lista.sort() # Para poder ordenar elementos de una lista, 
# sus valores deben ser del mismo tipo

# %%
lista
# Out:
# ['Hola', 'Julio', 'Marco', 'Mundo']

# %%
lista_mixta.remove(True)

# %%
lista_mixta
# Out:
# [2.5, 'Marco']

# %%
lista_float
# Out:
# [1.0, 2.5, 3, 1, 0.5]

# %%
lista_float.sort()

# %%
lista_float
# Out:
# [0.5, 1.0, 1, 2.5, 3]

# %%
lista_int.sort()

# %%
lista_int
# Out:
# []
