# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/0_python/2_estructuras_datos/2_tuplas/tuplas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # 6 Range

# %% [markdown]
# Este es otro tipo de dato con el que podemos trabajar en Python.

# %% [markdown]
# Los rangos nos permitiran tener progresiones aritméticas definidas por un número inicial, un número final y un incremento que nosotros definiremos.

# %% [markdown]
# Creamos los rango utilizando la palabra reservada `range`

# %%
rango = range(6)

# %%
print(rango)
# Out:
# range(0, 6)

# %% [markdown]
# Este tipo de dato nos va a servir para cuendo comencemos a trabajar con las iteraciones.

# %% [markdown]
# ## Tareas de afienzamiento y fijación de lo aprendido

# %% [markdown]
# ## Evaluación de lo aprendido

# %% [markdown]
# ## Referencias
