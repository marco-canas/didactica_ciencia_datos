# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/2_regresion/2_preprocesamiento_regresion/2_evaluation_quiz_parcial_preprocesamiento_regresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso:  ]()

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)
#
# ## Definición y características de este modelo

# %% [markdown]
# ## ¿Qué es?
#
# Flipped Learning o aprendizaje invertido es un enfoque pedagógico en el que:
#
# * la instrucción directa se realiza fuera del aula y
# * se utiliza el tiempo de clase para llevar a cabo actividades que impliquen el desarrollo de procesos cognitivos de mayor complejidad, en las que son necesarias la ayuda y la experiencia del docente.

# %% [markdown]
# ## ¿Para qué sirve?
#
# Mejora el proceso de enseñanza-aprendizaje realizando,
#
# * fuera del aula, actividades de aprendizaje sencillas (observar, memorizar, resumir, etc.) y,
# * en el aula, actividades más complejas (razonar, examinar, priorizar, argumentar, proponer, etc.) que requieren la interacción entre iguales y la ayuda del docente como facilitador.

# %% [markdown]
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/atributos_aprendizaje_invertido.png?raw=true'>

# %% [markdown]
# # Proceso Flipped Learning

# %% [markdown]
# ## Fuera del Aula

# %% [markdown]
# ### Docente:

# %% [markdown]
# * Diseña y planea el proceso de enseñanza-aprendizaje del aula, integrando estrategias, modelos de enseñanza y metodologías (aprendizaje basado en proyectos, aprendizaje cooperativo y colaborativo,…).
#
# * Diseña y planea actividades que se realizarán fuera del aula (ver vídeos, cumplimentar cuestionarios,…).
#
# * Selecciona e integra la tecnología en actividades de aprendizaje activo.
#
# * Diseña actividades de evaluación que promuevan el aprendizaje del alumnado.

# %% [markdown]
# ### Alumnado:

# %% [markdown]
# * Accede, cuantas veces necesite, a las actividades facilitadas por el profesorado.
# * Realiza las actividades propuestas.

# %% [markdown]
# ## En el Aula

# %% [markdown]
# ### Docente:

# %% [markdown]
# * Guía y facilita los procesos de aprendizaje, atendiendo a la diversidad.
# * Retroalimenta el desempeño de los equipos/grupos y del alumnado individualmente.
# * Genera espacios para la coevaluación y autoevaluación.

# %% [markdown]
# ### Alumnado:

# %% [markdown]
# * Realiza las actividades (debates, exposiciones orales, informes, diario de aprendizaje, cuaderno de trabajo cooperativo,…).
# * Recibe retroalimentación inmediata del profesorado y de sus compañeros y compañeras.
# * Accede, si fuera necesario, a las actividades previas facilitadas por el profesorado.

# %% [markdown]
# ## Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas
#
# # Las comparaciones

# %% [markdown]
# Hay otra forma de juzgar que consiste en el uso de comparaciones.

# %% [markdown]
# En su libro Cómo ser un perfecto desdichado, Dan Greenburg demuestra, valiéndose del humor, el insidioso poder que pueden ejercer sobre nosotros las comparaciones.

# %% [markdown]
# Afirma que si alguien aspira sinceramente a ser desgraciado lo único que tiene que hacer es compararse con los demás. Para beneficio de aquellos que no están familiarizados con esta práctica, propone una serie de ejercicios.

# %% [markdown]
# El primero consiste en presentar fotografías de cuerpo entero de un hombre y una mujer que son una representación de la belleza física ideal según los cánones difundidos por los medios de comunicación.

# %% [markdown]
# Se aconseja a los lectores que se tomen las medidas de diferentes partes del cuerpo, las comparen con las
# que figuran en las fotos de esos atractivos ejemplares de ser humano, y observen
# las diferencias.

# %% [markdown]
# Es un ejercicio que cumple lo que promete: cuando hacemos la comparación, nos sentimos profundamente desgraciados. Ya hundidos en una profunda depresión, descubrimos, al dar vuelta la página, que ese primer ejercicio sólo era de calentamiento.

# %% [markdown]
# Partiendo de la base de que la belleza física es relativamente superficial, Greenburg nos brinda a continuación la oportunidad de hacer la comparación que realmente importa: el éxito personal.

# %% [markdown]
# Recurre, según dice, a la guía telefónica para sacar de ella los nombres de unos cuantos individuos elegidos al azar
# con el objeto de establecer comparaciones.

# %% [markdown]
# El primer nombre que dice haber sacado de la guía es Wolfgang Amadeus Mozart.

# %% [markdown]
# Greenburg hace una lista de los
# idiomas que hablaba Mozart desde su adolescencia y de las principales obras que ya había compuesto a esa edad. El ejercicio invita al lector a comparar todo lo que
# él ha logrado hasta ese momento de su vida con lo que Mozart había logrado a
# los doce años, y que observe las diferencias.
# Incluso los lectores que no consiguen superar el malestar causado por este
# ejercicio perciben hasta qué punto esta forma de pensar bloquea la compasión,
# tanto por nosotros mismos como por los demás.
# # Negación de la responsabilidad

# %% [markdown]
# Otra forma de comunicación que aliena de la vida es la negación de la responsabilidad. La comunicación que aliena de la vida nos nubla la conciencia de nuestra responsabilidad en lo que pensamos, sentimos y hacemos. El uso de la expresión tan habitual: «tener que», como en el caso de la afirmación: «te guste o no, tienes que hacerlo», ilustra hasta qué punto nuestra responsabilidad personal por nuestras acciones se ve oscurecida por esta mane

# %% [markdown]
# ## Título de la clase

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# * Evaluar la capacidad de realizar el preprocesamiento de datos para un modelo de regresión con los datos de la estación meteorológica

# %% [markdown]
# ## Establecimiento de prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.
#
# (Elabore una lista de preguntas al rededor de los conceptos que consideres necesarios para empezar la clase).
#
# 1.
# 2.
# 3.

# %% [markdown]
# # Para el diseño de la clase tenga en cuenta algunos problemas de aprendizaje

# %% [markdown]
# ## Secuencia conceptual introductoria a la clase

# %% [markdown]
# ## Importación de los datos de Caucasia

# %% [markdown]
# ## Cuestionario o lista de verificación para realizar labores de memorización y observación,  a la síntesis de la información
#
# 1.  Inporte las librerías NumPy y Pandas.
# 2.

# %%
import numpy as np 
import pandas as pd 
ubicacion_datos = 'https://raw.githubusercontent.com/marco-canas/7_didactica_ciencia_datos/main/datasets/antioquia_mira_su_cielo/caucasia.csv'

# %%
df=pd.read_csv(ubicacion_datos)

# %%
df
# Out:
#         Unnamed: 0       Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 0                0  2023-01-25 09:47:53         O       1441.0    29687.0
# 1                1  2023-01-25 09:48:00         O       1441.0    29687.0
# 2                2  2023-01-25 09:49:03         O       1441.0    29687.0
# 3                3  2023-01-25 09:50:00         O       1441.0    29687.0
# 4                4  2023-01-25 09:51:00         O       1441.0    29684.0
# ...            ...                  ...       ...          ...        ...
# 133402         896  2023-05-25 09:56:00         O       2081.0    29698.0
# 133403         897  2023-05-25 09:57:00         O       2081.0    29698.0
# 133404         898  2023-05-25 09:58:00         O       2081.0    29698.0
# 133405         899  2023-05-25 09:59:00         O       2081.0    29698.0
# 133406         900  2023-05-25 10:00:00         O       2082.0    29699.0
#
#         Inside Temperature  Inside Humidity  Outside Temperature  Wind Speed  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 0           0  2023-01-25 09:47:53         O       1441.0    29687.0
# 1           1  2023-01-25 09:48:00         O       1441.0    29687.0
# 2           2  2023-01-25 09:49:03         O       1441.0    29687.0
# 3           3  2023-01-25 09:50:00         O       1441.0    29687.0
# 4           4  2023-01-25 09:51:00         O       1441.0    29684.0
#
#    Inside Temperature  Inside Humidity  Outside Temperature  Wind Speed  \
# 0               942.0             50.0                921.0         2.0
# 1               943.0             50.0                921.0         3.0
# 2               942.0             50.0                922.0         4.0
# 3               942.0             50.0                923.0         4.0
# 4               943.0             50.0                923.0         3.0
#
#    10 Min Avg Wind Speed  ...  Soil & Leaf Alarms  Transmitter Battery Status  \
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0       Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 133402         896  2023-05-25 09:56:00         O       2081.0    29698.0
# 133403         897  2023-05-25 09:57:00         O       2081.0    29698.0
# 133404         898  2023-05-25 09:58:00         O       2081.0    29698.0
# 133405         899  2023-05-25 09:59:00         O       2081.0    29698.0
# 133406         900  2023-05-25 10:00:00         O       2082.0    29699.0
#
#         Inside Temperature  Inside Humidity  Outside Temperature  Wind Speed  \
# 133402               881.0             73.0                816.0         2.0
# 133403               881.0             73.0                816.0         4.0
# 133404               880.0             73.0                817.0         2.0
# 133405               880.0             74.0                817.0         5.0
# 133406               880.0             74.0                817.0         2.0
#
#         10 Min Avg Wind Speed  ...  Soil & Leaf Alarms  \
# ...

# %%
df[100:150] # Notación de corchetes para porciones del dataframe
# Out:
#      Unnamed: 0       Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 100         100  2023-01-25 11:31:00         O       1445.0    29690.0
# 101         101  2023-01-25 11:32:00         O       1445.0    29688.0
# 102         102  2023-01-25 11:33:00         O       1445.0    29687.0
# 103         103  2023-01-25 11:34:00         O       1445.0    29688.0
# 104         104  2023-01-25 11:35:00         O       1445.0    29688.0
# 105         105  2023-01-25 11:36:00         O       1445.0    29688.0
# 106         106  2023-01-25 11:37:00         O       1445.0    29689.0
# 107         107  2023-01-25 11:38:00         O       1445.0    29690.0
# 108         108  2023-01-25 11:39:00         O       1445.0    29688.0
# 109         109  2023-01-25 11:40:00         O       1445.0    29687.0
# 110         110  2023-01-25 11:41:00         O       1445.0    29688.0
# 111         111  2023-01-25 11:42:00         O       1445.0    29689.0
# ...

# %%
df.shape
# Out:
# (133407, 43)

# %% [markdown]
# ## dame el código python para codificar la variable 'Tiempo Sistema' en una serie de tiempo dada en un DataFrame

# %% [markdown]
# Claro, puedo ayudarte con eso. Para codificar la variable "Tiempo Sistema" en una serie de tiempo en un DataFrame en Python, puedes seguir estos pasos:
#
# 1. Importa las bibliotecas necesarias:
# ```python
# import pandas as pd
# import numpy as np
# from sklearn.preprocessing import LabelEncoder
# ```
#
# 2. Crea un DataFrame de ejemplo:
# ```python
# data = {'Tiempo Sistema': ['10:00', '12:30', '14:45', '09:15']}
# df = pd.DataFrame(data)
# ```
#
# 3. Crea una instancia de `LabelEncoder` para codificar la variable "Tiempo Sistema":
# ```python
# encoder = LabelEncoder()
# ```
#
# 4. Ajusta el codificador a los valores únicos en la columna "Tiempo Sistema":
# ```python
# encoder.fit(df['Tiempo Sistema'])
# ```
#
# 5. Codifica los valores en la columna "Tiempo Sistema" utilizando el codificador:
# ```python
# df['Tiempo Codificado'] = encoder.transform(df['Tiempo Sistema'])
# ```
#
# El DataFrame resultante contendrá una nueva columna llamada "Tiempo Codificado" que contiene los valores codificados de la variable "Tiempo Sistema".
#
# Aquí tienes el código completo:
#
# ```python
# import pandas as pd
# import numpy as np
# from sklearn.preprocessing import LabelEncoder
#
# # Crear DataFrame de ejemplo
# data = {'Tiempo Sistema': ['10:00', '12:30', '14:45', '09:15']}
# df = pd.DataFrame(data)
#
# # Crear instancia de LabelEncoder
# encoder = LabelEncoder()
#
# # Ajustar codificador a los valores únicos en la columna "Tiempo Sistema"
# encoder.fit(df['Tiempo Sistema'])
#
# # Codificar los valores en la columna "Tiempo Sistema"
# df['Tiempo Codificado'] = encoder.transform(df['Tiempo Sistema'])
#
# print(df)
# ```
#
# La salida será:
#
# ```
#   Tiempo Sistema  Tiempo Codificado
# 0          10:00                  1
# 1          12:30                  2
# 2          14:45                  3
# 3          09:15                  0
# ```
#
# En este ejemplo, los valores únicos en la columna "Tiempo Sistema" se codificaron en números enteros en la columna "Tiempo Codificado". Cada valor único se asigna a un número entero único.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
# Crear instancia de LabelEncoder
encoder = LabelEncoder()

# Ajustar codificador a los valores únicos en la columna "Tiempo Sistema"
encoder.fit(df['Tiempo Sistema'])

# Codificar los valores en la columna "Tiempo Sistema"
df['Tiempo Codificado'] = encoder.transform(df['Tiempo Sistema'])

print(df)
# Out:
#   Tiempo Sistema  Tiempo Codificado
# 0          10:00                  1
# 1          12:30                  2
# 2          14:45                  3
# 3          09:15                  0

# %% [markdown]
# ## Mapa conceptual de la clase elaborado en CMapTools

# %% [markdown]
# <img src = ''>

# %% [markdown]
# ## Tareas para realizar antes de la clase

# %% [markdown]
# 1. Ver los videos respectivos []()
# 2. Memorizar las definiciones []()
# 3. Sintetizar o resumir la información en mapas conceptuales. []()

# %% [markdown]
# # Tareas para realizar en clase

# %% [markdown]
# * Modelación matemática
# * Trabajo en equipos

# %% [markdown]
# # Tareas para realizar después de la realización de la clase

# %% [markdown]
# * Actividades de memorización:
#   - escucha reiterada de grabaciones de formulas y resultados científicos.
#   - relectura de notas.
#   - ejercicios de mayor complejidad.

# %% [markdown]
# ## Dificultades de aprendizaje detectados durante la clase

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# ## Grabaciones en audio para fomentar la capacidad de memorizar enunciados de teoremas y resultados científicos y la capacidad de parafrasear estos resultados.

# %% [markdown]
# Se dispondrá de un lugar en el drive asociuado al correo institucional de la Universidad Nacional del Profesor Marso para albergar los archivosd de audio de fomento a la memoirización, enunciación y parafraseo de los resultados científicos, prtopiedades, reglas, etc.
#
# * Vocaroo

# %% [markdown]
# ### Comparta sus cuadernos y videos, evidencias de su aprendizaje [aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUMEMwTEZVMzEwVVBPTElWNVg5OVEyWUhMUy4u)

# %% [markdown]
# # Vocabulary

# %% [markdown]
# 1. shape:
# 2. read:
# 3. head:
# 4. sort: ordenar

# %% [markdown]
# ## Mapa conceptual que vincula los conceptos asoaciados al objetivo de aprendizaje

# %% [markdown]
# ## Quiz de 5 minutos para ejercitación y adquisición de habilidades

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [stewart precálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ERHIq62I6qFNrmxy6LZb8ZMBci7kUsyNME1nIh9yCBMJ_w?e=0zMSla)
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
# * [uzcategui](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ETDikm-lVl1Or8XoEo9oyh0BEti9Zs8le-f0D-dBdtZmbA?e=bBsoyQ)
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Conjeturas pedagógicas fruto de la aplicación del modelo de aprendizaje invertido y del enfoque hacia la ciencia de datos con python
#
# 1. Todo cálculo o resultado debe ser interpretado en una línea markdown del cuaderno Jupyter, inmediatamente después de la enunciación del resultado y después de la presentación de una tabla o gráfico bidimensional, de tal menera que el estudiante explicite la comprensión verbal del resultado y las inferencias o estrategias que este resultado le sugieren.

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado.
#
# Y a mi esposa Yasmira por su apoyo, orientación y acompañamiento.
