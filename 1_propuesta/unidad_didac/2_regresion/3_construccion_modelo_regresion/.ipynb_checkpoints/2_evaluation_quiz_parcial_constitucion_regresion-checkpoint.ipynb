# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/2_regresion/3_construccion_modelo_regresion/2_evaluation_quiz_parcial_constitucion_regresion.ipynb#scrollTo=41e82203" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno](https://www.youtube.com/watch?v=HpXcQi2cXas)

# %% [markdown]
# ## [Vínculo al programa del curso:  ](https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/cartilla/cartilla.ipynb)

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)
#
# ## Definición y características de este modelo

# %% [markdown]
# ## ¿Qué es?
#
# Flipped Learning o aprendizaje invertido es un enfoque pedagógico en el que:
#
# * la instrucción directa se realiza fuera del aula y
# * se utiliza el tiempo de clase para llevar a cabo actividades que impliquen el desarrollo de procesos cognitivos de mayor complejidad, en las que son necesarias la ayuda y la experiencia del docente.

# %% [markdown]
# ## ¿Para qué sirve?
#
# Mejora el proceso de enseñanza-aprendizaje realizando,
#
# * fuera del aula, actividades de aprendizaje sencillas (observar, memorizar, resumir, etc.) y,
# * en el aula, actividades más complejas (razonar, examinar, priorizar, argumentar, proponer, etc.) que requieren la interacción entre iguales y la ayuda del docente como facilitador.

# %% [markdown]
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/atributos_aprendizaje_invertido.png?raw=true'>

# %% [markdown]
# # Proceso Flipped Learning

# %% [markdown]
# ## Fuera del Aula

# %% [markdown]
# ### Docente:

# %% [markdown]
# * Diseña y planea el proceso de enseñanza-aprendizaje del aula, integrando estrategias, modelos de enseñanza y metodologías (aprendizaje basado en proyectos, aprendizaje cooperativo y colaborativo,…).
#
# * Diseña y planea actividades que se realizarán fuera del aula (ver vídeos, cumplimentar cuestionarios,…).
#
# * Selecciona e integra la tecnología en actividades de aprendizaje activo.
#
# * Diseña actividades de evaluación que promuevan el aprendizaje del alumnado.

# %% [markdown]
# ### Alumnado:

# %% [markdown]
# * Accede, cuantas veces necesite, a las actividades facilitadas por el profesorado.
# * Realiza las actividades propuestas.

# %% [markdown]
# ## En el Aula

# %% [markdown]
# ### Docente:

# %% [markdown]
# * Guía y facilita los procesos de aprendizaje, atendiendo a la diversidad.
# * Retroalimenta el desempeño de los equipos/grupos y del alumnado individualmente.
# * Genera espacios para la coevaluación y autoevaluación.

# %% [markdown]
# ### Alumnado:

# %% [markdown]
# * Realiza las actividades (debates, exposiciones orales, informes, diario de aprendizaje, cuaderno de trabajo cooperativo,…).
# * Recibe retroalimentación inmediata del profesorado y de sus compañeros y compañeras.
# * Accede, si fuera necesario, a las actividades previas facilitadas por el profesorado.

# %% [markdown]
# ## Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas
#
# ## Negación de la responsabilidad

# %% [markdown]
# Otra forma de comunicación que aliena de la vida es la negación de la responsabilidad.

# %% [markdown]
# La comunicación que aliena de la vida nos nubla la conciencia de nuestra responsabilidad en lo que pensamos, sentimos y hacemos.

# %% [markdown]
# El uso de la expresión tan habitual: «tener que», como en el caso de la afirmación: «te guste o no, tienes que hacerlo», ilustra hasta qué punto nuestra responsabilidad personal por nuestras acciones se ve oscurecida por esta manera de hablar.

# %% [markdown]
# En cuanto a la expresión: «hacer sentir», como en el caso de: «me haces sentir culpable», constituye otro ejemplo más de cómo el lenguaje nos allana el camino para que podamos negar nuestra responsabilidad personal con respecto a lo que sentimos y a lo que
# pensamos.

# %% [markdown]
# En su libro Eichmann in Jerusalem,* que documenta el juicio por los crímenes contra la humanidad cometidos por el oficial nazi Adolph Eichmann, Hannah Arendt dice que Eichmann declaró que tanto él como sus compañeros utilizaban una palabra especial para referirse al lenguaje con el que eludían y negaban su responsabilidad.

# %% [markdown]
# El nombre que daban a esa actitud era Amtssprache, que podría traducirse libremente como «lenguaje oficial» o «jerga burocrática».

# %% [markdown]
# Si se les preguntaba, por ejemplo, por qué habían cometido determinados actos, la respuesta podía ser: «Tenía que hacerlo». Y si se les preguntaba por qué «tenían que» hacerlo, la respuesta podía ser: «Eran órdenes superiores», «Era la política del momento», «Era la ley».

# %% [markdown]
# Negamos la responsabilidad de nuestros actos cuando atribuimos su causa a:
#
# * Fuerzas difusas e impersonales:
# Limpié mi habitación porque tenía que hacerlo.

# %% [markdown]
# * Nuestro estado de salud, un diagnóstico o nuestra historia personal o psicológica:
#
# Bebo porque soy alcohólico.

# %% [markdown]
# * Lo que hacen los demás:
#
# Le pegué a mi hijo porque cruzó la calle corriendo.

# %% [markdown]
# * Órdenes de la autoridad:
#
# Mentí al cliente porque mi jefe me dijo que lo hiciera.
#
# * Presiones de grupo:
#
# Empecé a fumar porque todos mis amigos lo hacían.
#
# * Políticas, normas y reglas institucionales:
# Tengo que expulsarte por esta infracción porque es la política de la escuela.
#
# * Los roles asignados según sexo, posición social o edad:
# Me fastidia ir a trabajar, pero tengo que hacerlo porque soy marido y padre.
#
# * Impulsos irrefrenables:
# Me superaron las ganas de comer bombones y me los comí.

# %% [markdown]
# Cierta vez, durante un encuentro de padres y maestros en el que se habló de los peligros de un lenguaje que presupone la imposibilidad de elegir, una mujer objetó, indignada: «¡Pero hay cosas que uno tiene que hacer, le guste o no! No veo

# %% [markdown]
# # El lobo que gana
#
# https://www.instagram.com/reel/CrvqKmZgE0o/?igshid=MTc4MmM1YmI2Ng%3D%3D

# %% [markdown]
# ## Título de la clase : Práctica de constitución de modelos de regresión

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# * Constituir en el menor tiempo posible, un modelo de regresion siguiendo la metodología de Aurelien Geron.

# %% [markdown]
# ## Establecimiento de prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.
#
# (Elabore una lista de preguntas al rededor de los conceptos que consideres necesarios para empezar la clase).
# 1. Introducción a Google Colab
# 2. lenguaje python
# 3. Elementos de estadística para ciencia de datos
# 4.

# %% [markdown]
# # Para el diseño de la clase tenga en cuenta algunos problemas de aprendizaje

# %% [markdown]
# 1. Saberse de memoria los nombre de atributos, métodos de Python para obtención y procesamiento de datos.

# %% [markdown]
# ## Secuencia conceptual introductoria a la clase

# %% [markdown]
# # Cronómetremos el tiempo de constitución del modelo

# %%
# Este código determina el tiempo de ejecución de un código en Python
import time

# Inicio del cronómetro
inicio = time.time()

# Código o proceso que deseas medir el tiempo
# Aquí puedes colocar tu código o proceso a cronometrar

time.sleep(0.5)  # Ejemplo de espera de 2 segundos

# Fin del cronómetro
fin = time.time()

# Cálculo del tiempo transcurrido
tiempo_transcurrido = fin - inicio

# Imprimir el tiempo transcurrido
print("Tiempo transcurrido:", tiempo_transcurrido, "segundos")
# Out:
# Tiempo transcurrido: 0.5072994232177734 segundos

# %% [markdown]
# # Chapter 2. End-to-End Machine Learning Project

# %% [markdown]
# # Vocabulary
#
# 1. chapter
# 2. end to end: de principio a fin
# 3. learning
# 4. project:
# 5. shape: forma
# 6. unnamed: sin nombre
# 7. rows: filas (horizontales)
# 8. columns: columnas (Verticales)
# 9. size: tamaño
# 10. color: color
# 11. research group leader: lider del grupo de investigación.
# 12.
#
# [Este vocabulario grabado en voocaro]()

# %% [markdown]
# In this chapter you will work through an example project end to end, pretending
# to be a recently hired data scientist at a real estate company. Here are the main
# steps you will go through:
# 1. Look at the big picture.
#
# <img src = 'https://www.darrera.com/wp/wp-content/uploads/2017/06/6152-vantage-pro2-inalambrica.jpg'>

# %% [markdown]
# <img src = 'https://greenforest.com.co/wp-content/uploads/2018/03/consola-de-la-davis-vantage-pro2.jpg'>

# %% [markdown]
# # 2. Get the data.

# %%
import numpy as np 
import pandas as pd 

ubicacion_datos = "https://raw.githubusercontent.com/marco-canas/7_didactica_ciencia_datos/main/datasets/antioquia_mira_su_cielo/caucasia.csv"

# %%
df = pd.read_csv(ubicacion_datos)

# %%
df
# Out:
#         Unnamed: 0       Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 0                0  2023-01-25 09:47:53         O       1441.0    29687.0
# 1                1  2023-01-25 09:48:00         O       1441.0    29687.0
# 2                2  2023-01-25 09:49:03         O       1441.0    29687.0
# 3                3  2023-01-25 09:50:00         O       1441.0    29687.0
# 4                4  2023-01-25 09:51:00         O       1441.0    29684.0
# ...            ...                  ...       ...          ...        ...
# 133402         896  2023-05-25 09:56:00         O       2081.0    29698.0
# 133403         897  2023-05-25 09:57:00         O       2081.0    29698.0
# 133404         898  2023-05-25 09:58:00         O       2081.0    29698.0
# 133405         899  2023-05-25 09:59:00         O       2081.0    29698.0
# 133406         900  2023-05-25 10:00:00         O       2082.0    29699.0
#
#         Inside Temperature  Inside Humidity  Outside Temperature  Wind Speed  \
# ...

# %% [markdown]
# # 3. Discover and visualize the data to gain insights.

# %% [markdown]
# ## Visualización tabular

# %%
df.head()
# Out:
#    Unnamed: 0       Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 0           0  2023-01-25 09:47:53         O       1441.0    29687.0
# 1           1  2023-01-25 09:48:00         O       1441.0    29687.0
# 2           2  2023-01-25 09:49:03         O       1441.0    29687.0
# 3           3  2023-01-25 09:50:00         O       1441.0    29687.0
# 4           4  2023-01-25 09:51:00         O       1441.0    29684.0
#
#    Inside Temperature  Inside Humidity  Outside Temperature  Wind Speed  \
# 0               942.0             50.0                921.0         2.0
# 1               943.0             50.0                921.0         3.0
# 2               942.0             50.0                922.0         4.0
# 3               942.0             50.0                923.0         4.0
# 4               943.0             50.0                923.0         3.0
#
#    10 Min Avg Wind Speed  ...  Soil & Leaf Alarms  Transmitter Battery Status  \
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0       Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 133402         896  2023-05-25 09:56:00         O       2081.0    29698.0
# 133403         897  2023-05-25 09:57:00         O       2081.0    29698.0
# 133404         898  2023-05-25 09:58:00         O       2081.0    29698.0
# 133405         899  2023-05-25 09:59:00         O       2081.0    29698.0
# 133406         900  2023-05-25 10:00:00         O       2082.0    29699.0
#
#         Inside Temperature  Inside Humidity  Outside Temperature  Wind Speed  \
# 133402               881.0             73.0                816.0         2.0
# 133403               881.0             73.0                816.0         4.0
# 133404               880.0             73.0                817.0         2.0
# 133405               880.0             74.0                817.0         5.0
# 133406               880.0             74.0                817.0         2.0
#
#         10 Min Avg Wind Speed  ...  Soil & Leaf Alarms  \
# ...

# %%
df.info() #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133407 entries, 0 to 133406
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   133407 non-null  int64
#  1   Tiempo Sistema               133404 non-null  object
#  2   Bar Trend                    133404 non-null  object
#  3   Next Record                  133404 non-null  float64
#  4   Barometer                    133404 non-null  float64
#  5   Inside Temperature           133404 non-null  float64
#  6   Inside Humidity              133404 non-null  float64
#  7   Outside Temperature          133404 non-null  float64
#  8   Wind Speed                   133404 non-null  float64
#  9   10 Min Avg Wind Speed        133404 non-null  float64
#  10  Wind Direction               133404 non-null  float64
#  11  Extra Temperatures           133404 non-null  float64
# ...

# %%
df['Tiempo Sistema'].value_counts() # contamos la frecuencia absoluta de cada una de sus subcategorias
# Out:
# 2023-01-25 09:47:53    1
# 2023-04-15 20:10:00    1
# 2023-04-15 20:08:00    1
# 2023-04-15 20:07:00    1
# 2023-04-15 20:06:00    1
#                       ..
# 2023-03-03 05:43:00    1
# 2023-03-03 05:42:00    1
# 2023-03-03 05:41:00    1
# 2023-03-03 05:40:00    1
# 2023-05-25 10:00:00    1
# Name: Tiempo Sistema, Length: 133404, dtype: int64

# %%
df.describe()
# Out:
#           Unnamed: 0    Next Record      Barometer  Inside Temperature  \
# count  133407.000000  133404.000000  133404.000000       133404.000000
# mean      695.201511    1233.218112   29804.154373          893.317419
# std       413.806832     647.741720      65.400173           32.349080
# min         0.000000       0.000000   29604.000000          814.000000
# 25%       336.000000     750.000000   29760.000000          869.000000
# 50%       681.000000    1306.000000   29806.000000          891.000000
# 75%      1049.000000    1755.000000   29849.000000          917.000000
# max      1439.000000    2559.000000   29987.000000          988.000000
#
#        Inside Humidity  Outside Temperature     Wind Speed  \
# count    133404.000000        133404.000000  133404.000000
# mean         62.753336           829.066250       2.426711
# std           7.663550            59.618614       1.997109
# min          41.000000           707.000000       0.000000
# ...

# %% [markdown]
# # Visualización gráfica

# %%
import matplotlib.pyplot as plt # matriz de histogramas 
df.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ## Hacer un diagrama de dispersión o scatter

# %%
df.plot(kind = 'scatter', x ='Outside Temperature', y = 'Outside Humidity', alpha = 0.5,\
        s=df['Barometer']/1000, label="Presión", figsize=(7,5),\
        c='Wind Speed', cmap=plt.get_cmap("jet"), colorbar=True,
)
# Out:
# <AxesSubplot:xlabel='Outside Temperature', ylabel='Outside Humidity'>

# %% [markdown]
# # 4. Prepare the data for Machine Learning algorithms.

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(df, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Hicimos una copia de los datos de entrenamiento

# %%
df = train_set.copy()

# %%
df.keys() # listar los atributos
# Out:
# Index(['Unnamed: 0', 'Tiempo Sistema', 'Bar Trend', 'Next Record', 'Barometer',
#        'Inside Temperature', 'Inside Humidity', 'Outside Temperature',
#        'Wind Speed', '10 Min Avg Wind Speed', 'Wind Direction',
#        'Extra Temperatures', 'Soil Temperatures', 'Leaf Temperatures',
#        'Outside Humidity', 'Extra Humidties', 'Rain Rate', 'UV',
#        'Solar Radiation', 'Storm Rain', 'Start Date of current Storm',
#        'Day Rain', 'Month Rain', 'Year Rain', 'Day ET', 'Month ET', 'Year ET',
#        'Soil Moistures', 'Leaf Wetnesses', 'Inside Alarms', 'Rain Alarms',
#        'Outside Alarms', 'Extra Temp/Hum Alarms', 'Soil & Leaf Alarms',
#        'Transmitter Battery Status', 'Console Battery Voltage',
#        'Forecast Icons', 'Forecast Rule number', 'Time of Sunrise',
#        'Time of Sunset', '<LF> = 0x0A', '<CR> = 0x0D', 'CRC'],
#       dtype='object')

# %% [markdown]
# # Codificación de la variable `Tiempo Sistema`

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# Crear instancia de LabelEncoder
encoder = LabelEncoder()

# Ajustar codificador a los valores únicos en la columna "Tiempo Sistema"
encoder.fit(df['Tiempo Sistema'])

# Codificar los valores en la columna "Tiempo Sistema"
df['Tiempo Codificado'] = encoder.transform(df['Tiempo Sistema'])

df
# Out:
#         Unnamed: 0       Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 97990         1336  2023-04-28 17:16:00         O        800.0    29867.0
# 111420         366  2023-05-08 01:06:00         O       1248.0    29763.0
# 22964          357  2023-02-16 00:57:00         O       2480.0    29786.0
# 86844          845  2023-04-14 09:05:00         O        112.0    29697.0
# 35818          257  2023-02-24 23:17:00         O        348.0    29832.0
# ...            ...                  ...       ...          ...        ...
# 110268         654  2023-05-07 05:54:00         O       1209.0    29815.0
# 119879         333  2023-05-16 00:33:00         O       1631.0    29873.0
# 103694        1280  2023-05-02 16:20:00         O        990.0    29721.0
# 131932         866  2023-05-24 09:26:00         O       2032.0    29752.0
# 121958         972  2023-05-17 11:12:00         O       1700.0    29727.0
#
#         Inside Temperature  Inside Humidity  Outside Temperature  Wind Speed  \
# ...

# %% [markdown]
# # Análisis de correlaciones

# %% [markdown]
# Para constituir una matriz de correlaciones y visualizarla como un mapa de calor en Pandas, puedes utilizar las funciones proporcionadas por las bibliotecas Pandas, NumPy y Seaborn. Aquí tienes un ejemplo de cómo hacerlo:
#
# 1. Importa las bibliotecas necesarias:
#
# ```python
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```
#
# 2. Crea un DataFrame de ejemplo con datos:
#
# ```python
# data = {'Variable1': [1, 2, 3, 4, 5],
#         'Variable2': [2, 4, 6, 8, 10],
#         'Variable3': [3, 6, 9, 12, 15],
#         'Variable4': [4, 8, 12, 16, 20]}
# df = pd.DataFrame(data)
# ```
#
# 3. Calcula la matriz de correlaciones utilizando la función `corr()` de Pandas:
#
# ```python
# correlation_matrix = df.corr()
# ```
#
# 4. Crea un mapa de calor utilizando la matriz de correlaciones con la función `heatmap()` de Seaborn:
#
# ```python
# sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
# plt.title('Matriz de Correlaciones')
# plt.show()
# ```
#
# En este ejemplo, se crea un DataFrame de ejemplo con cuatro variables y se calcula la matriz de correlaciones utilizando la función `corr()`. Luego, se utiliza la función `heatmap()` de Seaborn para crear un mapa de calor de la matriz de correlaciones. Los argumentos `annot=True` muestran los valores de correlación en cada celda, y `cmap="coolwarm"` define el esquema de colores.
#
# Finalmente, se muestra el mapa de calor utilizando `plt.show()` y se le agrega un título con `plt.title()`.
#
# Puedes aplicar este código a tus propios conjuntos de datos para visualizar la matriz de correlaciones como un mapa de calor en Pandas.
#
# Recuerda que debes tener las bibliotecas Pandas, NumPy, Seaborn y Matplotlib instaladas en tu entorno de trabajo para ejecutar este código correctamente.

# %%
matriz_correlaciones = df.corr()

# %%
matriz_correlaciones['Outside Temperature'].sort_values(ascending=False)
# Out:
# Outside Temperature            1.000000
# Inside Temperature             0.809654
# Solar Radiation                0.591178
# Day ET                         0.584882
# 10 Min Avg Wind Speed          0.431751
# Unnamed: 0                     0.404265
# Forecast Rule number           0.384579
# Wind Speed                     0.332214
# Forecast Icons                 0.135955
# Tiempo Codificado              0.013077
# Year ET                        0.010303
# Time of Sunset                 0.008037
# Time of Sunrise                0.004952
# CRC                           -0.003148
# Next Record                   -0.016390
# Month ET                      -0.037837
# Wind Direction                -0.188366
# Console Battery Voltage       -0.277100
# Barometer                     -0.523169
# Inside Humidity               -0.698864
# Outside Humidity              -0.922147
# Extra Temperatures                  NaN
# Soil Temperatures                   NaN
# ...

# %%
lista_atributos_mejor_correlacionados = ['Inside Temperature', 'Solar Radiation',\
                                   'Day ET', '10 Min Avg Wind Speed', 'Forecast Rule number', \
                                   'Wind Speed', 'Forecast Icons', 'Year ET', 'Time of Sunset', \
                                   'Time of Sunrise', 'CRC', 'Next Record', 'Month ET', 'Wind Direction',\
                                   'Console Battery Voltage', 'Barometer', 'Inside Humidity', 'Outside Humidity',\
                                         'Outside Temperature', 'Outside Temperature']

# %%
df = df[lista_atributos_mejor_correlacionados]

# %%
df.corr()['Outside Temperature'].sort_values(ascending = False)
# Out:
# Outside Temperature        1.000000
# Inside Temperature         0.809654
# Solar Radiation            0.591178
# Day ET                     0.584882
# 10 Min Avg Wind Speed      0.431751
# Forecast Rule number       0.384579
# Wind Speed                 0.332214
# Forecast Icons             0.135955
# Year ET                    0.010303
# Time of Sunset             0.008037
# Time of Sunrise            0.004952
# CRC                       -0.003148
# Next Record               -0.016390
# Month ET                  -0.037837
# Wind Direction            -0.188366
# Console Battery Voltage   -0.277100
# Barometer                 -0.523169
# Inside Humidity           -0.698864
# Outside Humidity          -0.922147
# Name: Outside Temperature, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ['Outside Temperature','Solar Radiation', 'Day ET','Barometer', 'Outside Humidity', 'Outside Temperature']
scatter_matrix(df[attributes], figsize=(12, 8))
plt.show()

# %%
df.plot(kind="scatter", x="Solar Radiation", y="Outside Temperature",
alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Solar Radiation', ylabel='Outside Temperature'>

# %%
df.plot(kind="scatter", x="Outside Humidity", y="Outside Temperature",
alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Outside Humidity', ylabel='Outside Temperature'>

# %% [markdown]
# # Dividir en predictores y variable objetivo

# %%
df_predictores = df.drop('Outside Temperature',axis = 1)
df_labels = df[['Outside Temperature']] # dataframe

# %%
df_predictores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106725 entries, 97990 to 121958
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Inside Temperature       106723 non-null  float64
#  1   Solar Radiation          106723 non-null  float64
#  2   Day ET                   106723 non-null  float64
#  3   10 Min Avg Wind Speed    106723 non-null  float64
#  4   Forecast Rule number     106723 non-null  float64
#  5   Wind Speed               106723 non-null  float64
#  6   Forecast Icons           106723 non-null  float64
#  7   Year ET                  106723 non-null  float64
#  8   Time of Sunset           106723 non-null  float64
#  9   Time of Sunrise          106723 non-null  float64
#  10  CRC                      106723 non-null  float64
#  11  Next Record              106723 non-null  float64
#  12  Month ET                 106723 non-null  float64
# ...

# %%
df_labels
# Out:
#         Outside Temperature
# 97990                 784.0
# 111420                797.0
# 22964                 782.0
# 86844                 918.0
# 35818                 745.0
# ...                     ...
# 110268                889.0
# 119879                778.0
# 103694                847.0
# 131932                816.0
# 121958                853.0
#
# [106725 rows x 1 columns]

# %% [markdown]
# # Imputar los dos daticos faltantes en el dataframe de predictores df_predictores

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")

# %%
X_predictores_imputado = imputer.fit_transform(df_predictores)

# %%
df_predictores_imputado = pd.DataFrame(X_predictores_imputado, columns = df_predictores.keys())

# %%
df_predictores_imputado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106725 entries, 0 to 106724
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Inside Temperature       106725 non-null  float64
#  1   Solar Radiation          106725 non-null  float64
#  2   Day ET                   106725 non-null  float64
#  3   10 Min Avg Wind Speed    106725 non-null  float64
#  4   Forecast Rule number     106725 non-null  float64
#  5   Wind Speed               106725 non-null  float64
#  6   Forecast Icons           106725 non-null  float64
#  7   Year ET                  106725 non-null  float64
#  8   Time of Sunset           106725 non-null  float64
#  9   Time of Sunrise          106725 non-null  float64
#  10  CRC                      106725 non-null  float64
#  11  Next Record              106725 non-null  float64
#  12  Month ET                 106725 non-null  float64
# ...

# %% [markdown]
# # Escalamiento de los atributos

# %%
from sklearn.preprocessing import StandardScaler
escalador = StandardScaler()

# %%
X_predictores_imputados_escalados = escalador.fit_transform(df_predictores_imputado)

# %%
df_predictores_imputados_escalados = pd.DataFrame(X_predictores_imputados_escalados, columns = df_predictores_imputado.keys())

# %%
df_predictores_imputados_escalados.describe()
# Out:
#        Inside Temperature  Solar Radiation        Day ET  \
# count        1.067250e+05     1.067250e+05  1.067250e+05
# mean        -2.427675e-16     7.167124e-16  4.751500e-16
# std          1.000005e+00     1.000005e+00  1.000005e+00
# min         -2.450423e+00    -6.624335e-01 -9.564521e-01
# 25%         -7.516542e-01    -6.624335e-01 -9.564521e-01
# 50%         -7.214656e-02    -6.624335e-01 -3.649696e-01
# 75%          7.309080e-01     4.019429e-01  9.869902e-01
# max          2.923865e+00     3.822653e+00  2.071375e+00
#
#        10 Min Avg Wind Speed  Forecast Rule number    Wind Speed  \
# count           1.067250e+05          1.067250e+05  1.067250e+05
# mean            5.667573e-17         -1.312524e-15 -9.032685e-16
# std             1.000005e+00          1.000005e+00  1.000005e+00
# min            -1.632602e+00         -1.819696e+00 -1.214635e+00
# 25%            -9.741829e-01         -6.865172e-01 -7.145427e-01
# ...

# %%
df_predictores_imputados_escalados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106725 entries, 0 to 106724
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Inside Temperature       106725 non-null  float64
#  1   Solar Radiation          106725 non-null  float64
#  2   Day ET                   106725 non-null  float64
#  3   10 Min Avg Wind Speed    106725 non-null  float64
#  4   Forecast Rule number     106725 non-null  float64
#  5   Wind Speed               106725 non-null  float64
#  6   Forecast Icons           106725 non-null  float64
#  7   Year ET                  106725 non-null  float64
#  8   Time of Sunset           106725 non-null  float64
#  9   Time of Sunrise          106725 non-null  float64
#  10  CRC                      106725 non-null  float64
#  11  Next Record              106725 non-null  float64
#  12  Month ET                 106725 non-null  float64
# ...

# %% [markdown]
# # 5. Select a model and train it.

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(df_predictores_imputados_escalados.values, df_labels.values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17104\3794787049.py in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 lin_reg = LinearRegression()
# ----> 3 lin_reg.fit(df_predictores_imputados_escalados.values, df_labels.values)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# ...

# %% [markdown]
# # Búsqueda de el valor NaN o infinito

# %%
len(df_predictores_imputados_escalados) == len(df_labels)
# Out:
# True

# %%
df_labels.max()
# Out:
# 980.0

# %%
any(df_labels>'inf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7656\3676834020.py in <module>
# ----> 1 any(df_labels>'inf')
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5621
#    5622         with np.errstate(all="ignore"):
# ...

# %%
any([True, True])
# Out:
# True

# %%
df_predictores_imputados_escalados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106725 entries, 0 to 106724
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Inside Temperature       106725 non-null  float64
#  1   Solar Radiation          106725 non-null  float64
#  2   Day ET                   106725 non-null  float64
#  3   10 Min Avg Wind Speed    106725 non-null  float64
#  4   Forecast Rule number     106725 non-null  float64
#  5   Wind Speed               106725 non-null  float64
#  6   Forecast Icons           106725 non-null  float64
#  7   Year ET                  106725 non-null  float64
#  8   Time of Sunset           106725 non-null  float64
#  9   Time of Sunrise          106725 non-null  float64
#  10  CRC                      106725 non-null  float64
#  11  Next Record              106725 non-null  float64
#  12  Month ET                 106725 non-null  float64
# ...

# %% [markdown]
# 6. Fine-tune your model.
# 7. Present your solution.
# 8. Launch, monitor, and maintain your system.

# %% [markdown]
# ## Mapa conceptual de la clase elaborado en CMapTools

# %% [markdown]
# <img src = ''>

# %% [markdown]
# ## Tareas para realizar antes de la clase

# %% [markdown]
# 1. Ver los videos respectivos []()
# 2. Memorizar las definiciones []()
# 3. Sintetizar o resumir la información en mapas conceptuales. []()

# %% [markdown]
# # Tareas para realizar en clase

# %% [markdown]
# * Modelación matemática
# * Trabajo en equipos

# %% [markdown]
# # Tareas para realizar después de la realización de la clase

# %% [markdown]
# * Actividades de memorización:
#   - escucha reiterada de grabaciones de formulas y resultados científicos.
#   - relectura de notas.
#   - ejercicios de mayor complejidad.

# %% [markdown]
# ## Dificultades de aprendizaje detectados durante la clase

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# ## Cuestionario para realizar labores de memorización y observación,  a la síntesis de la información

# %% [markdown]
# ## Grabaciones en audio para fomentar la capacidad de memorizar enunciados de teoremas y resultados científicos y la capacidad de parafrasear estos resultados.

# %% [markdown]
# Se dispondrá de un lugar vocaroo.com para albergar los archivos de audio de fomento a la memorización, enunciación y parafraseo de los resultados científicos, propiedades, reglas, vocabulario en inglés, etc.
#
# * [Vocaroo](https://vocaroo.com/)

# %% [markdown]
# ### Comparta sus cuadernos y videos, evidencias de su aprendizaje [aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUMEMwTEZVMzEwVVBPTElWNVg5OVEyWUhMUy4u)

# %% [markdown]
# ## Mapa conceptual que vincula los conceptos asoaciados al objetivo de aprendizaje

# %% [markdown]
# <img src = ''>

# %% [markdown]
# ## Quiz de 10 minutos para ejercitación y adquisición de habilidades
#
# Los quieces, se propone realizarlos cada 6 horas de clase. Y que solo duren entre 10 minutos a 20 minutos.

# %% [markdown]
# 1. Importe los datos de la estación meteorologica Davis posicionada en la Seccional Bajo Cauca - Caucasia de la Universidad de Antioquia, correspondiente al periodo comprendido entre: fecha inicial : 2023-01-25 09:47:53; fecha final : 2023-05-25 10:00:00

# %% [markdown]
# 2.

# %% [markdown]
# 3.

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [stewart precálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ERHIq62I6qFNrmxy6LZb8ZMBci7kUsyNME1nIh9yCBMJ_w?e=0zMSla)
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
# * [uzcategui](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ETDikm-lVl1Or8XoEo9oyh0BEti9Zs8le-f0D-dBdtZmbA?e=bBsoyQ)
#
# * [pandas.DataFrame.plot()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.[Geron, Aurelien. Hands on Machine Learning](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Ecet27yjQzZIlT1Y_Bc2erkBUhbeYuIe6HG8i1FYZRlZww?e=dlvZ4v)
#
# * McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".[Wes Mackinney. ](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EVbi5JIeBl9ErbiUnZfGe8YBhNTnZ8sxTK5hjIOPK4UpGw?e=fFclah)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Conjeturas pedagógicas fruto de la aplicación del modelo de aprendizaje invertido y del enfoque hacia la ciencia de datos con python
#
# 1. Todo cálculo o resultado debe ser interpretado en una línea markdown del cuaderno Jupyter, inmediatamente después de la enunciación del resultado y después de la presentación de una tabla o gráfico bidimensional, de tal menera que el estudiante explicite la comprensión verbal del resultado y las inferencias o estrategias que este resultado le sugieren.

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado.
#
# Y a mi esposa Yasmira por su apoyo, orientación y acompañamiento.
