# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/10_pygame/blob/main/1_capitulo_instalar_pygame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## Booleanos

# %%
booleano = False

# %%
verdadero = True

# %%
falso = False

# %% [markdown]
# ## Inpresion de variables booleanas

# %%
print(verdadero)
# Out:
# True

# %%
print(falso)
# Out:
# False

# %% [markdown]
# Las variables y los datos de tipo booleano cobran sentido cuando vamos a hacer control de flujo
