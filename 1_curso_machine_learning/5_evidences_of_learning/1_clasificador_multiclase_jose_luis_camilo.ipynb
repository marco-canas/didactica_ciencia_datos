# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/10_evidences_of_learning/clasificador_multiclase_jose_luis_camilo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo ]()

# %% [markdown]
# ## [Vínculo al programa del curso en Machine Leaning y ciencia de datos:  ](https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/prop_invest/cartilla/cartilla.ipynb)

# %% [markdown]
# ## Cuaderno de Jose Luis Camilo

# %% [markdown]
# ## Clasificador multiclase

# %% [markdown]
# ### Librerías necesarias

# %%
#paso 1
import matplotlib.pyplot as plt

# %%
#paso 2
from sklearn.model_selection import StratifiedShuffleSplit

# %%
#paso 3
from sklearn.preprocessing import StandardScaler

# %%
#paso 4
from sklearn.linear_model import SGDClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import cross_val_predict

# %%
from sklearn.metrics import confusion_matrix

# %%
# paso 5  

from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Paso 1
#
# Visualice con función `imshow()` de matplotlib una de las imágenes del dataset.
