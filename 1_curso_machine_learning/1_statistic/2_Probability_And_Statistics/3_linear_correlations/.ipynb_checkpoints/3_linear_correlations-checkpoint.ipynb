# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/2_Probability_And_Statistics/3_linear_correlations/3_linear_correlations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo a la lectura interactiva y experimental de este cuaderno sobre correlaciones lineales](https://www.youtube.com/watch?v=ra0yWzwByiU)

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)
#
# ## Definición y características de este modelo

# %% [markdown]
# ## ¿Qué es?
#
# Flipped Learning o aprendizaje invertido es un enfoque pedagógico en el que:
#
# * la instrucción directa se realiza fuera del aula y
# * se utiliza el tiempo de clase para llevar a cabo actividades que impliquen el desarrollo de procesos cognitivos de mayor complejidad, en las que son necesarias la ayuda y la experiencia del docente.

# %% [markdown]
# ## ¿Para qué sirve?
#
# Mejora el proceso de enseñanza-aprendizaje realizando,
#
# * fuera del aula, actividades de aprendizaje sencillas (observar, memorizar, resumir, etc.) y,
# * en el aula, actividades más complejas (razonar, examinar, priorizar, argumentar, proponer, etc.) que requieren la interacción entre iguales y la ayuda del docente como facilitador.

# %% [markdown]
# Modelo pedagógico es el de [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)
#
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/2_Probability_And_Statistics/3_linear_correlations/atributos_aula_invertida.png?raw=true'>

# %% [markdown]
# ## Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas
#
# John Allen Paulos. El hombre anumérico. El analfabetismo matemático y sus consecuencias.
#
# "Las mates siempre fueron mi asignatura más floja."
#
# <<Un millón de dolares, >>

# %% [markdown]
# # Coeficiente de correlación de Person

# %% [markdown]
# ## Objetivo de aprendizaje

# %% [markdown]
# * Entender el concepto de correlación lineal de Pearson de la mano de Aurelien Geron.
# * aprender a usar el método `.corr()` de pandas para establecer correlaciones entre variables

# %% [markdown]
# ## [Vínculo al programa del curso:  ]()
#
# * Realizar la metodología del curso de ciencia de datos en imágenes

# %% [markdown]
# ## Metodología del curso de ciencia de datos y machine learningt en forma gráfica

# %% [markdown]
# # [Definición de coeficiente de correlación de Person](https://es.wikipedia.org/wiki/Coeficiente_de_correlaci%C3%B3n_de_Pearson)

# %% [markdown]
# En estadística, el coeficiente de correlación de Pearson es una medida de dependencia lineal entre dos variables aleatorias cuantitativas.

# %%
from ipywidgets import interact 
import numpy as np 

import matplotlib.pyplot as plt 
b = 0
def graficar_funcion_lineal(m = 1): 
    dominio = np.array([-12, 12]) # dias 
    rango = m*dominio + b  
    plt.plot(dominio, rango, color = 'blue')
    plt.axis([-12,12, -12,12])
    plt.grid(alpha = 0.4)
    
interact(graficar_funcion_lineal, m = (-1, 1, 1))    

plt.show()
# Out:
# interactive(children=(IntSlider(value=1, description='m', max=1, min=-1), Output()), _dom_classes=('widget-int…

# %% [markdown]
# A diferencia de la covarianza, la correlación de Pearson es independiente de la escala de medida de las variables.

# %% [markdown]
# De manera menos formal, podemos definir el coeficiente de correlación de Pearson como un índice que puede utilizarse para medir el grado de relación de dos variables, siempre y cuando ambas sean **cuantitativas y continuas**.

# %% [markdown]
# Incluir mapa conceptual de los tipos de variables.
#
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/2_Probability_And_Statistics/3_linear_correlations/imagenes/variable_aleatoria.jpg?raw=true'>

# %% [markdown]
# ## Para una muestra

# %% [markdown]
# El coeficiente de correlación de Pearson cuando es aplicado a una muestra, se suele denotar por $r_{xy}$ y se refiere a este como el coeficiente de correlación muestral o el coeficiente de correlación muestral de Pearson.

# %% [markdown]
# Dados $n$ pares de datos $\{(x_{i},y_{i})\}_{i=1}^{n}$, se define el coeficiente de correlación muestral de Pearson como
#
# $$ r_{xy} = \frac{\sum _{i=1}^{n}\left(x_{i}-{\bar {x}}\right)\left(y_{i}-{\bar {y}}\right)}{{\sqrt {\sum _{i=1}^{n}\left(x_{i}-{\bar {x}}\right)^{2}}}{\sqrt {\sum _{i=1}^{n}\left(y_{i}-{\bar {y}}\right)^{2}}}} $$
#
# donde
#
# * $n$ es el tamaño de la muestra.
# * $x_{i} , y_{i}$ son puntos muestrales individuales indexados con $i$.
# * $\bar{x}$ denota la media muestral definida por
#
# $$ \bar{x} = \frac{1}{n}\sum_{i = 1}^{n}x_{ i}.$$

# %% [markdown]
# # Tarea de clase: para realizar en equipos bajo la metodología de desarrollo creciente
#
# ## Experimentación o lectura experimental e interactiva de la fórmula de definición del coeficiente de correlación

# %%
def toggle_cell_code(button_id):
    """
    Adds a button to toggle (show/hide) the code cell but not the output. 
    
    Parameters
    ----------
    button_id : str
        An identifier for cells that will hide/show when button is pressed.
    """
    
    from IPython.display import display_html
    my_html = '''
    <button type="button" id="%s" onclick="code_toggle('%s')">Codigo</button>
    <script>
    function code_toggle(my_id) {
        // get the parent element for the cell code and output
        var p = $("#"+my_id);
        if (p.length==0) return;
        while (!p.hasClass("cell")) {
            p = p.parent();
            if (p.prop("tagName") =="body") return;
        }
    // get the cell code and toggle its value
    var cell_code = p.find(".input");
    cell_code.toggle();
    }
    </script>
    ''' %(button_id, button_id)
    return display_html(my_html, raw=True)

# %%
toggle_cell_code("Función respuesta de la tarea")

def calcular_correlacion(variable_x, variable_y):
    media_x = np.mean(variable_x)
    media_y = np.mean(variable_y)
    desviaciones_x = variable_x - media_x
    desviaciones_y = variable_y - media_y
    producto_desviaciones = desviaciones_x*desviaciones_y
    suma_productos_desviaciones = np.sum(producto_desviaciones)
    # lo de abajo
    cuadrado_desviaciones_x = desviaciones_x**2
    cuadrado_desviaciones_y = desviaciones_y**2
    suma_cuadrado_desviaciones_x = np.sum(cuadrado_desviaciones_x)
    suma_cuadrado_desviaciones_y = np.sum(cuadrado_desviaciones_y)
    raiz_suma_cuadrado_desviaciones_x = np.sqrt(suma_cuadrado_desviaciones_x)
    raiz_suma_cuadrado_desviaciones_y = np.sqrt(suma_cuadrado_desviaciones_y)
    producto_raiz_jerson = raiz_suma_cuadrado_desviaciones_x*raiz_suma_cuadrado_desviaciones_y
    # division
    coeficiente_correlacion = suma_productos_desviaciones/producto_raiz_jerson
    return coeficiente_correlacion
# Out:
#     <button type="button" id="Función respuesta de la tarea" onclick="code_toggle('Función respuesta de la tarea')">Codigo</button>
#     <script>
#     function code_toggle(my_id) {
#         // get the parent element for the cell code and output
#         var p = $("#"+my_id);
#         if (p.length==0) return;
#         while (!p.hasClass("cell")) {
#             p = p.parent();
#             if (p.prop("tagName") =="body") return;
#         }
#     // get the cell code and toggle its value
#     var cell_code = p.find(".input");
#     cell_code.toggle();
#     }
#     </script>

# %% [markdown]
# ## Generación de variables aleatorias y llamado a la función de cálculo de correlaciones

# %%
import numpy as np 
edades = np.array([21, 21, 26])
estaturas = np.array([1.68, 1.59, 1.78])
calcular_correlacion(edades, estaturas )
# Out:
# 0.8808122718846415

# %% [markdown]
# # Visualizamos las variables aleatorias creadas

# %%
import matplotlib.pyplot as plt 

plt.scatter(edades, estaturas, color = 'red')

plt.grid(alpha = 0.4)

# %% [markdown]
# # Ejemplo de correlaciones lineales
#
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/2_Probability_And_Statistics/3_linear_correlations/corralation_examples.png?raw=true'>

# %% [markdown]
# # Looking for the correlations

# %% [markdown]
# Since the dataset is not too large, you can easily compute the standard correlation coefficient (also called Pearson’s r) between every pair of attributes using the `corr()` method:

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/marco-canas/7_didactica_ciencia_datos/main/datasets/vivienda/vivienda.csv'
v = pd.read_csv(url)
v.head() 
# tomado de https://github.com/ageron/handson-ml/blob/master/02_end_to_end_machine_learning_project.ipynb
# Out:
#    longitud  latitud  antiguedad  habitaciones  dormitorios  población  \
# 0   -122.23    37.88        41.0         880.0        129.0      322.0
# 1   -122.22    37.86        21.0        7099.0       1106.0     2401.0
# 2   -122.24    37.85        52.0        1467.0        190.0      496.0
# 3   -122.25    37.85        52.0        1274.0        235.0      558.0
# 4   -122.25    37.85        52.0        1627.0        280.0      565.0
#
#    hogares  ingresos proximidad    precio
# 0    126.0    8.3252   NEAR BAY  452600.0
# 1   1138.0    8.3014   NEAR BAY  358500.0
# 2    177.0    7.2574   NEAR BAY  352100.0
# 3    219.0    5.6431   NEAR BAY  341300.0
# 4    259.0    3.8462   NEAR BAY  342200.0

# %%
corr_matrix = v.corr()  # utilizando en esta el dataset de Housing para construir la matriz de correlaciones

# %%
corr_matrix
# Out:
#               longitud   latitud  antiguedad  habitaciones  dormitorios  \
# longitud      1.000000 -0.924664   -0.108197      0.044568     0.069608
# latitud      -0.924664  1.000000    0.011173     -0.036100    -0.066983
# antiguedad   -0.108197  0.011173    1.000000     -0.361262    -0.320451
# habitaciones  0.044568 -0.036100   -0.361262      1.000000     0.930380
# dormitorios   0.069608 -0.066983   -0.320451      0.930380     1.000000
# población     0.099773 -0.108785   -0.296244      0.857126     0.877747
# hogares       0.055310 -0.071035   -0.302916      0.918484     0.979728
# ingresos     -0.015176 -0.079809   -0.119034      0.198050    -0.007723
# precio       -0.045967 -0.144160    0.105623      0.134153     0.049686
#
#               población   hogares  ingresos    precio
# longitud       0.099773  0.055310 -0.015176 -0.045967
# latitud       -0.108785 -0.071035 -0.079809 -0.144160
# antiguedad    -0.296244 -0.302916 -0.119034  0.105623
# ...

# %%
corr_matrix.values
# Out:
# array([[ 1.        , -0.92466443, -0.10819681,  0.04456798,  0.06960802,
#          0.09977322,  0.05531009, -0.01517587, -0.04596662],
#        [-0.92466443,  1.        ,  0.01117267, -0.0360996 , -0.06698283,
#         -0.10878475, -0.07103543, -0.07980913, -0.14416028],
#        [-0.10819681,  0.01117267,  1.        , -0.3612622 , -0.32045104,
#         -0.29624424, -0.30291601, -0.11903399,  0.10562341],
#        [ 0.04456798, -0.0360996 , -0.3612622 ,  1.        ,  0.9303795 ,
#          0.85712597,  0.91848449,  0.19804965,  0.13415311],
#        [ 0.06960802, -0.06698283, -0.32045104,  0.9303795 ,  1.        ,
#          0.87774674,  0.97972827, -0.00772285,  0.04968618],
#        [ 0.09977322, -0.10878475, -0.29624424,  0.85712597,  0.87774674,
#          1.        ,  0.90722227,  0.00483435, -0.02464968],
#        [ 0.05531009, -0.07103543, -0.30291601,  0.91848449,  0.97972827,
#          0.90722227,  1.        ,  0.01303305,  0.06584265],
# ...

# %%
corr_matrix.keys()
# Out:
# Index(['longitud', 'latitud', 'antiguedad', 'habitaciones', 'dormitorios',
#        'población', 'hogares', 'ingresos', 'precio'],
#       dtype='object')

# %% [markdown]
# # Trazo de la matriz de correlaciones con `matplotlib.pyplot.imshow()`

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt

attributes = corr_matrix.keys() # obtención de los nombres de las variables 

matriz_correlaciones_numpy = np.round(corr_matrix.values,2)

fig, ax = plt.subplots(figsize = (13,13))

im = ax.imshow(matriz_correlaciones_numpy) # la función imshow() visualiza matrices como mapas de calor. 

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(attributes)), labels=attributes)
ax.set_yticks(np.arange(len(attributes)), labels=attributes)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(attributes)):
    for j in range(len(attributes)):
        text = ax.text(j, i, matriz_correlaciones_numpy[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Correlaciones en el dataset de Vivienda")
fig.tight_layout()

plt.savefig('correlaciones_como_mapa_calor.jpg')
plt.show()

# https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html

# %% [markdown]
# Now let’s look at how much each attribute correlates with the median house value:

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %% [markdown]
# The correlation coefficient ranges from –1 to 1.

# %% [markdown]
# When it is close to 1, it means that there is a strong positive correlation; for example, the median house value tends to go up when the median income goes up.

# %% [markdown]
# When the coefficient is close to –1, it means that there is a strong negative correlation; you can see a small negative correlation between the latitude and the median house value (i.e., prices have a slight tendency to go down when you go north).

# %% [markdown]
# Finally, coefficients close to 0 mean that there is no linear correlation.

# %% [markdown]
# Figure 2-14 shows various plots along with the correlation coefficient between their horizontal and vertical axes.

# %% [markdown]
# # Ejemplo de correlaciones lineales
#
# <img src = 'https://github.com/marco-canas/7_didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/2_Probability_And_Statistics/3_linear_correlations/corralation_examples.png?raw=true'>

# %% [markdown]
# ## WARNING

# %% [markdown]
# The correlation coefficient only measures linear correlations (“if $x$ goes up, then $y$ generally goes up/down”).

# %% [markdown]
# It may completely miss out on nonlinear relationships (e.g., “if $x$ is close to 0, then $y$ generally goes up”).

# %% [markdown]
# Note how all the plots of the bottom row have a correlation coefficient equal to 0, despite the fact that their axes are clearly not independent: these are examples of nonlinear relationships.

# %% [markdown]
# Also, the second row shows examples where the correlation coefficient is equal to 1 or –1; notice that this has nothing to do with the slope. For
# example, your height in inches has a correlation coefficient of 1 with your height in feet or in
# nanometers.

# %% [markdown]
# Another way to check for correlation between attributes is to use the pandas `scatter_matrix()` function, which plots every numerical attribute against every other numerical attribute.

# %% [markdown]
# Since there are now 11 numerical attributes,
# you would get 11 = 121 plots, which would not fit on a page—so let’s just
# focus on a few promising attributes that seem most correlated with the median
# housing value (Figure 2-15):

# %%
housing.keys() # obtener las claves o lñlaves de acceso a la información
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt 
from pandas.plotting import scatter_matrix
attributes = ["median_house_value", "median_income", "total_rooms", "housing_median_age", 'latitude']
scatter_matrix(housing[attributes], figsize=(12, 8))

plt.savefig('scatter_matrix.png')

plt.show()

# %% [markdown]
# The main diagonal (top left to bottom right) would be full of straight lines if pandas plotted each variable against itself, which would not be very useful.

# %% [markdown]
# So instead pandas displays a histogram of each attribute (other options are available; see the pandas documentation for more details).

# %% [markdown]
# The most promising attribute to predict the median house value is the median income, so let’s zoom in on their correlation scatterplot (Figure 2-16):

# %%
housing.plot(kind="scatter", x="median_income", y="median_house_value",
alpha=0.1)
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='median_house_value'>

# %% [markdown]
# This plot reveals a few things. First, the correlation is indeed very strong; you can clearly see the upward trend, and the points are not too dispersed.

# %% [markdown]
# Second, the price cap that we noticed earlier is clearly visible as a horizontal line at $500,000. But this plot reveals other less obvious straight lines: a horizontal line around $450,000, another around $350,000, perhaps one around $280,000,
# and a few more below that.

# %% [markdown]
# You may want to try removing the corresponding districts to prevent your algorithms from learning to reproduce these data
# quirks.

# %% [markdown]
# ## Experimentando con combinaciones de atributos

# %% [markdown]
# Hopefully the previous sections gave you an idea of a few ways you can explore the data and gain insights.

# %% [markdown]
# You identified a few data quirks that you may want to clean up before feeding the data to a Machine Learning algorithm,
# and you found interesting correlations between attributes, in particular with the target attribute.

# %% [markdown]
# You also noticed that some attributes have a tail-heavy distribution, so you may want to transform them (e.g., by computing their logarithm).

# %% [markdown]
# Of course, your mileage will vary considerably with each project, but the general ideas are similar.

# %% [markdown]
# One last thing you may want to do before preparing the data for Machine Learning algorithms is to try out various attribute combinations.

# %% [markdown]
# For example, the total number of rooms in a district is not very useful if you don’t know how
# many households there are.

# %% [markdown]
# What you really want is the number of rooms per household.

# %% [markdown]
# Similarly, the total number of bedrooms by itself is not very useful:
#
# you probably want to compare it to the number of rooms.

# %% [markdown]
# And the population per household also seems like an interesting attribute combination to look at.

# %% [markdown]
# Let’s create these new attributes:

# %%
housing["rooms_per_household"] = housing["total_rooms"]/housing["households"]
housing["bedrooms_per_room"] = housing["total_bedrooms"]/housing["total_rooms"]
housing["population_per_household"]=housing["population"]/housing["households"]

# %% [markdown]
# And now let’s look at the correlation matrix again:

# %%
corr_matrix = housing.corr()
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value          1.000000
# median_income               0.688075
# rooms_per_household         0.151948
# total_rooms                 0.134153
# housing_median_age          0.105623
# households                  0.065843
# total_bedrooms              0.049686
# population_per_household   -0.023737
# population                 -0.024650
# longitude                  -0.045967
# latitude                   -0.144160
# bedrooms_per_room          -0.255880
# Name: median_house_value, dtype: float64

# %% [markdown]
# Hey, not bad! The new bedrooms_per_room attribute is much more correlated with the median house value than the total number of rooms or bedrooms.

# %% [markdown]
# Apparently houses with a lower bedroom/room ratio tend to be more expensive.

# %% [markdown]
# The number of rooms per household is also more informative than the total number of rooms in a district—obviously the larger the houses, the more expensive they are.

# %% [markdown]
# Esta ronda de exploración no tiene que ser absolutamente minuciosa; el punto es comenzar con el pie derecho y obtener rápidamente información que lo ayudará a obtener un primer prototipo razonablemente bueno.

# %% [markdown]
# Pero este es un proceso iterativo: una vez que tiene un prototipo en funcionamiento, puede analizar su resultado para obtener más información y volver a este paso de exploración.

# %% [markdown]
# ## Tareas para antes de la clase

# %% [markdown]
# Leer todo sobre el concepto estadístico de correlación lineal.

# %% [markdown]
# ## Tareas para después de clase

# %% [markdown]
# * Exploremos las correlaciones entre las variables cuantitativas continuas de ancho y largo de sépalo y pétalo en el dataset de florez de iris.

# %% [markdown]
# ## Solución de la tarea

# %%
from sklearn.datasets import load_iris
X,y = load_iris(return_X_y = True, as_frame = True) 
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Vocabulary
#
# 1. squared root (sqrt): raíz cuadrada.

# %% [markdown]
# ## Referentes
#
# * [ageron](https://github.com/ageron/handson-ml3/blob/main/02_end_to_end_machine_learning_project.ipynb) Capítulo 2 de Hands on Machine Learning with sklearn and tensorflow and Keras
#
# * Definición de wiki de correlación de pearson: https://es.wikipedia.org/wiki/Coeficiente_de_correlaci%C3%B3n_de_Pearson
#
# * dataset de datos de housing tomado de: https://github.com/ageron/handson-ml/blob/master/02_end_to_end_machine_learning_project.ipynb
#
# * tarfile module of python: https://docs.python.org/3/library/tarfile.html
#
# * [`pandas.DataFrame.corr()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html)
#
# * [`matplotlib.pyplot.heatmap()`](https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html)
#
# * [correlaciones lineales en wikipedia:](https://es.wikipedia.org/wiki/Coeficiente_de_correlaci%C3%B3n_de_Pearson)
#
# * [Recomendaciones de la Unesco sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [Comunicación no violenta en tu hogar y en el aula de clases](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Efb_5fC50D5JnA4BzTKzgsIB9UeMjgs1kCU-sROZDlWTGw?e=BbFOPc)
#
# * [economipedia](https://economipedia.com/definiciones/variable-aleatoria.html)

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Reflexionemos sobre la comunicación no violenta en nuestros hogares y en nuestro trabajo.
