# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/1_Basic_Descriptive_Statistics/1_medidas_tendencia_central/1_media.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Video de apoyo a la lectura interactiva y experimental de este cuaderno](https://www.youtube.com/watch?v=V9ikhkgm8ag)
#
# ## [Segundo video de apoyo a la lectura interactiva de este cuaderno](https://www.youtube.com/watch?v=2RXc920iTus)

# %% [markdown]
# # Medidas de tendencia central - La media

# %% [markdown]
# El modelo pedagógico que sustenta esta propuesta de Unidad didáctica para la enseñanza de la ciencia de datos es el de [Flipped Learning](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/files/2018/11/flipped-classroom.pdf) o de aprendizaje investido.

# %% [markdown]
# ### Metodología para la clase sobre la media como estadístico importante para un científico de datos
#
# 1. exploración de presaberes: listas, tuples, tipos de datos, acceso a los datos.
# 2. Definir una función de usuario de Python que calcule la media de un conjunto de datos.
# 3. determinar la media con la librería NumPy a interpretarla.
# 4. Determinar la media con la librería scipy
# 5. Determinar la media con el módulo statistics
# 6. Realizar la tarea de fijación de conceptos y adquisición de habilidades
# 7. Realizar la evaluación de conceptos ganados y habilidades adquiridas.
# 8. Hacer la autoevaluación.

# %% [markdown]
# ## Elementos previos o conceptos previos.

# %% [markdown]
# * Listas y tuplas de python
# * Funciones incorporadas de python
# * Funciones de usuario de python

# %% [markdown]
# ## Creación de listas

# %% [markdown]
# ### Secuencia de creación de una lista de datos
#
# 1. Cree una variable con el nombe del tipo de datos que albergará la lista
# 2. Recuerde que la lista es una estructura delimitada por corchetes y cuyos elementos se separan por comas.

# %%
edades = [14, 48, 73]
estaturas = [1.66, 1.65, 1.60]

# %%
type(edades), type(estaturas)
# Out:
# (list, list)

# %%
type(edades[0]), type(estaturas[0])
# Out:
# (int, float)

# %%
edades = [19, 20, 21]

# %% [markdown]
# ## Acceso a los datos de una lista

# %%
edades[2] # se accede a los datos en una lista a través de la notación de corchetes
# y cada uno de los elementos de la lista tiene asociado un indice para cada posición.
# Out:
# 21

# %%
estaturas[2]
# Out:
# 1.6

# %% [markdown]
# ## creación de tuplas

# %%
edades_tupla = (14, 48, 73)
estaturas_tuplas = (1.66, 1.65, 1.60)

# %% [markdown]
# ## Acceso a los datos de una tupla de Python

# %%
edades[0]
# Out:
# 14

# %%
estaturas[2]
# Out:
# 1.6

# %% [markdown]
# ## Definición de media o promedio de una cantidad de datos cuantitatuva discreta o continua.

# %% [markdown]
# $$ \bar{x} = \frac{\sum x_{i}}{n} $$

# %% [markdown]
# ## Funciones incorporadas

# %%
edades
# Out:
# [14, 48, 73]

# %%
sum(edades)
# Out:
# 135

# %%
len(edades)
# Out:
# 3

# %%
media = sum(edades)/len(edades) 
media
# Out:
# 45.0

# %%
tupla2 = (1,2,3)

# %%
sum(tupla2)
# Out:
# 6

# %%
len(estaturas)
# Out:
# 3

# %% [markdown]
# ## Funciones definidas por el usuario

# %%
def calcula_media(datos):
    suma = sum(datos)
    longitud = len(datos)
    return suma/longitud

# %%
calcula_media(edades)
# Out:
# 45.0

# %%
import numpy as np

# %%
edades_array = np.array(edades)

# %%
type(edades_array)
# Out:
# numpy.ndarray

# %%
np.mean(edades_array)
# Out:
# 20.0

# %% [markdown]
# # Calcular la media con scipy

# %%
import scipy
import numpy

# %%
numpy.mean(edades_array)
# Out:
# 20.0

# %% [markdown]
# # Calculo de la media con el módulo statistics

# %%
import statistics

# %%
type(statistics.mean(edades_array))
# Out:
# numpy.int32

# %% [markdown]
# 1. Mean

# %% [markdown]
# * Cómo se define
# * Ejemplos ilustrativos.
# * Visualización de esta medida de tendencia central
# * Cómo se interpreta.

# %%
def calcule_media(numeros):
    return sum(numeros)/len(numeros)

# %%
calcule_media(edades)
# Out:
# 20.0

# %%
calcule_media(estaturas)
# Out:
# 1.7

# %% [markdown]
# Creación de una función de media personalizada
#
# Comencemos calculando la edad promedio (media) de los jugadores de un equipo de baloncesto. El nombre del equipo será "Pythonic Machines".

# %%
team_ages = [19, 20, 21]

# %%
def promedio_de_edades(lista_edades):
    return sum(lista_edades)/len(lista_edades)

# %%
promedio_de_edades(team_ages)
# Out:
# 20.0

# %%
def mean(dataset):
    return sum(dataset) / len(dataset)

print(mean(pythonic_machine_ages))
# Out:
# 26.375

# %% [markdown]
# Desglosando este código:
#
# * "ages" es una lista con las edades de los jugadores de baloncesto
# * Definimos una función `media()` que devuelve la suma del conjunto de datos dado dividido por su longitud
# * Los `sum()` La función devuelve la suma total (irónicamente) de los valores de un iterable, en este caso, una lista. Intente pasar el conjunto de datos como argumento, devolverá 211
# * Los `len()` La función devuelve la longitud de un iterable, si le pasa el conjunto de datos obtendrá 8
# * Pasamos las edades del equipo de baloncesto al `media()` función e imprimir el resultado.
#
# Si verifica la salida, obtendrá:

# %% [markdown]
# ## Tareas de fijación de los conceptos vistos y de adquisición de habilidades.

# %% [markdown]
# 1. Importe el dataset de florez de iris y determine el promedio o media por atributos. Y realizar las interpretacionesde estos estadísticos.
# 2. Luego determine la media o promedio de los cuatro atributos para cada especie de flor de Iris.

# %% [markdown]
# ## Solución de la tarea de fijación y adquisición de habilidades

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris(as_frame = False)

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
X = iris.data

# %%
y = iris.target

# %%
X.shape
# Out:
# (150, 4)

# %%
len(np.mean(X, axis = 0)) # cacule media por columnas
# Out:
# 4

# %% [markdown]
# Interpretaciones
#
# 1. la media de las longitudes de sepalo en este dataset de florez de iris es 5.84.
# 2. la media de las anchos de sepalo de las flores en este dataset es de 3.057.

# %% [markdown]
# ## Evaluación

# %% [markdown]
# 1. Importe el dataset housing del capítulo 2 de Geron y determine la media de cada una de las variables cuantitativas continuas presentes en este dataset.

# %% [markdown]
# ## solución de la evaluación

# %%
import pandas as pd

# %%
pd.read_csv('housing.csv').describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# La edad promedio de las casas en los 20640 distritos es de $28.63$

# %%
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request

def load_housing_data():
    tarball_path = Path("datasets/housing.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
        with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path="datasets")
    return pd.read_csv(Path("datasets/housing/housing.csv"))

housing = load_housing_data()

# %%
X = housing.values

# %%
X[:,2].mean()
# Out:
# 28.639486434108527

# %% [markdown]
# ## Tareas para realizar en casa

# %% [markdown]
# ## Tareas para realizar durante la clase

# %% [markdown]
# Realiza las actividades (debates, exposiciones orales, informes,
# diario de aprendizaje, cuaderno de trabajo cooperativo,...).
# Recibe retroalimentación inmediata del/la docente y de sus
# compañeros y compañeras.
# Accede, si fuera necesario, a las actividades previas facilitadas
# por el/la docente.

# %% [markdown]
# * Entre la media y la madiana, cuál consideras como mejor medida de tenmdencia central y por qué?

# %% [markdown]
# ## Evaluación

# %% [markdown]
# ## Reflexiones y autoevaluación derivada de la realización de las tareas y la evaluación propuesta.

# %% [markdown]
# Los datos generalmente vienen contenidos en una estructura de datos llamada nbarray de NumPy, es decir, vienen como grandes matrices. Y es por esto que el parátro axis de la función np.mean() cobra mucho valor.

# %% [markdown]
# ## Referentes

# %% [markdown]
# * Medidas de tendencia central con python: https://geekflare.com/es/python-find-mean-median-and-mode/
#
# * documentación de la función scipy.stats.mean(): https://www.geeksforgeeks.org/scipy-stats-mean-function-python/
#
# * sobre la obtención del dataset de housing: https://github.com/ageron/handson-ml3/blob/main/02_end_to_end_machine_learning_project.ipynb

# %% [markdown]
# ### [Continue la secuencia de enseñanza a través de este vínculo](https://github.com/marco-canas/didactica_ciencia_datos/blob/main/propuesta/unidad_didac/1_statistic/1_Basic_Descriptive_Statistics/1_medidas_tendencia_central/2_mediana.ipynb)
