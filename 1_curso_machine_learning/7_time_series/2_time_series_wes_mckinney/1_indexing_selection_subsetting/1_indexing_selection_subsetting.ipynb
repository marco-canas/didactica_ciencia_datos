# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/1_curso_machine_learning/8_time_series/curso_corto_series_tiempo/2_time_series_wes_mckinney/1_indexing_selection_subsetting/1_indexing_selection_subsetting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ### [Video de apoyo a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# ## [Vínculo al programa del curso:  ]()

# %% [markdown]
# Un reconocimiento a mis estudiantes que han construido conmigo este saber pedagógico:
#
# <img src = ''>

# %% [markdown]
# # Llamar a lista o tomar asistencia con python o llamar el equipo para la tarea con video y cuaderno Jupyter sobre medición indirecta de grandes alturas con imágenes

# %%
import pandas as pd
import random

# Cargar la lista de estudiantes desde la URL
url = 'https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_diferencial.csv'
estudiantes = pd.read_csv(url)

# Función para llamar a un estudiante aleatoriamente y registrar su nota de seguimiento
def llamar_estudiante():
    estudiante_aleatorio = random.choice(estudiantes['Nombre'])
    print(f"Llamando a {estudiante_aleatorio}...")
    
    
# Llamar a la función para realizar el proceso
llamar_estudiante()

# %% [markdown]
# # Modelo general de clase: [aula invertida](https://www3.gobiernodecanarias.org/medusa/ecoescuela/pedagotic/aprendizaje-invertido-flipped-classroom/)

# %% [markdown]
# ## Fomento de la lectura literaria asociada a Ingeniería agropecuaria y licenciatura en Matemáticas
#
#
# [MARSHALL ROSENBERG](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Efb_5fC50D5JnA4BzTKzgsIB9UeMjgs1kCU-sROZDlWTGw?e=gjRMdZ)

# %% [markdown]
# * forma parte intrínseca de nuestra naturaleza sentirnos satisfechos cuando damos y recibimos algo de manera compasiva o solidaria,
# * hay dos preguntas que me han preocupado durante la mayor parte de mi vida.

# %% [markdown]
# ¿Qué ocurre que nos desconecta de nuestra naturaleza solidaria y nos lleva a comportarnos de manera violenta y abusiva?

# %% [markdown]
#  Y a la inversa, ¿por qué algunas personas son consecuentes con esta actitud solidaria incluso en las circunstancias más adversas?

# %% [markdown]
# Desde aquel verano del año 1943, he estado analizando las dos preguntas que a lo largo de este libro, como en toda su obra sobre comunicación no violenta, Marshall Rosenberg utiliza con frecuencia el término "compasión".

# %% [markdown]
# Lo hace apelando al profundo impulso de humanidad común que existe en los seres humanos cuando nos comunicamos sin violencia.

# %% [markdown]
# # Los juicios moralistas

# %% [markdown]
# Un tipo de comunicación que aliena de la vida es aquél en el que empleamos juicios moralistas que presuponen una actitud errónea o malvada por parte de aquellas personas que no actúan de acuerdo con nuestros valores.

# %% [markdown]
# Estos juicios se reflejan en comentarios como:
#
# * «Tu problema es que eres muy egoísta»,
# * «Es una perezosa»,
# * «Están llenos de prejuicios»,
# * «Esto es inapropiado».
#
# Echar la culpa a alguien, insultarlo, rebajarlo, ponerle etiquetas, criticarlo, establecer comparaciones y emitir diagnósticos son distintas maneras de formular juicios.

# %% [markdown]
# Sin embargo, la comunicación que nos aliena de la vida nos atrapa en un mundo de ideas preconcebidas con respecto a lo que está bien y lo que está mal, un mundo hecho de juicios.

# %% [markdown]
# Emplea un lenguaje en el que abundan las palabras que establecen clasificaciones y dicotomías con respecto a las personas y a sus formas de actuar.

# %% [markdown]
# Cuando utilizamos este lenguaje juzgamos a los demás y su comportamiento y nos centramos en quién es bueno, malo, normal, anormal, responsable, irresponsable, inteligente, ignorante, etcétera.

# %% [markdown]
# Estas formas de comunicación nos alienan de nuestro estado natural de compasión o solidaridad.

# %% [markdown]
# En el mundo de los juicios
# nuestra preocupación se
# centra en quién “es” qué.

# %% [markdown]
# Mucho antes de llegar a la edad adulta, aprendí a comunicarme con los demás de una manera impersonal en la que no necesitaba revelar lo que me estaba pasando internamente.

# %% [markdown]
# Cada vez que me encontraba con personas o hechos que no me gustaban o no comprendía, mi reacción consistía en dictaminar que los equivocados eran ellos.

# %% [markdown]
# Cuando mis maestros me encomendaban una tarea que yo no tenía ganas de hacer, se convertían a mis ojos en unos «pesados» o unos «imbéciles».

# %% [markdown]
# Cuando estaba manejando y alguien me pasaba por delante, yo reaccionaba llamándolo «idiota».

# %% [markdown]
# Siempre que empleamos este lenguaje, pensamos y nos comunicamos desde la perspectiva de que algo falla en los demás porque se comportan de una determinada manera o, a veces, de que algo falla en nosotros porque no comprendemos o no respondemos como nos gustaría.

# %% [markdown]
# Centramos nuestra atención en clasificar, analizar y determinar niveles de error más que en lo que necesitamos (nosotros y los demás) y no conseguimos.

# %% [markdown]
# En consecuencia, si mi pareja quiere más cariño del que yo le ofrezco, es una persona «dependiente y desvalida».

# %% [markdown]
# Pero si yo quiero más cariño que el que ella me da, es «distante e insensible».

# %% [markdown]
# Si mi compañero de trabajo se preocupa más que yo por los detalles, es «quisquilloso y compulsivo».

# %% [markdown]
# En cambio, si soy yo quien se preocupa más por los detalles, él es «descuidado y desorganizado».

# %% [markdown]
# Creo que este tipo de análisis de otros seres humanos no es más que una trágica expresión de nuestros propios valores y necesidades.

# %% [markdown]
# Trágica porque, cuando expresamos nuestros valores y necesidades de esta manera, lo único que conseguimos es potenciar una actitud defensiva y de resistencia en las mismas personas cuya conducta nos molesta.

# %% [markdown]
# Y si aceptan actuar en consonancia con nuestra escala de valores porque coinciden en nuestro análisis de su ineptitud, es probable que sólo lo hagan por miedo, culpa o vergüenza.

# %% [markdown]
# Sin embargo, cuando los demás acceden a actuar de acuerdo con nuestros valores y necesidades, no porque lo deseen de corazón, sino porque tienen miedo o se sienten culpables o avergonzados, el precio que nos toca pagar es realmente muy alto.

# %% [markdown]
# Tarde o temprano vendrán las consecuencias bajo la forma de una falta de buena voluntad por parte de aquellos que responden a nuestros deseos por coerción externa o interna.

# %% [markdown]
# Por otro lado, cuando alguien hace algo por miedo, culpa o vergüenza, también paga un precio de tipo emocional, ya que abrigará un resentimiento contra nosotros al quedar rebajada su autoestima.

# %% [markdown]
# Además, cada
# vez que otras personas nos asocien con cualquiera de estos sentimientos, disminuirá la probabilidad de que en el futuro respondan de una manera solidaria a nuestras necesidades y nuestros valores.

# %% [markdown]
# ## Título de la clase: Indexing, selection, subsetting

# %% [markdown]
# ### Objetivo de aprendizaje (Enunciar, de manera corta sencilla y clara para todos los asistentes)
#
# * Con datos de series de tiempo de cambios bursátiles, aprender a acceder a los datos en un dataframe que representa una serie de tiempo.

# %% [markdown]
# ## Cuestionario para realizar labores de memorización, observación y síntesis de la información (Además de diagnóstico)
#
# ### cuestionario de diagnóstico sobre indexación, selección y segmentación de series temporales con Pandas en Python.

# %% [markdown]
# Incluí las respuestas para que puedas evaluar el conocimiento de los estudiantes.
#
# Recuerda que este cuestionario es de nivel introductorio y puede necesitar ajustes según el nivel de la clase.

# %% [markdown]
# ### Cuestionario de Diagnóstico: Indexación, Selección y Subconjuntos de Series Temporales con Pandas en Python

# %% [markdown]
# 1. **¿Qué es Pandas y cuál es su función principal en el análisis de datos en Python?**
#    - A) Un lenguaje de programación.
#    - B) Una librería de manipulación y análisis de datos.
#    - C) Un entorno de desarrollo integrado.
#
#    **Respuesta: B) Una librería de manipulación y análisis de datos.**

# %% [markdown]
# 2. **En Pandas, ¿qué es un DataFrame y cómo se relaciona con una serie temporal?**
#    - A) Un tipo de gráfico.
#    - B) Una estructura de datos bidimensional, similar a una tabla, y se puede utilizar para almacenar series temporales.
#    - C) Un formato de archivo para datos temporales.

# %% [markdown]
#    **Respuesta: B) Una estructura de datos bidimensional, similar a una tabla, y se puede utilizar para almacenar series temporales.**

# %% [markdown]
# 3. **¿Cómo se puede leer un archivo CSV que contiene datos temporales en Pandas?**
#    - A) `pd.load_csv()`
#    - B) `pd.read_excel()`
#    - C) `pd.read_csv()`

# %% [markdown]
#    **Respuesta: C) `pd.read_csv()`**

# %% [markdown]
# 4. **¿Qué es un índice en una serie temporal y por qué es importante?**
#    - A) Es el valor medio de la serie.
#    - B) Es un identificador único para cada punto de datos y facilita la manipulación y análisis de datos temporales.
#    - C) Es el primer valor de la serie.

# %% [markdown]
#    **Respuesta: B) Es un identificador único para cada punto de datos y facilita la manipulación y análisis de datos temporales.**

# %% [markdown]
# 5. **¿Cómo seleccionar todas las filas de una serie temporal entre las fechas '2022-01-01' y '2022-02-01' utilizando Pandas?**
#    - A) `df['2022-01-01':'2022-02-01']`
#    - B) `df.loc['2022-01-01':'2022-02-01']`
#    - C) `df.select('2022-01-01':'2022-02-01')`
#
#    **Respuesta: A) `df['2022-01-01':'2022-02-01']`**

# %% [markdown]
# 6. **¿Qué función se utiliza para realizar una agregación temporal, por ejemplo, obtener la media diaria de una serie temporal en Pandas?**
#    - A) `df.aggregate()`
#    - B) `df.resample()`
#    - C) `df.mean()`
#
#    **Respuesta: B) `df.resample()`**

# %% [markdown]
# 7. **¿Cuál es la diferencia entre `loc` y `iloc` en Pandas en el contexto de la selección de datos?**
#    - A) `loc` se utiliza para seleccionar por etiquetas, mientras que `iloc` se utiliza para seleccionar por índices enteros.
#    - B) `iloc` se utiliza para seleccionar por etiquetas, mientras que `loc` se utiliza para seleccionar por índices enteros.
#    - C) No hay diferencia, se pueden usar indistintamente.
#
#    **Respuesta: A) `loc` se utiliza para seleccionar por etiquetas, mientras que `iloc` se utiliza para seleccionar por índices enteros.**

# %% [markdown]
# 8. **¿Cómo eliminar las filas duplicadas de un DataFrame en Pandas?**
#    - A) `df.drop_duplicates()`
#    - B) `df.remove_duplicates()`
#    - C) `df.delete_duplicates()`
#
#    **Respuesta: A) `df.drop_duplicates()`**

# %% [markdown]
# 9. **¿Qué método se utiliza para realizar operaciones de ventana (rolling) en una serie temporal en Pandas?**
#    - A) `df.window()`
#    - B) `df.rolling()`
#    - C) `df.move()`
#
#    **Respuesta: B) `df.rolling()`**
#
# 10. **Si tienes una serie temporal con frecuencia diaria y deseas convertirla a frecuencia mensual en Pandas, ¿qué método utilizarías?**
#    - A) `df.resample('M')`
#    - B) `df.convert_frequency('M')`
#    - C) `df.change_frequency('M')`
#
#    **Respuesta: A) `df.resample('M')`**
#
# Este cuestionario debería proporcionar una evaluación básica del conocimiento de los estudiantes sobre indexación, selección y subconjuntos de series temporales con Pandas en Python.

# %% [markdown]
# ## Establecimiento de prerrequisitos conceptuales para alcanzar el objetivo de aprendizaje trazado.
#
# (Elabore una lista de preguntas al rededor de los conceptos que consideres necesarios para empezar la clase).
#
# Antes de sumergirse en el aprendizaje sobre indexación de series de tiempo con Pandas, es fundamental tener una comprensión sólida de varios conceptos relacionados. Aquí hay algunos prerrequisitos conceptuales importantes:
#
# 1. **Python y Pandas**: Debes tener un conocimiento básico de Python, incluyendo estructuras de datos como listas, diccionarios y funciones. Además, necesitas familiarizarte con la biblioteca Pandas, que es una herramienta poderosa para el análisis de datos en Python.
#
# 2. **Series y DataFrames**: Entender cómo funcionan las Series y los DataFrames en Pandas es esencial, ya que estas son las estructuras de datos fundamentales que se utilizan para manipular y analizar datos en Pandas. Una Serie es una matriz unidimensional etiquetada, mientras que un DataFrame es una estructura de datos bidimensional etiquetada.
#
# 3. **Indexación y selección en Pandas**: Debes conocer los conceptos básicos de cómo indexar y seleccionar datos en Pandas utilizando métodos como `loc[]`, `iloc[]`, y métodos de selección condicional.
#
# 4. **Numpy**: Numpy es otra biblioteca de Python que se utiliza ampliamente en el análisis de datos, especialmente para cálculos numéricos eficientes. Familiarízate con Numpy, especialmente con conceptos como arrays y operaciones de matriz.
#
# 5. **Fecha y hora en Python**: Debes tener una comprensión básica de cómo trabajar con fechas y horas en Python. Esto incluye el uso de las bibliotecas `datetime` y `dateutil`.
#
# 6. **Conceptos básicos de series de tiempo**: Es útil comprender los conceptos básicos de series de tiempo, como tendencia, estacionalidad, autocorrelación y estacionariedad.
#
# 7. **Frecuencia y resampling**: Familiarízate con los conceptos de frecuencia en series de tiempo y cómo resamplear datos para cambiar su frecuencia temporal.
#
# 8. **Visualización de datos**: Conocer cómo visualizar datos de series de tiempo es importante. Puedes empezar por aprender cómo utilizar la biblioteca Matplotlib junto con Pandas para crear gráficos informativos de tus series de tiempo.
#
# Una vez que tengas una comprensión sólida de estos prerrequisitos conceptuales, estarás bien preparado para adentrarte en el aprendizaje específico sobre indexación de series de tiempo con Pandas.

# %% [markdown]
# # Para el diseño de la clase tenga en cuenta algunos problemas de aprendizaje
#
# Aquí tienes algunos problemas de aprendizaje sobre indexación de series de tiempo con Pandas que puedes abordar para mejorar tus habilidades:
#
# 1. **Selección de datos por fechas**: Prueba diferentes formas de seleccionar datos de una serie de tiempo utilizando fechas específicas. Por ejemplo, selecciona datos para un mes específico, un año específico o un rango de fechas.
#
# 2. **Resampling de datos**: Practica el resampling de datos de series de tiempo para cambiar la frecuencia temporal. Intenta cambiar datos diarios a datos mensuales, trimestrales o anuales utilizando diferentes métodos de agregación (como suma, media, etc.).
#
# 3. **Aplicación de ventanas de tiempo móviles**: Explora cómo aplicar ventanas de tiempo móviles para calcular estadísticas como la media móvil o la desviación estándar en una serie de tiempo.
#
# 4. **Desplazamiento de índices de tiempo**: Experimenta con el desplazamiento de índices de tiempo hacia adelante o hacia atrás en una serie de tiempo. Por ejemplo, desplaza los índices de tiempo en un día, una semana o un mes.
#
# 5. **Tratamiento de datos faltantes**: Encuentra diferentes formas de manejar datos faltantes en una serie de tiempo, como rellenarlos con valores medios, interpolación lineal o eliminación de datos faltantes.
#
# 6. **Visualización avanzada de series de tiempo**: Practica la creación de gráficos más avanzados de series de tiempo utilizando herramientas como subplots, líneas de tendencia, bandas de confianza, etc.
#
# 7. **Análisis estacional y tendencias**: Intenta identificar y visualizar patrones estacionales y tendencias en tus series de tiempo utilizando técnicas como la descomposición estacional.
#
# 8. **Comparación de series de tiempo**: Compara dos o más series de tiempo entre sí, calculando estadísticas de correlación y visualizando las diferencias y similitudes entre ellas.
#
# Estos problemas te ayudarán a profundizar tus habilidades en la indexación y manipulación de series de tiempo con Pandas, así como a mejorar tu comprensión de cómo trabajar con datos temporales en general.

# %% [markdown]
# # Vocabulary and phrases
#
# * As a convenience: como una conveniencia.
# * loan: préstamo.
#
# []()

# %% [markdown]
# ## Secuencia conceptual introductoria a la clase

# %%
# Mapa conceptual de la clase
import networkx as nx 
import matplotlib.pyplot as plt 

plt.figure(figsize=(12,8))
G = nx.DiGraph()

# Agregar lísta de conceptos
c1 = 'time series'
c2 = 'indexing'
c3 = 'selecting'
c4 = 'subsetting'
c5 = 'pandas'
c6 = 'datetime'

lista_conceptos = [c1, c2, c3, c4 ]

G.add_nodes_from(lista_conceptos)

# Agregar las flechas de vinculación de conceptos

pares_conceptos_vinculados = [(c1, c2), \
                              (c5,c6)]

G.add_edges_from(pares_conceptos_vinculados)

pos = nx.spring_layout(G, seed = 513)

nx.draw(G, pos, with_labels = True, node_size = 2000 )

plt.savefig('/home/marco/Documentos/investigacion/didactica_ciencia_datos/4_images/indexing.jpg')

# %% [markdown]
# Time series behaves like any other Series when you are indexing and selecting data based on the label:

# %%
#obtención de datos 
import pandas as pd 
url_ibm_dates = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo&datatype=csv"
ts = pd.read_csv(url_ibm_dates, parse_dates=['timestamp'], index_col='timestamp') 
ts
# Out:
#               open      high      low   close   volume
# timestamp
# 2024-02-06  183.55  184.6800  183.040  183.41  3338196
# 2024-02-05  185.51  185.7800  183.255  183.42  4379602
# 2024-02-02  187.10  187.3900  185.615  185.79  4055411
# 2024-02-01  183.63  187.5100  182.710  186.90  4669444
# 2024-01-31  187.05  187.6500  183.140  183.66  8876055
# ...            ...       ...      ...     ...      ...
# 2023-09-20  148.36  151.9299  148.130  149.83  9636681
# 2023-09-19  145.00  146.7200  144.660  146.52  3945423
# 2023-09-18  145.77  146.4800  145.060  145.09  2508062
# 2023-09-15  147.11  147.8500  145.530  145.99  6234033
# 2023-09-14  147.38  147.7300  146.480  147.35  2723200
#
# [100 rows x 5 columns]

# %%
ts.resample('w').mean()  # haciendo remuestreo o resampling cada seman con función de agregación la media
# Out:
#                 open        high        low     close       volume
# timestamp
# 2023-09-17  147.2450  147.790000  146.00500  146.6700   4478616.50
# 2023-09-24  147.1080  148.495980  146.39600  147.1460   4719433.60
# 2023-10-01  143.9780  144.366400  142.16902  142.9540   4689085.00
# 2023-10-08  140.7160  141.786080  140.03000  141.1620   3186583.60
# 2023-10-15  141.9380  142.441000  140.75200  141.4480   3277266.80
# 2023-10-22  138.6380  139.901000  137.89200  138.9340   4208809.80
# 2023-10-29  139.3380  140.652000  138.30800  139.5060   6045489.60
# 2023-11-05  144.8820  146.263000  144.34800  145.5160   4591892.80
# 2023-11-12  148.0320  148.869000  147.11900  148.2940   3671588.80
# 2023-11-19  150.9200  151.873260  150.27802  151.4080   3909519.00
# 2023-11-26  154.1850  155.111250  153.48500  154.6425   2840674.00
# 2023-12-03  156.3880  157.716000  156.10400  157.3480   4380128.80
# 2023-12-10  160.7280  162.224000  160.19800  160.9900   4383791.40
# ...

# %%
stamp = ts.index[2]
stamp
# Out:
# Timestamp('2024-02-02 00:00:00')

# %%
ts.loc[stamp]
# Out:
# open          187.100
# high          187.390
# low           185.615
# close         185.790
# volume    4055411.000
# Name: 2024-02-02 00:00:00, dtype: float64

# %%
ts.iloc[1]
# Out:
# open          185.510
# high          185.780
# low           183.255
# close         183.420
# volume    4379602.000
# Name: 2024-02-05 00:00:00, dtype: float64

# %%
ts.open[stamp]
# Out:
# 187.1

# %% [markdown]
# As a convenience,

# %%
ts.loc['2024-02-01']
# Out:
# open          183.63
# high          187.51
# low           182.71
# close         186.90
# volume    4669444.00
# Name: 2024-02-01 00:00:00, dtype: float64

# %% [markdown]
# # Slicing

# %%
ts.iloc[1:4,1:3]
# Out:
#               high      low
# timestamp
# 2024-02-05  185.78  183.255
# 2024-02-02  187.39  185.615
# 2024-02-01  187.51  182.710

# %% [markdown]
# # Selección de información por años
#
# Here, the string '2023' is interpreted as a year and selects that time period. This also
# works if you specify the month:

# %%
ts.loc['2024']
# Out:
#               open      high      low   close    volume
# timestamp
# 2024-02-06  183.55  184.6800  183.040  183.41   3338196
# 2024-02-05  185.51  185.7800  183.255  183.42   4379602
# 2024-02-02  187.10  187.3900  185.615  185.79   4055411
# 2024-02-01  183.63  187.5100  182.710  186.90   4669444
# 2024-01-31  187.05  187.6500  183.140  183.66   8876055
# 2024-01-30  187.71  188.6500  186.770  187.87   4575058
# 2024-01-29  187.46  189.4600  186.050  187.14   6107908
# 2024-01-26  191.31  192.3896  186.160  187.42   9895941
# 2024-01-25  184.96  196.9000  184.830  190.43  29596239
# 2024-01-24  174.76  174.8600  172.900  173.93   7831157
# 2024-01-23  172.90  174.0200  172.480  173.94   3983461
# 2024-01-22  172.82  174.4500  172.400  172.83   4925964
# 2024-01-19  170.59  171.5791  169.180  171.48   6929079
# 2024-01-18  166.49  166.9900  165.040  166.84   3776990
# 2024-01-17  166.79  167.8200  165.495  166.08   4288604
# 2024-01-16  165.80  167.2500  165.340  166.96   4869635
# ...

# %%
ts.loc['2023-11']
# Out:
#               open      high       low   close   volume
# timestamp
# 2023-11-30  156.95  158.6000  156.8900  158.56  6740622
# 2023-11-29  156.15  157.5100  156.0200  156.41  3568887
# 2023-11-28  155.44  155.7450  154.8600  155.65  2666182
# 2023-11-27  154.99  156.1350  154.7500  155.57  4053093
# 2023-11-24  155.13  155.4000  153.9200  155.18  1799161
# 2023-11-22  154.50  155.7050  154.1600  155.13  3045091
# 2023-11-21  154.60  154.6600  153.5100  153.91  2859508
# 2023-11-20  152.51  154.6800  152.3500  154.35  3658936
# 2023-11-17  153.29  153.5000  152.4601  152.89  4426676
# 2023-11-16  153.00  153.3500  152.1300  153.06  3519172
# 2023-11-15  150.40  153.2200  150.4000  152.58  4632519
# 2023-11-14  149.45  150.8063  149.0500  150.41  4321940
# 2023-11-13  148.46  148.4900  147.3500  148.10  2647288
# 2023-11-10  147.44  149.1700  146.8500  149.02  3179541
# 2023-11-09  146.55  146.9900  145.2800  146.62  3412713
# 2023-11-08  149.25  149.6800  147.5850  148.03  3618588
# ...

# %% [markdown]
# # Apendice para esta clase
#
# ## Ejemplo de uso de la función `.resample()`

# %%
# creamos la serie de tiempo

index = pd.date_range('2024-02-03', periods = 9, freq = 'min')
index

# %%
series = pd.Series(range(9), index = index)
series

# %%
series.resample('3min').sum()

# %% [markdown]
# [Video de apoyo sobre este ejemplo de uso del método resample](https://www.youtube.com/watch?v=CY-frwfhNvs)

# %% [markdown]
# # [Secuencia metodol+ogica que seguiremos en cada modelación fundamentada en Borromeo citado por Carlos Ledezma](https://www.researchgate.net/profile/Carlos-Ledezma-4/publication/376076920_Modelizacion_matematica_desde_una_articulacion_teorica_entre_los_enfoques_cognitivo_y_onto-semiotico/links/6568cb363fa26f66f43b292a/Modelizacion-matematica-desde-una-articulacion-teorica-entre-los-enfoques-cognitivo-y-onto-semiotico.pdf)
#
# 1. Entender la tarea
# 2. Simplificar y estructurar la tarea
# 3. Matemátizar
# 4. Trabajar matemáticamente utilizando las competencias matemáticas del estudiante.
# 5. Interpretar y
# 6. validar

# %% [markdown]
# # Visualizaciones tabulares y gráficas

# %% [markdown]
# ## Visualización gráfica con plotly

# %%
import numpy as np 
import pandas as pd 
import plotly.express as px
# datos
X = np.array([])

Y = np.array([])

# tabla de datos
tabla = pd.DataFrame({'x':X, 'y':Y})
#trazo de diagrama de dispersión o scatter
fig = px.scatter(tabla,x = tabla.keys()[0], y = tabla.keys()[1], title='Relación entre x e y')

fig.show()

#fig.write_html('relacion_entre_x_e_y.html', auto_open=True)

# %% [markdown]
# ## Mapa conceptual de la clase elaborado en CMapTools

# %% [markdown]
# <img src = ''>

# %% [markdown]
# # Componente de manejo de calculadora Casio asociado al objetivo de aprendizaje de esta clase

# %% [markdown]
# ## Descripción de la calculadora Casio

# %% [markdown]
# ## Tareas para realizar antes de la clase

# %% [markdown]
# 1. Ver los videos respectivos []()
# 2. Memorizar las definiciones []()
# 3. Sintetizar o resumir la información en mapas conceptuales. []()
# 4. Tareas para incentivar el uso de la calculadora Casio Para ingenieros y licenciados.

# %% [markdown]
# # Tareas para realizar en clase

# %% [markdown]
# * Modelación matemática
# * Trabajo en equipos

# %%
## Quiz de 15 minutos para ejercitación y adquisición de habilidades computacionales y de pensamiento variacional

# Resolver con sympy el punto sobre centro de masa que se le haya propuesto. 

# Puede utilizar chatGPT, pero debe revisar y corregir, lo que este modelo le entregue. 


import pandas as pd
import numpy as np
import random
import requests


texto_guia_seccion_pagina = 'purcell_seccion_5.6_pagina 313'
n_exercises_del_taller_del_texto = 36
n_ejercicios_asignados_al_estudiante = 1



# Descargar la lista de estudiantes y ejercicios
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/calculo_integral.csv"
exercises = list(range(1, n_exercises_del_taller_del_texto))  # Lista de ejercicios del 1 al 83

# Cargar la lista de estudiantes
students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    random_exercises = random.sample(exercises, n_ejercicios_asignados_al_estudiante)  # Seleccionar 5 ejercicios aleatorios sin repetición
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student", "Exer1"]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = texto_guia_seccion_pagina 
assignment_df.to_csv(assignment_csv, index=False)

print("Asignaciones guardadas en", assignment_csv)
assignment_df

# %% [markdown]
# # Tareas para realizar después de la realización de la clase

# %% [markdown]
# * Actividades de memorización:
#   - escucha reiterada de grabaciones de formulas y resultados científicos.
#   - relectura de notas.
#   - ejercicios de mayor complejidad.
#
#
# ### No olvide asignar las tareas a los estudiantes a través de Google Colab y compartiendole el cuaderno de asignación a su correo institucional con fecha de entrega. [Google Colab](https://colab.research.google.com/?hl=es)

# %% [markdown]
# ## Asignación individual de tareas semanales

# %%
# asignación de ejercicios de un seccion del texto guía

# numpy.random.choice() obten la documentación de esta función en: 
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html

import pandas as pd
import numpy as np
import requests
np.random.seed(42)  # establecer semilla aleatoria para hacer los resultados reproducibles



grupo_estudiantes = 'fund_math'
nombre_texto_guia = 'Precalculo_Stewart'
pagina_y_seccion = 'Página_32_Sección_1.3'
numero_ejercicios_taller = 135
numero_de_ejercicios_asignados = 5


# Descargar la lista de  estudiantes
students_url = "https://raw.githubusercontent.com/marco-canas/groups_list/main/" + grupo_estudiantes + ".csv"
exercises = list(range(1, numero_ejercicios_taller))  

students_data = pd.read_csv(students_url)

# Crear una lista para almacenar las asignaciones
assignments = []

# Asignar ejercicios aleatorios a cada estudiante
for index, student in students_data.iterrows():
    # Seleccionar 5 ejercicios aleatorios sin repetición
    random_exercises = np.random.choice(exercises, numero_de_ejercicios_asignados, replace = False)+ 1 
    assignments.append([students_data["Nombre"][index], *random_exercises])  # Agregar asignación a la lista

# Crear un DataFrame con las asignaciones
columns = ["Student"] + [ "Exer" + str(i+1) for i in range(numero_de_ejercicios_asignados)]
assignment_df = pd.DataFrame(assignments, columns=columns)

# Guardar el DataFrame en un archivo CSV
assignment_csv = "tarea" + "_" + nombre_texto_guia + "_"+ pagina_y_seccion + ".csv"
assignment_df.to_csv(assignment_csv, index=False)

print("Tarea asignada: ", assignment_csv)
assignment_df

# %% [markdown]
# # No olvide la tarea de realizar la foda para autoevaluarse
#
# Fortalezas: F
# Oportuniudades O:
# Debilidades: D:
# Amenazas: A:

# %% [markdown]
# # Horario de clases del profesor Marco
#
# * Martes y jueves de 10 a 12: Fundamentos de las matemáticas
# * Martes y jueves de 2 a 4 PM: Fundamentos de la aritmética
#
# * Didáctica de la aritmética: Miércoles de 8 - 12

# %% [markdown]
# # Horarios de monitoría y asesoría

# %% [markdown]
# ## Monitor Manuel

# %% [markdown]
# Martes y jueves de 8 - 12
# Miércoles 10 - 12 y de 2 a 4 PM
# Sábado: 8 - 12

# %% [markdown]
# ## Dificultades de aprendizaje detectados durante la clase

# %% [markdown]
# ## Estrategias propuestas para la solución de las dificultades de aprendizaje detectadas

# %% [markdown]
# ## Grabaciones en audio para fomentar la capacidad de memorizar enunciados de teoremas y resultados científicos y la capacidad de parafrasear estos resultados. Y así desarrollar memoria muscular para los comandos comunes.
# Se dispondrá de un lugar en Vocaroo para albergar archivos de audio de fomento a la memorización, enunciación y parafraseo de los resultados científicos, propiedades, reglas, etc.
#
# [Vocaroo](https://vocaroo.com/)

# %% [markdown]
# ### Comparta sus cuadernos y videos, evidencias de su aprendizaje [aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUMEMwTEZVMzEwVVBPTElWNVg5OVEyWUhMUy4u)

# %% [markdown]
# # Vocabulary

# %% [markdown]
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# # Colección de verbos irregulares aprendidos
#
# |Verbo irregular en presente|en español|Pasado|
# |---------------------------|----------|------|
# |choose|elegir|chose|

# %% [markdown]
# ## Quiz de 20 minutos para ejercitación y adquisición de habilidades

# %% [markdown]
# * Pregunta 1:
# * Pregunta 2:
# * Pregunta 3:

# %% [markdown]
# ## Referentes

# %% [markdown]
# * [stewart precálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ERHIq62I6qFNrmxy6LZb8ZMBci7kUsyNME1nIh9yCBMJ_w?e=0zMSla)
#
# * [stewart cálculo](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EZgXZjAp8QxPqOAim2hs6LcBNPLGjSHf-xwYnUVYkwa04w?e=RZdTCy)
#
# * [larson](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES71ChFeO9ZDhW3TwC5Ijk8BjxUK3Pdqz_fjHxTTFAfIAg?e=VDEjfu)
#
# * [uzcategui](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ETDikm-lVl1Or8XoEo9oyh0BEti9Zs8le-f0D-dBdtZmbA?e=bBsoyQ)
#
# * [Cálculo de Purcell](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/ES60UB4h-QFFqqRQUFmkpWcBIgoLBJeqTfZjNajWNWSeJA?e=9NxjKJ)
#
# * [Recomendación de la UNESCO sobre ciencia abierta](https://unesdoc.unesco.org/ark:/48223/pf0000379949_spa)
#
# * [Fórmulas más comunes en latex](https://wiki.geogebra.org/es/C%C3%B3digo_LaTeX_para_las_f%C3%B3rmulas_m%C3%A1s_comunes)
#
# * [chatGPT](https://openai.com/blog/chatgpt)
#
# * Géron, A. (2017). Hands-on machine learning with scikit-learn and tensorflow: Concepts. Tools, and Techniques to build intelligent systems.[Geron, Aurelien. Hands on Machine Learning](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/Ecet27yjQzZIlT1Y_Bc2erkBUhbeYuIe6HG8i1FYZRlZww?e=dlvZ4v)
#
# * McKinney, W. (2012). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython. " O'Reilly Media, Inc.".[Wes Mackinney. ](https://udeaeduco-my.sharepoint.com/:b:/g/personal/marco_canas_udea_edu_co/EVbi5JIeBl9ErbiUnZfGe8YBhNTnZ8sxTK5hjIOPK4UpGw?e=fFclah)
#
# * [Ledezma, C., Font, V., & Sala-Sebastià, G. MODELIZACIÓN MATEMÁTICA DESDE UNA ARTICULACIÓN TEÓRICA ENTRE LOS ENFOQUES COGNITIVO Y ONTO-SEMIÓTICO.](https://www.researchgate.net/profile/Carlos-Ledezma-4/publication/376076920_Modelizacion_matematica_desde_una_articulacion_teorica_entre_los_enfoques_cognitivo_y_onto-semiotico/links/6568cb363fa26f66f43b292a/Modelizacion-matematica-desde-una-articulacion-teorica-entre-los-enfoques-cognitivo-y-onto-semiotico.pdf)

# %% [markdown]
# [Autoevaluemonos para hacernos concientes de nuestro aprendizaje y en lo que debemos enfocarnos en mejorar]()
#
# ¡Claro! Aquí tienes una lista de preguntas de selección múltiple para una autoevaluación en un curso de cálculo con un enfoque pedagógico de aula invertida. Estas preguntas abarcan los objetivos de desarrollo del pensamiento variacional, pensamiento computacional a través de Python, capacidad de comunicación científica con LaTeX, Git y el uso de cuadernos Jupyter, así como la promoción de políticas de ciencia libre.
#
# 1. **Pensamiento Variacional:**
#    a. ¿Qué significa el término "variación" en el contexto del pensamiento variacional?
#    b. ¿Cómo se relaciona el cálculo con el pensamiento variacional?
#    c. ¿Puede proporcionar un ejemplo práctico que ilustre el concepto de variación en un problema de cálculo?
#
# 2. **Pensamiento Computacional (Python):**
#    a. ¿Cuál es el propósito principal de utilizar Python en un curso de cálculo?
#    b. ¿Cómo se puede utilizar Python para resolver problemas matemáticos complejos?
#    c. Menciona al menos dos ventajas de usar Python en comparación con otros lenguajes de programación en el contexto del cálculo.
#
# 3. **Comunicación Científica (LaTeX):**
#    a. ¿Por qué es importante utilizar LaTeX para la comunicación científica en matemáticas y ciencias?
#    b. Enumera al menos tres comandos básicos de LaTeX utilizados para escribir ecuaciones matemáticas.
#    c. ¿Cómo mejorarías la presentación visual de una fórmula matemática utilizando LaTeX?
#
# 4. **Gestión de Versiones (Git):**
#    a. ¿Cuál es el propósito principal de utilizar Git en el desarrollo de proyectos científicos?
#    b. Explica el concepto de "commit" en Git.
#    c. ¿Cómo resolverías un conflicto de fusión (merge conflict) en Git?
#
# 5. **Cuadernos Jupyter:**
#    a. ¿Cuáles son las ventajas de utilizar cuadernos Jupyter en comparación con otros entornos de desarrollo?
#    b. Describe cómo se integra el código Python y la documentación en un cuaderno Jupyter.
#    c. ¿Cómo compartirías un cuaderno Jupyter con tus compañeros de clase utilizando GitHub?
#
# 6. **Promoción de Políticas de Ciencia Libre:**
#    a. ¿Cuáles son los beneficios de utilizar plataformas como GitHub y YouTube para compartir recursos científicos?
#    b. ¿Cómo podrías contribuir a la promoción de la ciencia libre en tu comunidad académica?
#    c. ¿Por qué es importante la transparencia y accesibilidad en la investigación científica?
#
# Estas preguntas están diseñadas para evaluar la comprensión de los estudiantes en diversos aspectos del curso, abarcando desde los conceptos matemáticos hasta las habilidades tecnológicas y la conciencia sobre la ciencia libre.

# %% [markdown]
# ### [Evaluamos al profesor Marco Cañas Aquí](https://forms.office.com/Pages/ResponsePage.aspx?id=IefhmYRxjkmK_7KtTlPBwkanXIs1i1FEujpsZgO6dXpUREJPV1kxUk1JV1ozTFJIQVNIQjY5WEY3US4u)

# %% [markdown]
# # Aportes de mis estudiantes a la metodología del curso
# 1.
#
# Sus opiniones y aportes son muy importantes para mi. Pues esta es una investigación educativa y un servicio de enseñanza para ustedes. Ustedes son la razón de ser de mi actividad docente. Dios los bendiga.

# %% [markdown]
# # Aportes de mis colegas docentes a la metodología que estoy aplicando en mis cursos.

# %% [markdown]
# ## [Evaluación luego de alcanzar estos objetivos de aprendizaje]()

# %% [markdown]
# ### Continue su aprendizaje en la siguiente clase a través del siguiente [vínculo]()

# %% [markdown]
# # Conjeturas pedagógicas fruto de la aplicación del modelo de aprendizaje invertido y del enfoque hacia la ciencia de datos con python
#
# 1. Todo cálculo o resultado debe ser interpretado en una línea markdown del cuaderno Jupyter, inmediatamente después de la enunciación del resultado y después de la presentación de una tabla o gráfico bidimensional, de tal menera que el estudiante explicite la comprensión verbal del resultado y las inferencias o estrategias que este resultado le sugieren.
#
# 2. Debo colocar las conjeturas pedagógicas, que el uso en el aula de [ChatGPT](https://openai.com/blog/chatgpt/) traiga para la enseñanza y el aprendizaje de las matemáticas.
#
# 3. Promover ciencia abierta en clase de matemáticas puede ser pidiendo a los estudiantes, tomar nota en clase pero en cuadernos Jupyter y entregar siempre al final de cada clase su cuaderno con todas las notas y experimentaciones de clase replicadas.
# 4. Profesor Marco, ¿ha contemplado la posibilidad de intercambio de experiencias de aprendizaje y aplicación de Python al día a día con comfama? (Estudio Trabajo Social y allí, en comfama, aprendí los fundamentos, lo básico de Python)
#
# ¿Conoce si en la Universidad de Antioquia hay medios para poder aprender Swift/XCODE? (Para programar para dispositivos de Apple)
# 5. Debo considerar la metodología ABP, es decir, diseñar las clase bajo la metodología de Aprendizaje Basado en Problemas.

# %% [markdown]
# ## Agradecimientos
#
# Doy gracias a Dios por la vida de mi Hijo Joseph Cañas Osorio y la madurez que ha alcanzado.
#
# Y a mi esposa Yasmira por su apoyo, orientación y acompañamiento.
