# %% [markdown]
# # Creating the model using the Sequential API
#
# Now let’s build the neural network! Here is a classification MLP with two hidden layers:

# %%
import tensorflow as tf

# %%
model = keras.models

# %% [markdown]
# Este es mi primer cuaderno Jupyter

# %%
# Cómo se suma en python

4/5

# %%
# Cómo saco raiz 

16**(1/2)

# %%
import math 

math.sqrt(16)

# %%
import numpy as np 

np.sqrt(25)

# %% [markdown]
# Quiero presentar el problema de resolver una ecuación cuadrática $ax^{2} + bx + c = 0$
#
# Y la solución de este problema es:
#
#
# $$ x = \frac{-b \pm \sqrt{b^{2} - 4ac}}{2a}  $$

# %%
'5' + 5

# %%
'55'

# %%
10

# %%
a = [1,2,3]
b = a

# %%
a.append(4)

# %%
a

# %%
b

# %%
def append_elemnt(lista, elemento):
    lista.append(elemento)

# %%
dato = [1,2,3]

# %%
append_elemnt(dato, 5)

# %%
a

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 import tensorflow as tf
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# ModuleNotFoundError: No module named 'tensorflow.python'
