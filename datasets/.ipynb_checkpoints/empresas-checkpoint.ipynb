# %%
import pandas as pd 
empresas = pd.read_excel('mejores_empresas_1000-informe-2021.xlsx')
empresas
# Out:
#      RANKING        NIT                         RAZON SOCIAL       SUPERVISOR  \
# 0          1  899999068                        ECOPETROL S.A  SUPERFINANCIERA
# 1          2  830095213             ORGANIZACIÓN TERPEL S.A.  SUPERFINANCIERA
# 2          3  900112515        REFINERIA DE CARTAGENA S.A.S   SUPERSOCIEDADES
# 3          4  800153993          COMUNICACIÓN CELULAR S.A.    SUPERSOCIEDADES
# 4          5  890900608                  ALMACENES EXITO S A  SUPERFINANCIERA
# ..       ...        ...                                  ...              ...
# 995      996  900294923                 AVICOLA TRIPLE A SAS  SUPERSOCIEDADES
# 996      997  860020308                 COMESTIBLES RICOS SA  SUPERSOCIEDADES
# 997      998  830111367            SUDESPENSA BARRAGAN S.A.   SUPERSOCIEDADES
# 998      999  890324420            FERRETERIA TUBOLAMINAS SA  SUPERSOCIEDADES
# 999     1000  890901475  DISTRIBUIDORA FARMACEUTICA ROMA SA   SUPERSOCIEDADES
#
# ...
