# %% [markdown]
# # Regresión

# %% [markdown]
# ## Situación problemática

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('StudentsPerformance.csv') 
df.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93

# %% [markdown]
# ## Determinación de la naturaleza de las características

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.columns = ['genero', 'raza',
             'educacion_padres','comida',
             'curso_preparatorio','score_math',
             'score_lectura','score_escritura']
df.head()
# Out:
#    genero     raza    educacion_padres        comida curso_preparatorio  \
# 0  female  group B   bachelor's degree      standard               none
# 1  female  group C        some college      standard          completed
# 2  female  group B     master's degree      standard               none
# 3    male  group A  associate's degree  free/reduced               none
# 4    male  group C        some college      standard               none
#
#    score_math  score_lectura  score_escritura
# 0          72             72               74
# 1          69             90               88
# 2          90             95               93
# 3          47             57               44
# 4          76             78               75

# %%
# Creamos las variables binarias
genero_cod = pd.get_dummies(df['genero'])
# Añadimos las variables binarias al DataFrame
df = pd.concat([df, genero_cod], axis = 1)

# Eliminamos la vairable original genero
df = df.drop(columns=['genero'])

# %%
df.head()
# Out:
#       raza    educacion_padres        comida curso_preparatorio  score_math  \
# 0  group B   bachelor's degree      standard               none          72
# 1  group C        some college      standard          completed          69
# 2  group B     master's degree      standard               none          90
# 3  group A  associate's degree  free/reduced               none          47
# 4  group C        some college      standard               none          76
#
#    score_lectura  score_escritura  female  male
# 0             72               74       1     0
# 1             90               88       1     0
# 2             95               93       1     0
# 3             57               44       0     1
# 4             78               75       0     1

# %%
# Creamos las variables binarias
raza_cod = pd.get_dummies(df['raza'])
# Añadimos las variables binarias al DataFrame
df = pd.concat([df, raza_cod['group A'], raza_cod['group B'], 
                raza_cod['group C'], raza_cod['group D']], axis = 1)

# Eliminamos la vairable original raza
df = df.drop(columns=['raza'])

# %% [markdown]
# # Codicicación de variable categórica ordinal `educacion_padres`

# %%
from sklearn.preprocessing import OrdinalEncoder

# Creamos el codificador indicandole el orden de la variables

encoder = OrdinalEncoder(categories = [['some high school',"high school", 
                                      "some college","bachelor's degree",  
                                      "master's degree","associate's degree"]])

# Ajustamos el codificador con la variable educacion padres y la transformamos

encoder.fit(df[["educacion_padres"]])
df["educacion_padres-encoded"] = encoder.transform(df[["educacion_padres"]]) 
# Eliminamos la vairable original race
df = df.drop(columns=['educacion_padres'])

# %%
df.head()
# Out:
#          comida curso_preparatorio  score_math  score_lectura  \
# 0      standard               none          72             72
# 1      standard          completed          69             90
# 2      standard               none          90             95
# 3  free/reduced               none          47             57
# 4      standard               none          76             78
#
#    score_escritura  female  male  group A  group B  group C  group D  \
# 0               74       1     0        0        1        0        0
# 1               88       1     0        0        0        1        0
# 2               93       1     0        0        1        0        0
# 3               44       0     1        1        0        0        0
# 4               75       0     1        0        0        1        0
#
#    educacion_padres-encoded
# 0                       3.0
# 1                       2.0
# 2                       4.0
# 3                       5.0
# 4                       2.0

# %% [markdown]
# # Codicicación de variable categórica nominal `curso_preparatorio`

# %%
# Creamos las variables binarias
preparatorio_cod = pd.get_dummies(df['curso_preparatorio'])
# Añadimos las variables binarias al DataFrame
df = pd.concat([df, preparatorio_cod], axis = 1)

# Eliminamos la vairable original curso_preparatorio
df = df.drop(columns=['curso_preparatorio'])

# %%
df.head(3)
# Out:
#      comida  score_math  score_lectura  score_escritura  female  male  \
# 0  standard          72             72               74       1     0
# 1  standard          69             90               88       1     0
# 2  standard          90             95               93       1     0
#
#    group A  group B  group C  group D  educacion_padres-encoded  completed  \
# 0        0        1        0        0                       3.0          0
# 1        0        0        1        0                       2.0          1
# 2        0        1        0        0                       4.0          0
#
#    none
# 0     1
# 1     0
# 2     1

# %%
# Creamos las variables binarias
comida_cod = pd.get_dummies(df['comida'])
# Añadimos las variables binarias al DataFrame
df = pd.concat([df, comida_cod], axis = 1)

# Eliminamos la vairable original curso_preparatorio
df = df.drop(columns=['comida'])

# %%
df.head()
# Out:
#    score_math  score_lectura  score_escritura  female  male  group A  group B  \
# 0          72             72               74       1     0        0        1
# 1          69             90               88       1     0        0        0
# 2          90             95               93       1     0        0        1
# 3          47             57               44       0     1        1        0
# 4          76             78               75       0     1        0        0
#
#    group C  group D  educacion_padres-encoded  completed  none  free/reduced  \
# 0        0        0                       3.0          0     1             0
# 1        1        0                       2.0          1     0             0
# 2        0        0                       4.0          0     1             0
# 3        0        0                       5.0          0     1             1
# 4        1        0                       2.0          0     1             0
#
#    standard
# 0         1
# 1         1
# 2         1
# 3         0
# 4         1

# %%
df.keys()
# Out:
# Index(['score_math', 'score_lectura', 'score_escritura', 'female', 'male',
#        'group A', 'group B', 'group C', 'group D', 'educacion_padres-encoded',
#        'completed', 'none', 'free/reduced', 'standard'],
#       dtype='object')

# %%
df.columns = ["score_math","score_lectura","score_escritura","female","male","raza_A",
             "raza_B","raza_C","raza_D","educacion_padres","curso_preparatario_completado",
             "no_hizo_curso_preparatorio","comida_reducida","comida_estandar"]

# %%
df.head()
# Out:
#    score_math  score_lectura  score_escritura  female  male  raza_A  raza_B  \
# 0          72             72               74       1     0       0       1
# 1          69             90               88       1     0       0       0
# 2          90             95               93       1     0       0       1
# 3          47             57               44       0     1       1       0
# 4          76             78               75       0     1       0       0
#
#    raza_C  raza_D  educacion_padres  curso_preparatario_completado  \
# 0       0       0               3.0                              0
# 1       1       0               2.0                              1
# 2       0       0               4.0                              0
# 3       0       0               5.0                              0
# 4       1       0               2.0                              0
#
#    no_hizo_curso_preparatorio  comida_reducida  comida_estandar
# 0                           1                0                1
# 1                           0                0                1
# 2                           1                0                1
# 3                           1                1                0
# 4                           1                0                1

# %% [markdown]
# # Un modelo de regresión lineal para predecir el desempeño en matemáticas
