# %% [markdown]
#  <td>
#     <a href="https://colab.research.google.com/github/marco-canas/innovaciones/blob/main/prop/unidad_didac/2_clasificacion/2_clasif_load_digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>

# %% [markdown]
# # Clasificación

# %% [markdown]
# ## ¿Qué significa clasificar en ciencia de datos?

# %% [markdown]
# ## Ejemplo ilustrativo de clasificación binaria

# %% [markdown]
# <img src = 'data:image/png;base64,...'>

# %% [markdown]
# <img src = 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Iris_dataset_scatterplot.svg/330px-Iris_dataset_scatterplot.svg.png'>

# %% [markdown]
# ## cargar los datos

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
X,y = load_iris(return_X_y = True)

# %% [markdown]
# # Reducción dimensional

# %%
X_area_sep = X[:,0]*X[:,1]
X_area_pet = X[:,2]*X[:,3]

# %%
import numpy as np 
X_area = np.c_[X_area_sep, X_area_pet]

# %% [markdown]
# ## Configuración de etiquetas para un detector de setosa

# %%
y_setosa = (y==0)

# %% [markdown]
# # Visualización de las tres especies de florez de iris en dos dimensiones

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
import matplotlib.pyplot as plt 

fig, ax = plt.subplots()
ax.set(title ='Clasificación de iris en función de las áreas de sepalo y pétalo',\
       xlabel = 'área sepalo', ylabel = 'área pétalo' )


ax.scatter(X_area[:,0][y_setosa==1], X_area[:,1][y_setosa==1], color = 'red', label = 'setosa') 
ax.scatter(X_area[:,0][y_setosa==0], X_area[:,1][y_setosa==0], color = 'blue', label = 'versicolor') 

ax.legend()
ax.grid(alpha = 0.3)

plt.show()

# %% [markdown]
# ## Interpretación del gráfico bidimensional
#
# * La setosa se caracteriza por tener área de pétalo pequeño.
