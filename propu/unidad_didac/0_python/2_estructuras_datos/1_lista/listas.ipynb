# %% [markdown]
# # Introducción a las listas según Nicolas Shurmann

# %%
lista = []  # creación de una lista vacía

# %%
lista
# Out:
# []

# %% [markdown]
# # Meterle datos a la lista

# %%
lista.append(3) # utilizando el método append()

# %%
lista
# Out:
# [1, 2, 3]

# %%
lista.clear()

# %%
lista
# Out:
# []

# %%
lista = [2,4,6]

# %%
lista2 = lista.copy()

# %%
lista2
# Out:
# [2, 4, 6]

# %%
lista2[0] = 0
lista2
# Out:
# [0, 4, 6]

# %%
lista
# Out:
# [2, 4, 6]

# %%
lista.append(4)

# %%
lista, lista2

# %% [markdown]
# Cambia la lista sin necesidad de volverla a crear.

# %% [markdown]
# # Contando elementos y calculando el largo de una lista

# %%
lista = [2,2,2, 7]

# %%
lista.count(7)
# Out:
# 1

# %% [markdown]
# ## Determinando la longitud de la lista

# %%
len(lista)
# Out:
# 4

# %% [markdown]
# ## Accediendo a elementos de la lista

# %% [markdown]
# Empecemos con el acceso al primer elemento de una lista

# %%
lista[0]
# Out:
# 2

# %%
print(lista)
# Out:
# [2, 2, 2, 7]

# %%
lista[:4]
# Out:
# [2, 2, 2, 7]
