# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propu/unidad_didac/0_python/1_datos/datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Lista de reproducción asociada a la lectura interactiva y experimental de este cuaderno](https://www.youtube.com/watch?v=6PKivG1Wr2I&list=PLbk60veMSVKtv2Jhk0KpZ7YnWXUnisSK4)

# %% [markdown]
# # Instalación de editor y software para vincular el computador con la red social GitHub

# %% [markdown]
# * Instalación del editor **Visual Studio Code** recomendado para Python [aquí](https://code.visualstudio.com/download)
#
# * Y la instalación del **GitHub Desktop** la obtiene [aquí](https://desktop.github.com/)

# %% [markdown]
# La necesidad de descargar a GitHub Desktop es poder clonar el repositorio Cielo para alimentarlo de manera comunitaria por los 6 investigadores de la seccional Bajo Cauca.

# %% [markdown]
# # Los tipos de datos en Python

# %% [markdown]
# # [Basic Data Types in Python](https://realpython.com/python-data-types/)

# %% [markdown]
# # Table of Contents

# %% [markdown]
# * Integers
# * Floating-Point Numbers
# * Strings
# * Boolean Type, Boolean Context, and “Truthiness”
# * Built-In Functions
#      - Math
#      - Type Conversion
#         Iterables and Iterators
#         Composite Data Type
#         Classes, Attributes, and Inheritance
#         Input/Output
#         Variables, References, and Scope
#         Miscellaneous
# * Conclusion

# %% [markdown]
# # Integers

# %%
edad_de_marco = 47

# %%
type(edad_de_marco)
# Out:
# int

# %% [markdown]
# In Python 3, there is effectively no limit to how long an integer value can be.

# %% [markdown]
# Of course, it is constrained by the amount of memory your system has, as are all things, but beyond that an integer can be as long as you need it to be:

# %%
 print(123123123123123123123123123123123123123123123123123123123 + 2)
# Out:
# 123123123123123123123123123123123123123123123123123123125

# %%
123412341234123412341234123412341234123412341234123412341234 + 1
# Out:
# 123412341234123412341234123412341234123412341234123412341235

# %% [markdown]
# # Datos numéricos de punto flotante

# %%
estatura_de_marco = 1.65

# %%
type(estatura_de_marco)
# Out:
# float

# %%
size(estatura_de_marco)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 size(estatura_de_marco)
#
# NameError: name 'size' is not defined

# %%
estatura_de_marco.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 estatura_de_marco.size
#
# AttributeError: 'float' object has no attribute 'size'

# %%
help(estatura_de_marco)
# Out:
# Help on float object:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(self, /)
#  |      Return the ceiling as an Integral.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(self, /)
#  |      Return the floor as an Integral.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
# ...

# %% [markdown]
# # Booleanos como tipos de datos

# %%
primer_valor_booleano = True

# %%
segundo_valor_booleano = False

# %%
type(primer_valor_booleano)
# Out:
# bool

# %%
import numpy as np 
lista = [45, 12, 23, 7]
vector = np.array(lista)

# %%
vector % 2 == 0
# Out:
# array([False,  True, False, False])

# %% [markdown]
# # Variables en Python

# %% [markdown]
# Es una cajita que contiene un tipo de dato.

# %% [markdown]
# # Los cuatro tipos de datos básicos en Python

# %%
edad = 13 # tipo int
nombre_de_mi_hijo = "Joseph" # tipo str
estatura_joseph = 1.60 # tipo float
es_mayor_de_edad = (edad >= 18) # indicar estados son los valores booleanos

# %%
type(y)
# Out:
# str

# %%
es_mayor_de_edad
# Out:
# False

# %%
print(x,y)
# Out:
# 5 chanchito feliz

# %%
email = 'chanchito@feliz.com'

# %%
print(email)  # el nombre de las variables debe ser representativas de lo que ellas están guardando
# Nombres representativos. Ser consistente.
# Out:
# chanchito@feliz.com

# %%
email
# Out:
# 'chanchito@feliz.com'

# %%
mivar = 'chanchito'
mi_var = 'chanchito'   # Dos formas de dar nombre a mis variables. 
miVar = 'chanchito'
MIVAR = 'chanchito'   # para asignar constante, o variables que no pueden cambiar su valor. 
mivar123 = 'chanchito'   # numeros después de letras.

# %%
var1 = 5

# %% [markdown]
# # Cómo definir múltiples variables en Python

# %%
a,b,c = 'lala', 'lele', 'lili'

# %%
print(a,b,c)
# Out:
# lala lele lili

# %%
valor1 = valor2 = valor3 = 'chanchito feliz'

# %%
print(valor1, valor2, valor3)
# Out:
# chanchito feliz chanchito feliz chanchito feliz

# %% [markdown]
# # Estructuras de datos básicas en Python

# %% [markdown]
# ## listas de Python son contenedores de datos o información separada comas

# %% [markdown]
# ### ¿Cómo crearlas listas?

# %%
edades = [30, 32, 45, 47, 76]

# %%
type(edades)
# Out:
# list

# %%
estaturas = [1.0, 1.5, 1,7]

# %%
nombres = ['marco', "joseph", "yasmira"]

# %%
hombres = [True, True, False]

# %%
multiples_tipos_de_datos = [13, 1.62, 'joseph', True]

# %% [markdown]
# ### ¿Cómo acceder a la información o datos guardados en listas?

# %%
edades = [30, 32, 45, 47, 76]

edades[-1]
# Out:
# 76

# %% [markdown]
# ### ¿Por qué se dice que son mutables?

# %%
edades = [30, 32, 45, 47, 76]
edades[0] = 60

# %%
edades
# Out:
# [60, 32, 45, 47, 76]

# %% [markdown]
# ## Tuplas de Python  es un contenedor de información

# %% [markdown]
# ### ¿Cómo crearlas Tuplas?

# %%
edades = (10, 20, 30)

# %%
type(edades)
# Out:
# tuple

# %%
estaturas = (1.0, 1.5, 2.0)

# %%
nombres = ('marco', "joseph", "yasmira")

# %%
son_mujeres = (False, False, True)

# %%
multiples_tipos_datos_en_tupla = (10, 1.0, 'marco', False)

# %% [markdown]
# ### ¿Cómo acceder a la información o datos guardados en tuplas?

# %%
edades = (10, 20, 30)
edades[0]
# Out:
# 10

# %% [markdown]
# ### ¿Por qué se dice que son inmutables?

# %%
edades
# Out:
# (10, 20, 30)

# %%
edades[0] = 40
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 edades[0] = 40
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Diccionarios de Python : Son contenedores de información

# %% [markdown]
# ### ¿Cómo crear un diccionario en Python?

# %%
marco = {'edad':47, 'estatura':1.65, "hombre": True, 'apellido': 'canas'}

# %%
type(marco)
# Out:
# dict

# %% [markdown]
# ### ¿Cómo acceder a la información o datos guardados en diccionarios?

# %%
marco['apellido']
# Out:
# 'canas'

# %%
marco[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 marco[0]
#
# KeyError: 0

# %% [markdown]
# # Tipos de datos según Nicolas Shurmann

# %% [markdown]
# ## Tipo de dato string (palabra o frase)

# %% [markdown]
# ## Referentes
#
# * Basic data types in python: https://realpython.com/python-data-types/
#
# * Nicolas Shurmann: Curso de Python sin fronteras: HTML, CSS, MySQL. Udemy.
#
# * Mckinney: Python for Data Science
