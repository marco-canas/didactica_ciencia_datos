# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/didactica_ciencia_datos/blob/main/propu/unidad_didac/0_python/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# ## [Lista de reproducción asociada a la lectura interactiva y experimental de este cuaderno]()

# %% [markdown]
# # [Instalación del Interprete recomendado para Python](https://code.visualstudio.com/download)

# %% [markdown]
# # Los tipos de datos en Python

# %% [markdown]
# # [Basic Data Types in Python](https://realpython.com/python-data-types/)

# %% [markdown]
# # Table of Contents

# %% [markdown]
# * Integers
# * Floating-Point Numbers
# * Complex Numbers
# * Strings
#   - Escape Sequences in Strings
#   - Raw Strings
#   - Triple-Quoted Strings
# * Boolean Type, Boolean Context, and “Truthiness”
# * Built-In Functions
#      - Math
#         Type Conversion
#         Iterables and Iterators
#         Composite Data Type
#         Classes, Attributes, and Inheritance
#         Input/Output
#         Variables, References, and Scope
#         Miscellaneous
#     Conclusion

# %% [markdown]
# Now you know how to interact with the Python interpreter and execute Python code.

# %% [markdown]
# It’s time to dig into the Python language.

# %% [markdown]
# First up is a discussion of the basic data types that are built into Python.

# %% [markdown]
# Here’s what you’ll learn in this tutorial:

# %% [markdown]
# You’ll learn about several basic numeric, string, and Boolean types that are built into Python.

# %% [markdown]
# By the end of this tutorial, you’ll be familiar with what objects of these types look like, and how to represent them.

# %% [markdown]
# You’ll also get an overview of Python’s built-in functions.

# %% [markdown]
# These are pre-written chunks of code you can call to do useful things.

# %% [markdown]
# You have already seen the built-in `print()` function, but there are many others.

# %% [markdown]
# ## Take the Quiz:

# %% [markdown]
# Test your knowledge with our interactive “Basic Data Types in Python” quiz.

# %% [markdown]
#  Upon completion you will receive a score so you can track your learning progress over time:

# %% [markdown]
# # Integers

# %% [markdown]
# In Python 3, there is effectively no limit to how long an integer value can be. Of course, it is constrained by the amount of memory your system has, as are all things, but beyond that an integer can be as long as you need it to be:

# %%
 print(123123123123123123123123123123123123123123123123 + 1)
# Out:
# 123123123123123123123123123123123123123123123124

# %% [markdown]
# # Variables en Python

# %% [markdown]
# Es una cajita que contiene un tipo de dato.

# %%
x = 5
y = "chanchito feliz"

# %%
print(x,y)
# Out:
# 5 chanchito feliz

# %%
email = 'chanchito@feliz.com'

# %%
print(email)  # el nombre de las variables debe ser representativas de lo que ellas están guardando
# Nombres representativos. Ser consistente.
# Out:
# chanchito@feliz.com

# %%
mivar = 'chanchito'
mi_var = 'chanchito'   # Dos formas de dar nombre a mis variables. 
miVar = 'chanchito'
MIVAR = 'chanchito'   # para asignar constante, o variables que no pueden cambiar su valor. 
mivar123 = 'chanchito'   # numeros después de letras.

# %% [markdown]
# # Cómo definir múltiples variables en Python

# %%
a,b,c = 'lala', 'lele', 'lili'

# %%
print(a,b,c)
# Out:
# lala lele lili

# %%
valor1 = valor2 = valor3 = 'chanchito feliz'

# %%
print(valor1, valor2, valor3)
# Out:
# chanchito feliz chanchito feliz chanchito feliz

# %% [markdown]
# ## Referentes
#
# * Basic data types in python: https://realpython.com/python-data-types/
#
# * Nicolas Shurmann: Curso de Python sin fronteras: HTML, CSS, MySQL. Udemy.
