# %% [markdown]
# # Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(5)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
5> 6
# Out:
# False

# %% [markdown]
# # Los números enteros
#
# sirven para describir la edad de las personas

# %%
edad_de_marco = 47

# %%
type(edad_de_marco)
# Out:
# int

# %% [markdown]
# # Números de punto flotante

# %%
estatura_de_marco = 1.65

# %%
1,65
# Out:
# (1, 65)

# %%
type(estatura_de_marco)
# Out:
# float

# %%
nombre_de_marco = "Marco Julio Cañas Campillo"

# %%
nombre_de_mi_hermana = 'Yorlady'

# %%
type(nombre_de_mi_hermana)
# Out:
# str

# %% [markdown]
# # Funciones básicas de Python

# %%
abs(-5)
# Out:
# 5

# %%
divmod(13,3)
# Out:
# (4, 1)

# %%
mod(13,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 mod(13,3)
#
# NameError: name 'mod' is not defined

# %%
import numpy as np

# %%
np.mod(13,3)
# Out:
# 1

# %%
float(1)
# Out:
# 1.0

# %%
float('marco')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 float('marco')
#
# ValueError: could not convert string to float: 'marco'

# %%
int(3.5)
# Out:
# 3

# %%
str('a')
# Out:
# 'a'

# %%
str(1+2)
# Out:
# '3'

# %%
[], (), {}
