# %% [markdown]
# # Python Nicolás Shurmann

# %% [markdown]
# https://wp.catedu.es/colaboraulatic/lightbot-aprendemos-a-programar-en-3d/

# %% [markdown]
# # Instalación de Python

# %% [markdown]
# ## [python.org](https://www.python.org/)

# %% [markdown]
# ## [Instalar Git Bash](https://gitforwindows.org/)

# %% [markdown]
# ## [Instalar un editor de texto](https://code.visualstudio.com/download)

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %% [markdown]
# ## Comparaciones e identación

# %%
mkdir intro_python

# %%
cd intro_python
# Out:
# C:\Users\Marco\Documents\GitHub\taca\propu\unidad_didac\0_python\workspace\holamundo\intro_python

# %%
touch index.py
# Out:
#   Input In [9]
#     touch index.py
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Comentarios

# %% [markdown]
# Es bueno dejarnos mensajes en el código

# %% [markdown]
# ## Variables

# %% [markdown]
# Son cajitas que contienen valores
